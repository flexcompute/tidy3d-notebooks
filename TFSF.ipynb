# %% [markdown]
# # Defining a total-field scattered-field (TFSF) plane wave source
#
# This tutorial demonstrates the use of the [total-field scattered-field (TFSF) source](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.TFSF.html) in `Tidy3D`.
#
# The TFSF source allows specifying a box region into which a plane wave is injected. Fields inside this region can be interpreted as the superposition of the incident field and the scattered field due to any scatterers present in the simulation domain. The fields at the edges of the TFSF box are modified at each time step such that the incident field is cancelled out, so that all fields _outside_ the TFSF box are scattered fields only. This is useful in scenarios where one is interested in computing scattered fields only, for example when computing scattered cross sections of various objects. For an application example of radar cross section calculation using the TFSF technique, see [this notebook](https://www.flexcompute.com/tidy3d/examples/notebooks/Near2FarSphereRCS/).
#
# In this notebook, various situations in which the TFSF source can be applied will be discussed through several examples, including the use of finite- or infinite-extent TFSF regions, angled plane wave injection, and layered substrates.
#
# Note that unlike standard `Tidy3D` [PlaneWave sources](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.PlaneWave.html), the [TFSF source](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.TFSF.html) injects $1 \mathrm{W}\mu\mathrm{m}^{-2}$ of power in the TFSF source injection axis (note: this is **different** from the direction of propagation of the plane wave for angled incidence). This allows computing scattering and absorption cross sections without the need for additional normalization. For example, see [this notebook](https://www.flexcompute.com/tidy3d/examples/notebooks/Near2FarSphereRCS/) for radar cross section validation, and [this notebook](https://www.flexcompute.com/tidy3d/examples/notebooks/PlasmonicNanoparticle/) for absorption by a plasmonic nanoparticle.
#
# If you are new to the finite-difference time-domain (FDTD) method, we highly recommend going through our [FDTD101](https://www.flexcompute.com/fdtd101/) tutorials.

# %%
# standard python imports
import matplotlib.pyplot as plt
import numpy as np

# tidy3d imports
import tidy3d as td
import tidy3d.web as web

# %% [markdown]
# ### Simulation setup
# Here we define the basic simulation parameters that will be used throughout this notebook.

# %%
# basic simulation parameters
sim_size = (6, 6, 8)  # um
wavelength = 1.0  # um
f0 = td.C_0 / wavelength  # Hz
fwidth = f0 / 60.0  # Hz
run_time = 20.0 / fwidth  # s

# grid resolution
cells_per_wvl = 10

# time dependence of the sources used in this notebook
source_time = td.GaussianPulse(freq0=f0, fwidth=fwidth)

# simulation grid specification
grid_spec = td.GridSpec.auto(min_steps_per_wvl=cells_per_wvl)

# boundary conditions: PML on all sides
boundary_spec = td.BoundarySpec.all_sides(td.PML())

# %% [markdown]
# ### Source definition

# %% [markdown]
# We'll define a TFSF source region with angled injection similarly to the way in which any source in `Tidy3D` is defined.

# %%
# make the TFSF source specifying angled injection of a plane wave
source = td.TFSF(
    center=(0, 0, 0),
    size=(4, 3, 4),
    source_time=source_time,
    injection_axis=2,  # inject along the z axis...
    direction="+",  # ...in the positive direction, i.e. along z+
    name="tfsf1",
    pol_angle=0,
    angle_theta=np.pi / 6,  # with respect to the injection plane's normal vector
    angle_phi=np.pi / 5,  # with respect to the injection plane's normal vector
)

# %% [markdown]
# ### Monitor definition
# We'll define a set of monitors to
# - measure the flux that is injected into the simulation and make sure it is properly normalized,
# - measure the flux outside the TFSF region to make sure the incident field does not escape out side the TFSF region, and,
# - visualize the fields on cross sectional cuts through the simulation domain.

# %%
# make a box flux monitor surrounding the source to measure the flux escaping the TFSF box
monitor_out = td.FluxMonitor(
    center=source.center,
    size=[size * 1.2 for size in source.size],
    freqs=[f0],
    name="flux_out",
)

# make a surface flux monitor across the simulation domain to measure the total injected flux
monitor_inj = td.FluxMonitor(
    center=source.center,
    size=[td.inf, td.inf, 0],
    freqs=[f0],
    name="flux_inj",
)

# make field monitors along each cardinal plane to look at the fields
monitor_freq_xy = td.FieldMonitor(
    center=[0, 0, 0],
    size=[td.inf, td.inf, 0],
    freqs=[f0],
    name="freq_xy",
)

monitor_freq_xz = td.FieldMonitor(
    center=[0, 0, 0],
    size=[td.inf, 0, td.inf],
    freqs=[f0],
    name="freq_xz",
)

monitor_freq_yz = td.FieldMonitor(
    center=[0, 0, 0],
    size=[0, td.inf, td.inf],
    freqs=[f0],
    name="freq_yz",
)

# collect all monitors together
monitors = [monitor_out, monitor_inj, monitor_freq_xy, monitor_freq_xz, monitor_freq_yz]

# %% [markdown]
# ### Make simulation

# %%
# make the simulation instance
sim = td.Simulation(
    size=sim_size,
    grid_spec=grid_spec,
    medium=td.Medium(),  # air is the background medium
    structures=[],  # no structures
    sources=[source],
    monitors=monitors,
    run_time=run_time,
    boundary_spec=boundary_spec,
)

# visualize and check that everything was defined as expected
_, ax = plt.subplots(1, 3, figsize=(11, 4))
sim.plot(x=0, ax=ax[0])
sim.plot(y=0, ax=ax[1])
sim.plot(z=source.center[2] - source.size[2] / 2, ax=ax[2])
plt.show()
# Out:
# /tmp/ipykernel_23733/2724976860.py:18: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Run the simulation

# %%
sim_data = web.run(sim, task_name="tfsf1", path="data/tfsf1.hdf5", verbose=True)
# Out:
# 10:47:49 CEST Created task 'tfsf1' with task_id
#               'fdve-9848e7fe-f42a-483a-ac2b-b73e10598978' and task_type 'FDTD'.
# 10:47:50 CEST View task using web UI at
#               ]8;id=939902;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=14583;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\taskId]8;;\]8;id=939902;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\=]8;;\]8;id=782608;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\fdve]8;;\]8;id=939902;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\-9848e7fe-f4]8;;\
#               ]8;id=939902;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\2a-483a-ac2b-b73e10598978']8;;\.
#               Task folder: ]8;id=253397;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 1.4/1.4 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:47:52 CEST Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:47:54 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🚶  Waiting for 'tfsf1'...
# 🏃  Waiting for 'tfsf1'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:48:20 CEST starting up solver
#               running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# 10:48:21 CEST early shutoff detected at 8%, exiting.
# solver progress (field decay = 2.88e-10) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = postprocess
# Output()
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 10:48:23 CEST status = success
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# 🚶  Finishing 'tfsf1'...
# 🏃  Finishing 'tfsf1'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:48:25 CEST View simulation result at
#               ]8;id=523832;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=513019;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\taskId]8;;\]8;id=523832;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\=]8;;\]8;id=457572;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\fdve]8;;\]8;id=523832;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\-9848e7fe-f4]8;;\
#               ]8;id=523832;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9848e7fe-f42a-483a-ac2b-b73e10598978\2a-483a-ac2b-b73e10598978']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━━━━━━━━━ 22.8% • 0.3/1.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━ 45.6% • 0.5/1.1 MB • 207.5 kB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.4% • 0.8/1.1 MB • 143.3 kB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸━ 91.2% • 1.0/1.1 MB • 89.8 kB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━ 100.0% • 1.1/1.1 MB • 52.9 kB/s • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:48:48 CEST loading simulation from data/tfsf1.hdf5

# %% [markdown]
# ### Flux results
# If $1 \mathrm{W}\mu\mathrm{m}^{-2}$ is injected by the source, then the total injected flux captured should equal the area of the injection surface. To check that this is the case, we divide the computed injected flux by the area of the injection surface, and expect to obtain $1 \mathrm{W}\mu\mathrm{m}^{-2}$. We notice that the actual number is close to 1, but only within 1.5% accuracy. The reason for this is that the TFSF box actually snaps to the nearest FDTD grid cells. So, the actual area over which the source is injected is slightly different from the analytical area computed using `source.size`.
#
# We notice that the flux escaping the box is about ten orders of magnitude lower than the injected flux, and therefore negligible, as expected.

# %%
# print the escaped and injected flux
print(
    "flux_inj per unit area: ",
    sim_data["flux_inj"].flux.values[0] / source.size[0] / source.size[1],
)
print("flux_box: ", sim_data["flux_out"].flux.values[0])
# Out:
# flux_inj per unit area:  1.0162636
# flux_box:  4.9347826e-10

# %% [markdown]
# ### Field plots
# Here we'll visualize the frequency-domain fields and check that the plane wave is injected at the expected angle inside the TFSF box. As shown in the figures, the injected fields look correct inside the TFSF box, and are zero outside the box because there are no scatterers in this example.

# %%
# helper plot the fields for each cross section of the simulation for given simulation data
def plot_results_freq(sim_data, field_name="Ex", val="real"):
    """Helper for plotting frequency domain fields."""

    _, (ax1, ax2, ax3) = plt.subplots(1, 3, tight_layout=True, figsize=(12, 3))

    sim_data.plot_field(field_monitor_name="freq_xz", field_name=field_name, val=val, f=f0, ax=ax1)
    sim_data.plot_field(field_monitor_name="freq_yz", field_name=field_name, val=val, f=f0, ax=ax2)
    sim_data.plot_field(field_monitor_name="freq_xy", field_name=field_name, val=val, f=f0, ax=ax3)
    plt.show()


plot_results_freq(sim_data, field_name="Ex", val="real")
# Out:
# /tmp/ipykernel_23733/3597805261.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Infinite slab
# We can also make the TFSF box a slab which is infinite in the transverse directions ($x$ and $y$ in this example). However, in this case we must ensure that the boundary conditions in those directions are compatible with the injected plane wave. For angled incidence, this implies that Bloch periodic boundaries ([BlochBoundary](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.BlochBoundary.html)) must be used along $x$ and $y$. For normal incidence, either standard [Periodic](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Periodic.html) or Bloch boundaries can be used.
#
# **Important**: the TFSF box must not touch or protrude beyond the simulation domain along the injection axis. In this example, the TFSF box must not touch or go past the simulation domain in the $-z$ or $+z$ directions, because our `injection_axis` is `2`, i.e. $z$.

# %%
# make a TFSF source infinite along x and y
source = td.TFSF(
    center=(0, 0, 0),
    size=(td.inf, td.inf, 4),
    source_time=source_time,
    injection_axis=2,  # inject along the z axis...
    direction="+",  # ...in the positive direction, i.e. along z+
    name="tfsf2",
    pol_angle=0,
    angle_theta=np.pi / 4,
    angle_phi=np.pi / 4,
)

# specify boundaries compatible with this source
boundary_spec = td.BoundarySpec(
    x=td.Boundary.bloch_from_source(source=source, domain_size=sim_size[0], axis=0),
    y=td.Boundary.bloch_from_source(source=source, domain_size=sim_size[1], axis=1),
    z=td.Boundary.pml(),
)

# make flux monitors above and below the source to measure the escaped flux
center = [source.center[0], source.center[1], source.center[2]]
center[source.injection_axis] += 1.2 * source.size[source.injection_axis] / 2.0
monitor_above = td.FluxMonitor(
    center=[
        source.center[0],
        source.center[1],
        source.center[2] + 1.2 * source.size[2] / 2.0,
    ],
    size=[td.inf, td.inf, 0],
    freqs=[f0],
    name="flux_above",
)

center = [source.center[0], source.center[1], source.center[2]]
center[source.injection_axis] -= 1.2 * source.size[source.injection_axis] / 2.0
monitor_below = td.FluxMonitor(
    center=[
        source.center[0],
        source.center[1],
        source.center[2] - 1.2 * source.size[2] / 2.0,
    ],
    size=[td.inf, td.inf, 0],
    freqs=[f0],
    name="flux_below",
)

# collect all the monitors together again
monitors = [
    monitor_above,
    monitor_below,
    monitor_inj,
    monitor_freq_xy,
    monitor_freq_xz,
    monitor_freq_yz,
]

# %% [markdown]
# ### Make simulation

# %%
# update the simulation object with the new source, boundaries, and monitors
sim = sim.copy(
    update={
        "sources": [source],
        "boundary_spec": boundary_spec,
        "monitors": monitors,
    }
)

# visualize
_, ax = plt.subplots(1, 3, figsize=(11, 4))
sim.plot(x=0, ax=ax[0])
sim.plot(y=0, ax=ax[1])
sim.plot(z=source.center[2] - source.size[2] / 2, ax=ax[2])
plt.show()
# Out:
# /tmp/ipykernel_23733/3960784786.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Run the simulation

# %%
sim_data = web.run(sim, task_name="tfsf2", path="data/tfsf2.hdf5", verbose=True)
# Out:
# 10:48:53 CEST Created task 'tfsf2' with task_id
#               'fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=879822;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=815551;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\taskId]8;;\]8;id=879822;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\=]8;;\]8;id=551548;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\fdve]8;;\]8;id=879822;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\-a177f466-66]8;;\
#               ]8;id=879822;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\fa-43a5-9aab-bc9b0eaea8d7']8;;\.
#               Task folder: ]8;id=587592;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.4 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 1.4/1.4 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:48:56 CEST Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:48:57 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🏃  Waiting for 'tfsf2'...
# 🚶  Waiting for 'tfsf2'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:09 CEST starting up solver
#               running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# 10:49:10 CEST early shutoff detected at 8%, exiting.
# solver progress (field decay = 6.60e-10) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               View simulation result at
#               ]8;id=264634;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=679751;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\taskId]8;;\]8;id=264634;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\=]8;;\]8;id=466716;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\fdve]8;;\]8;id=264634;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\-a177f466-66]8;;\
#               ]8;id=264634;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a177f466-66fa-43a5-9aab-bc9b0eaea8d7\fa-43a5-9aab-bc9b0eaea8d7']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.1% • 262.1/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.1% • 262.1/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.1% • 262.1/654.0 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━ 80.2% • 524.3/654.0 • 606.6 kB/s • 0:00:01
#                                               kB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━ 100.0% • 654.0/654.0 • 812.8 kB/s • 0:00:00
#                                               kB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:14 CEST loading simulation from data/tfsf2.hdf5

# %% [markdown]
# ### Flux results
# Here, the flux injected by the source is extremely close to $1 \mathrm{W}\mu\mathrm{m}^{-2}$ as there are no finite-size effects at the source boundaries. As expected, the flux escaping above and below the TFSF slab is negligibly small.

# %%
# print the escaped and injected flux
print(
    "flux_inj per unit area: ",
    sim_data["flux_inj"].flux.values[0] / sim.size[0] / sim.size[1],
)  # using sim.size because the TFSF slab extends to sim edges
print("flux_above: ", sim_data["flux_above"].flux.values[0])
print("flux_below: ", sim_data["flux_below"].flux.values[0])
# Out:
# flux_inj per unit area:  0.9999965
# flux_above:  1.0977185e-08
# flux_below:  -1.28966325e-11

# %% [markdown]
# ### Field plots
# In plotting the fields, we can see that the plane wave is injected at the desired angle without leakage into the scattered-field region.

# %%
plot_results_freq(sim_data, field_name="Ex", val="real")
# Out:
# /tmp/ipykernel_23733/3597805261.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### TFSF source in a layered substrate
# A TFSF source can be set up in a layered substrate as long as the following condition is satisfied: **all four side walls of the TFSF box must see the same material profile along the injection axis**. In other words, any scatterers in the domain must either:
#
#  - intersect each of the 4 side walls of the TFSF box in exactly the same way, e.g., a layered substrate, or,
#
#  - be entirely inside or entirely outside the TFSF box.
#
# This example shows how to set up a TFSF source in a layered substrate.

# %%
# parameters of the layered substrate
epsrs = [4, 1.5, 5.5, 2.8]  # permittivities
zsizes = [0.3, 0.6, 0.7, 1.2]  # thicknesses
zpos = -1.5  # starting position of the first layer

# make the layer structures
layers = []
for idx, epsr in enumerate(epsrs):
    medium = td.Medium(permittivity=epsr)
    size = (td.inf, td.inf, zsizes[idx])
    center = (0, 0, zpos + zsizes[idx] / 2)
    layers.append(td.Structure(geometry=td.Box(center=center, size=size), medium=medium))
    zpos += zsizes[idx]

# make a TFSF box
source = td.TFSF(
    center=(0, 0, 0),
    size=(4, 3, 4),
    source_time=source_time,
    injection_axis=2,  # inject along the z axis...
    direction="+",  # ...in the positive direction, i.e. along z+
    name="tfsf3",
    pol_angle=0,
    angle_theta=np.pi / 6,
    angle_phi=np.pi / 7,
)

# specify boundaries compatible with the source for the scattered fields to obey;
# note that the source plane goes through the first layer of the substrate,
# so we should use that medium when specifying the Bloch boundaries
boundary_spec = td.BoundarySpec(
    x=td.Boundary.bloch_from_source(
        source=source,
        domain_size=sim_size[0],
        axis=0,
        medium=td.Medium(permittivity=epsrs[0]),
    ),
    y=td.Boundary.bloch_from_source(
        source=source,
        domain_size=sim_size[1],
        axis=1,
        medium=td.Medium(permittivity=epsrs[0]),
    ),
    z=td.Boundary.pml(),
)

# reuse the monitors from the first simulation
monitors = [monitor_out, monitor_inj, monitor_freq_xy, monitor_freq_xz, monitor_freq_yz]

# %% [markdown]
# ### Make simulation

# %%
# update the simulation object with the new source, boundaries, monitors, and structures
sim = sim.copy(
    update={
        "sources": [source],
        "boundary_spec": boundary_spec,
        "monitors": monitors,
        "structures": layers,
    }
)

# visualize
_, ax = plt.subplots(1, 3, figsize=(11, 4))
sim.plot(x=0, ax=ax[0])
sim.plot(y=0, ax=ax[1])
sim.plot(z=source.center[2] - source.size[2] / 2, ax=ax[2])
plt.show()
# Out:
# /tmp/ipykernel_23733/726226030.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Run the simulation

# %%
sim_data = web.run(sim, task_name="tfsf3", path="data/tfsf3.hdf5", verbose=True)
# Out:
# 10:49:16 CEST Created task 'tfsf3' with task_id
#               'fdve-eae82f40-eacb-457e-82c1-04fbd912ef87' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=5708;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=949412;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\taskId]8;;\]8;id=5708;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\=]8;;\]8;id=849461;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\fdve]8;;\]8;id=5708;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\-eae82f40-ea]8;;\
#               ]8;id=5708;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\cb-457e-82c1-04fbd912ef87']8;;\.
#               Task folder: ]8;id=967638;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 1.6/1.6 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:18 CEST Maximum FlexCredit cost: 0.082. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:49:20 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🚶  Waiting for 'tfsf3'...
# 🏃  Waiting for 'tfsf3'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:27 CEST starting up solver
#               running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# solver progress (field decay = 3.83e-07) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% -:--:--
# 10:49:34 CEST early shutoff detected at 8%, exiting.
# solver progress (field decay = 3.83e-07) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:35 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               View simulation result at
#               ]8;id=781851;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=876098;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\taskId]8;;\]8;id=781851;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\=]8;;\]8;id=480807;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\fdve]8;;\]8;id=781851;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\-eae82f40-ea]8;;\
#               ]8;id=781851;https://tidy3d.simulation.cloud/workbench?taskId=fdve-eae82f40-eacb-457e-82c1-04fbd912ef87\cb-457e-82c1-04fbd912ef87']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━╺━━━━━━━━━━━━━━━━━━━ 9.9% • 0.3/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━╺━━━━━━━━━━━━━━━━━━━ 9.9% • 0.3/2.7 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━╺━━━━━━━━━ 29.6% • 0.8/2.7 MB • 2.3 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━╺━━━━━━━━━ 29.6% • 0.8/2.7 MB • 2.3 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━━━ 69.1% • 1.8/2.7 MB • 3.1 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺━━ 78.9% • 2.1/2.7 MB • 2.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━ 100.0% • 2.7/2.7 MB • 3.6 MB/s • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:38 CEST loading simulation from data/tfsf3.hdf5

# %% [markdown]
# ### Flux results
# Despite the elaborate stack-up of dielectric layers considered above, we again see that the incident field is effectively confined within the TFSF box, while taking into account the presence of the layered substrate, with negligible leakage to the scattered field region.

# %%
# print the escaped flux
print("flux_box: ", sim_data["flux_out"].flux.values[0])
# Out:
# flux_box:  3.6938659e-09

# %% [markdown]
# ### Field plots
# The frequency-domain field plots confirm that the incident field is injected at the expected angle, takes into account the layer interfaces, and remains confined to the total field region.

# %%
plot_results_freq(sim_data, field_name="Ex", val="real")
# Out:
# /tmp/ipykernel_23733/3597805261.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Example with a scatterer
# Finally, we'll simulate the presence of a scatterer inside the TFSF box, as would be the case in scattering cross section problems. To validate the result, we'll also simulate the same scatterer using a standard plane wave source, and then compute the scattered field by subtracting out the incident field manually. This will require an additional simulation of the same domain but without the scatterer, to compute the incident field. This example will demonstrate the usefulness of TFSF in obtaining scattered fields without the need to run two simulations.

# %%
# make a TFSF box
source = td.TFSF(
    center=(0, 0, 0.2),
    size=(5, 5, 3.5),
    source_time=source_time,
    injection_axis=2,  # inject along the z axis...
    direction="+",  # ...in the positive direction, i.e. along z+
    name="tfsf4",
    pol_angle=0,
)

# set up scatterers: two boxes and a sphere inside the TFSF box
box1 = td.Structure(
    geometry=td.Box(center=[0, 0, 0.3], size=[4, 4, 0.6]),
    medium=td.material_library["SiO2"]["Horiba"],
)

box2 = td.Structure(
    geometry=td.Box(center=[0, 0, 1], size=[3, 3, 0.8]),
    medium=td.material_library["SiN"]["Horiba"],
)

sphere = td.Structure(
    geometry=td.Sphere(center=[-1, 0, -0.8], radius=0.6),
    medium=td.Medium(permittivity=2.4),
)

# collect all objects
structures = [box1, box2, sphere]

# make a field monitor above the TFSF box to compare fields between the two cases
monitor_freq = td.FieldMonitor(
    center=[0, 0, 2.5],
    size=[td.inf, td.inf, 0],
    freqs=[f0],
    name="freq",
)

# specify PML boundaries on all sides
boundary_spec = td.BoundarySpec.all_sides(td.PML())

# %% [markdown]
# #### Simulation with TFSF source
#
# It is important to note that when a non-uniform grid is used in the directions transverse to the `injection_axis` of the TFSF source, the suppression of the incident field outside the TFSF box may not be as close to zero as in the case of a uniform grid. Because of this, Tidy3D issues a warning when nonuniform grid TFSF setup is detected. In some cases, however, the accuracy may be only weakly affected, and the warnings can be ignored. In this example, the presence of scatterers does cause the auto-generated FDTD grid to be non-uniform in the $x$ and $y$ directions, but as we'll see, the results are still in excellent agreement with the reference simulation. To force a uniform grid in the TFSF region and avoid the warnings, a mesh override structure can be used, as illustrated in our [nanoparticle scattering example](../notebooks/PlasmonicNanoparticle.html).
#
# The presence of a non-uniform grid _along_ the `injection_axis` is not a problem.

# %%
# make the TFSF simulation by updating the previous one with the new structures and monitor
sim = sim.copy(
    update={
        "boundary_spec": boundary_spec,
        "monitors": [monitor_freq],
        "structures": structures,
        "sources": [source],
    }
)

# visualize
_, ax = plt.subplots(1, 3, figsize=(11, 4))
sim.plot(x=0, ax=ax[0])
sim.plot(y=0, ax=ax[1])
sim.plot(z=source.center[2] - source.size[2] / 2, ax=ax[2])
plt.show()
# Out:
# 10:49:40 CEST WARNING: The grid is nonuniform along the 'x' axis, which may lead
#               to sub-optimal cancellation of the incident field in the
#               scattered-field region for the total-field scattered-field (TFSF)
#               source 'tfsf4'. For best results, we recommended ensuring a
#               uniform grid in both directions tangential to the TFSF injection
#               axis, 'z'.
#               WARNING: Suppressed 1 WARNING message.
# /tmp/ipykernel_23733/1809349779.py:16: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# #### Reference simulation
#
# We will compare the results with a simulation that uses a regular plane wave source, where we compute scattered fields by also running an empty simulation and subtracting the results of the empty simulation from the results of the full one.

# %%
# make the two reference simulation with a standard plane wave source, one of them without the scatterer
source_planewave = td.PlaneWave(
    center=(0, 0, -1.55),
    size=(td.inf, td.inf, 0),
    source_time=source_time,
    direction="+",
    name="planewave",
    pol_angle=0,
)

sim_ref = sim.copy(
    update={
        "sources": [source_planewave],
    }
)

# for the empty simulation, we need to make sure the grid is identical to the one with objects,
# so we use override structures to create "phantoms" of the objects, so that the grid is generated
# as though the objects were there, even though they're not
grid_spec_empty = td.GridSpec.auto(
    min_steps_per_wvl=cells_per_wvl,
    override_structures=[box1, box2, sphere],
)

sim_ref_empty = sim.copy(
    update={
        "sources": [source_planewave],
        "structures": [],
        "grid_spec": grid_spec_empty,
    }
)

# visualize both simulations
_, ax = plt.subplots(1, 2, figsize=(8, 4))
sim_ref.plot(x=0, ax=ax[0])
sim_ref.plot(y=0, ax=ax[1])
plt.show()

_, ax = plt.subplots(1, 2, figsize=(8, 4))
sim_ref_empty.plot(x=0, ax=ax[0])
sim_ref_empty.plot(y=0, ax=ax[1])
plt.show()
# Out:
# /tmp/ipykernel_23733/1739830916.py:37: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /tmp/ipykernel_23733/1739830916.py:42: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ### Run all three simulations

# %%
# TFSF simulation
sim_data = web.run(sim, task_name="tfsf4", path="data/tfsf4.hdf5")

# planewave simulation
sim_data_ref = web.run(sim_ref, task_name="planewave", path="data/planewave.hdf5")

# planewave simulation without objects
sim_data_ref_empty = web.run(
    sim_ref_empty, task_name="planewave_empty", path="data/planewave_empty.hdf5"
)
# Out:
# 10:49:41 CEST Created task 'tfsf4' with task_id
#               'fdve-ebc92522-8835-4c20-88f6-129c6f53f47c' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=452434;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=368834;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\taskId]8;;\]8;id=452434;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\=]8;;\]8;id=550749;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\fdve]8;;\]8;id=452434;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\-ebc92522-88]8;;\
#               ]8;id=452434;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\35-4c20-88f6-129c6f53f47c']8;;\.
#               Task folder: ]8;id=91929;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 1.6/1.6 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:43 CEST Maximum FlexCredit cost: 0.028. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:49:44 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🏃  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# 🚶  Waiting for 'tfsf4'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:52 CEST starting up solver
#               running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# 10:49:54 CEST early shutoff detected at 12%, exiting.
# solver progress (field decay = 2.09e-06) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = postprocess
# Output()
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 10:49:57 CEST status = success
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🏃  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# 🚶  Finishing 'tfsf4'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:49:59 CEST View simulation result at
#               ]8;id=758558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=117934;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\taskId]8;;\]8;id=758558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\=]8;;\]8;id=104860;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\fdve]8;;\]8;id=758558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\-ebc92522-88]8;;\
#               ]8;id=758558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-ebc92522-8835-4c20-88f6-129c6f53f47c\35-4c20-88f6-129c6f53f47c']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 39.3% • 262.1/666.4 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 78.7% • 524.3/666.4  • 2.2 MB/s • 0:00:01
#                                                kB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 78.7% • 524.3/666.4  • 2.2 MB/s • 0:00:01
#                                                kB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━ 100.0% • 666.4/666.4 • 1.4 MB/s • 0:00:00
#                                                 kB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:50:02 CEST loading simulation from data/tfsf4.hdf5
#               WARNING: The grid is nonuniform along the 'x' axis, which may lead
#               to sub-optimal cancellation of the incident field in the
#               scattered-field region for the total-field scattered-field (TFSF)
#               source 'tfsf4'. For best results, we recommended ensuring a
#               uniform grid in both directions tangential to the TFSF injection
#               axis, 'z'.
#               WARNING: Suppressed 1 WARNING message.
#               WARNING: Warning messages were found in the solver log. For more
#               information, check 'SimulationData.log' or use
#               'web.download_log(task_id)'.
# 10:50:03 CEST Created task 'planewave' with task_id
#               'fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=667339;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=167109;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\taskId]8;;\]8;id=667339;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\=]8;;\]8;id=868358;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\fdve]8;;\]8;id=667339;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\-beef654f-db]8;;\
#               ]8;id=667339;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\8a-4cc1-bb62-727a87c5e28d']8;;\.
#               Task folder: ]8;id=306333;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 1.6/1.6 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:50:05 CEST Maximum FlexCredit cost: 0.028. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:50:06 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🚶  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# 🏃  Waiting for 'planewave'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:50:20 CEST starting up solver
#               running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# solver progress (field decay = 7.25e-07) ━━━╺━━━━━━━━━━━━━━━━━━━━━━  12% -:--:--
# 10:50:25 CEST early shutoff detected at 12%, exiting.
# solver progress (field decay = 7.25e-07) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               View simulation result at
#               ]8;id=543558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=160552;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\taskId]8;;\]8;id=543558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\=]8;;\]8;id=438210;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\fdve]8;;\]8;id=543558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\-beef654f-db]8;;\
#               ]8;id=543558;https://tidy3d.simulation.cloud/workbench?taskId=fdve-beef654f-db8a-4cc1-bb62-727a87c5e28d\8a-4cc1-bb62-727a87c5e28d']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━━━━━ 40.6% • 262.1/645.7 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━ 81.2% • 524.3/645.7 • 206.2 kB/s • 0:00:01
#                                               kB
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━ 81.2% • 524.3/645.7 • 206.2 kB/s • 0:00:01
#                                               kB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━ 100.0% • 645.7/645.7 • 250.4 kB/s • 0:00:00
#                                               kB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:50:32 CEST loading simulation from data/planewave.hdf5
# 10:50:33 CEST Created task 'planewave_empty' with task_id
#               'fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=108185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=29733;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\taskId]8;;\]8;id=108185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\=]8;;\]8;id=468014;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\fdve]8;;\]8;id=108185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\-642a6111-4f]8;;\
#               ]8;id=108185;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\7a-4056-9e1a-3b3c78c30af2']8;;\.
#               Task folder: ]8;id=920531;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/1.7 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 1.7/1.7 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:50:35 CEST Maximum FlexCredit cost: 0.025. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:50:36 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 10:50:45 CEST status = preprocess
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🏃  Waiting for 'planewave_empty'...
# 🚶  Waiting for 'planewave_empty'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:50:50 CEST starting up solver
#               running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# 10:50:51 CEST early shutoff detected at 8%, exiting.
# solver progress (field decay = 6.85e-10) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               View simulation result at
#               ]8;id=182058;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=565746;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\taskId]8;;\]8;id=182058;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\=]8;;\]8;id=126495;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\fdve]8;;\]8;id=182058;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\-642a6111-4f]8;;\
#               ]8;id=182058;https://tidy3d.simulation.cloud/workbench?taskId=fdve-642a6111-4f7a-4056-9e1a-3b3c78c30af2\7a-4056-9e1a-3b3c78c30af2']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/36.1 kB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━ 100.0% • 36.1/36.1 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:50:55 CEST loading simulation from data/planewave_empty.hdf5

# %% [markdown]
# For the reference simulation, compute the scattered fields by subtracting the results of the empty simulation.

# %%
# for the plane wave simulations, we need to manually compute the scattered fields
# by subtracting out the incident fields computed in the empty simulation
data_ref = sim_data_ref[monitor_freq.name]
data_ref_empty = sim_data_ref_empty[monitor_freq.name]

for field, field_empty in zip(
    data_ref.field_components.values(), data_ref_empty.field_components.values()
):
    field.values -= field_empty.values

# %% [markdown]
# ### Plot and compare
# Notice the excellent agreement in the scattered field distribution for the TFSF and reference cases. Note, however, that the field magnitudes are different in the two cases. The reason is that the sources are normalized differently, as discussed above.

# %%
fig, (ax1, ax2, ax3) = plt.subplots(1, 3, tight_layout=True, figsize=(12, 3))

im1 = ax1.pcolormesh(
    np.real(sim_data[monitor_freq.name].Ex.isel(z=0, f=0)), cmap="RdBu", shading="auto"
)
im2 = ax2.pcolormesh(
    np.real(sim_data[monitor_freq.name].Ey.isel(z=0, f=0)), cmap="RdBu", shading="auto"
)
im3 = ax3.pcolormesh(
    np.real(sim_data[monitor_freq.name].Ez.isel(z=0, f=0)), cmap="RdBu", shading="auto"
)
fig.colorbar(im1, ax=ax1)
fig.colorbar(im2, ax=ax2)
fig.colorbar(im3, ax=ax3)
plt.show()

fig, (ax1, ax2, ax3) = plt.subplots(1, 3, tight_layout=True, figsize=(12, 3))

im1 = ax1.pcolormesh(np.real(data_ref.Ex.isel(z=0, f=0)), cmap="RdBu", shading="auto")
im2 = ax2.pcolormesh(np.real(data_ref.Ey.isel(z=0, f=0)), cmap="RdBu", shading="auto")
im3 = ax3.pcolormesh(np.real(data_ref.Ez.isel(z=0, f=0)), cmap="RdBu", shading="auto")
fig.colorbar(im1, ax=ax1)
fig.colorbar(im2, ax=ax2)
fig.colorbar(im3, ax=ax3)

plt.show()
# Out:
# /tmp/ipykernel_23733/3619522483.py:15: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
# /tmp/ipykernel_23733/3619522483.py:26: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
