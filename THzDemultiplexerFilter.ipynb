# %% [markdown]
# # THz integrated demultiplexer/filter based on a ring resonator

# %% [markdown]
# Note: the cost of running the entire notebook is larger than 1 FlexCredit.
#
# Wireless communication technology has been experiencing rapid development to satisfy the ever growing need for higher data transmission speed. The current 5G network has been harnessing the power of microwave and mm wave. The future generations of wireless communication clearly points to even higher frequencies, entering the THz territory.
#
# Inspired by the advancement of integrated photonics at telecom wavelength, integrated THz technology is a promising candidate for future mass production of compact THz communication devices. This model aims to demonstrate the modeling of a silicon-based THz demultiplexer/filter, which is a crucial component in a high-speed integrated THz communication system. The device utilizes a ring resonator structure similar to a typical ring resonator used in a telecom integrated circuit. It achieves <1.5 dB transmission loss and 3 GHz free spectral range. The design of the device is adapted from [Deng, W. et al. On‐Chip Polarization‐ and Frequency‐Division Demultiplexing for Multidimensional Terahertz Communication. Laser Photon. Rev. 16, 2200136 (2022)](https://onlinelibrary.wiley.com/doi/abs/10.1002/lpor.202200136).
#
# <img src="img/thz_ring_resonator.png" width="700" alt="Schematic of the demultiplexer">
#
# For more integrated photonic examples such as the [8-Channel mode and polarization de-multiplexer](https://www.flexcompute.com/tidy3d/examples/notebooks/8ChannelDemultiplexer/), the [broadband bi-level taper polarization rotator-splitter](https://www.flexcompute.com/tidy3d/examples/notebooks/BilevelPSR/), and the [broadband directional coupler](https://www.flexcompute.com/tidy3d/examples/notebooks/BroadbandDirectionalCoupler/), please visit our [examples page](https://www.flexcompute.com/tidy3d/examples/).
#
# If you are new to the finite-difference time-domain (FDTD) method, we highly recommend going through our [FDTD101](https://www.flexcompute.com/fdtd101/) tutorials. FDTD simulations can diverge due to various reasons. If you run into any simulation divergence issues, please follow the steps outlined in our [troubleshooting guide](https://www.flexcompute.com/tidy3d/examples/notebooks/DivergedFDTDSimulation/) to resolve it.

# %% [markdown]
# ## Simulation Setup

# %%
import matplotlib.pyplot as plt
import numpy as np
import tidy3d as td
import tidy3d.web as web
from tidy3d.plugins.mode import ModeSolver

# %% [markdown]
# The demultiplexer/filter device consists of a ring resonator, a through port waveguide, and a drop port waveguide. It is fabricated on a silicon wafer with a thickness of 130 $\mu m$. A ridge waveguide with 110 $\mu m$ height is used. The radius of the ring resonator is designed to ensure low loss for the TE0 mode.

# %%
t_si = 130  # thickness of the si wafer
t_wg = 110  # height of the ridge waveguide
W0 = 200  # width of the waveguide
R1 = 3500  # inner radius of the ring resonator
R2 = 2000  # inner radius of the waveguide bend
Wg = 50  # width of the gap
s = 3000  # horizontal shift of the waveguide bend
inf_eff = 1e5  # effective infinity. This parameter is used to ensure the ports extend into the pml.

freq0 = 380e9  # central frequency
lda0 = td.C_0 / freq0  # central wavelength
freqs = np.linspace(375e9, 385e9, 301)  # wavelength range.
# To ensure we resolve the spectral features, 301 frequency points are used.

# %% [markdown]
# Since the whole structure is made of silicon, only two materials need to be defined -- silicon and air. At the simulation frequency, silicon has a small loss of $\alpha$=0.025 $cm^{-1}$. Therefore, the imaginary part of the refractive index can be calculated as $k = \frac{\alpha \lambda}{4\pi}$. Since the frequency dispersion is very small, we will model silicon as dispersionless material.

# %%
alpha = 0.025  # loss
k_si = alpha * lda0 * 1e-4 / (4 * np.pi)  # imaginary part of the Si refractive index
n_si = 3.405  # real part of the Si refractive index

si = td.Medium.from_nk(n=n_si, k=k_si, freq=freq0)
air = td.Medium(permittivity=1)

# %% [markdown]
# To build the device, we need to keep in mind that when two structures overlap, the one added later will override the one added earlier. This gives us great flexibility when making more complex geometries.
#
# To make the ring resonator, we first create a [Cylinder](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Cylinder.html) made of silicon with the radius set to the outer radius of the ring. Then, another [Cylinder](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Cylinder.html) made of air with the radius set to the inner radius of the ring is added. This effectively results in a silicon ring. The waveguide bend structure is built using the same principle.

# %%
# through port waveguide
wg1 = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, 0, 0), rmax=(inf_eff, W0, t_si)),
    medium=si,
)


# ring resonator
ring_out = td.Structure(
    geometry=td.Cylinder(
        center=(0, 2 * W0 + Wg + R1, t_si / 2), radius=R1 + W0, length=t_si, axis=2
    ),
    medium=si,
)

ring_in = td.Structure(
    geometry=td.Cylinder(center=(0, 2 * W0 + Wg + R1, t_si / 2), radius=R1, length=t_si, axis=2),
    medium=air,
)


# waveguide bend
wg_bend_out = td.Structure(
    geometry=td.Cylinder(
        center=(-s, 4 * W0 + 2 * Wg + 2 * R1 + R2, t_si / 2),
        radius=R2 + W0,
        length=t_si,
        axis=2,
    ),
    medium=si,
)

wg_bend_in = td.Structure(
    geometry=td.Cylinder(
        center=(-s, 4 * W0 + 2 * Wg + 2 * R1 + R2, t_si / 2),
        radius=R2,
        length=t_si,
        axis=2,
    ),
    medium=air,
)

wg_bend_left = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-s, 3 * W0 + 2 * Wg + 2 * R1, 0),
        rmax=(-s + R2 + W0, 5 * W0 + 2 * Wg + 2 * R1 * 2 * R2, t_si),
    ),
    medium=air,
)


# drop port waveguide
wg2 = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-s, 3 * W0 + 2 * Wg + 2 * R1, 0), rmax=(s, 4 * W0 + 2 * Wg + 2 * R1, t_si)
    ),
    medium=si,
)

wg3 = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-s, 4 * W0 + 2 * Wg + 2 * R1 + 2 * R2, 0),
        rmax=(inf_eff, 5 * W0 + 2 * Wg + 2 * R1 + 2 * R2, t_si),
    ),
    medium=si,
)


# si wafer
si_substrate = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, 0), rmax=(inf_eff, inf_eff, t_si - t_wg)),
    medium=si,
)

# %% [markdown]
# Define source and monitors. Here we will define a [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeSource.html) that launches the TE0 mode into the input waveguide. Two [FluxMonitors](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.FluxMonitor.html) are added to the through port and the drop port to monitor the transmission. A [FieldMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.FieldMonitor.html) is added in the xy plane to visualize the field distribution.

# %%
mode_spec = td.ModeSpec(
    num_modes=1, target_neff=3
)  # we are only interested in the TE0 mode so num_modes is set to 1
# add a mode source at the input of the waveguide
mode_source = td.ModeSource(
    center=(-1.5 * R1, W0 / 2, t_si / 2),
    size=(0, 4 * W0, 4 * t_si),
    source_time=td.GaussianPulse(freq0=freq0, fwidth=freq0 / 10),
    direction="+",
    mode_spec=mode_spec,
    mode_index=0,
)

# add two flux monitors at the through port and the drop port
flux_monitor1 = td.FluxMonitor(
    center=(1.5 * R1, W0 / 2, t_si / 2),
    size=(0, 4 * W0, 4 * t_si),
    freqs=freqs,
    name="flux1",
)

flux_monitor2 = td.FluxMonitor(
    center=(1.5 * R1, 4.5 * W0 + 2 * Wg + 2 * R1 + 2 * R2, t_si / 2),
    size=(0, 4 * W0, 4 * t_si),
    freqs=freqs,
    name="flux2",
)

freq1 = 378.8e9  # frequency at which the power is transmitted to the through port
freq2 = 380.2e9  # frequency at which the power is transmitted to the drop port

# define a field monitor in the z=0 plane to visualize the field flow
field_monitor = td.FieldMonitor(
    center=(0, 0, t_si / 2),
    size=(td.inf, td.inf, 0),
    freqs=[freq1, freq2],
    name="field",
)

# %% [markdown]
# Define the simulation using the above structures, source, and monitors. Due to the high-Q resonance of the ring resonator, we need to ensure that the simulation run time is sufficiently long.

# %%
buffer_y = lda0  # buffer spacing in the y direction

# simulation domain size
Lx = 3.5 * R1
Ly = 2 * R1 + 2 * R2 + 5 * W0 + 2 * Wg + 2 * buffer_y
Lz = 1.5 * lda0
sim_size = (Lx, Ly, Lz)

run_time = 12e-9  # simulation run time

# initialize the Simulation object
sim = td.Simulation(
    center=(0, Ly / 2 - buffer_y, t_si),
    size=sim_size,
    grid_spec=td.GridSpec.auto(min_steps_per_wvl=15, wavelength=lda0),
    structures=[
        wg1,
        ring_out,
        ring_in,
        wg_bend_out,
        wg_bend_in,
        wg_bend_left,
        wg2,
        wg3,
        si_substrate,
    ],
    sources=[mode_source],
    monitors=[field_monitor, flux_monitor1, flux_monitor2],
    run_time=run_time,
    boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),
)

# visualize the structure to make sure it is set up correctly
sim.plot(z=t_si)
plt.show()
# Out:
# 10:51:31 CEST WARNING:  ℹ️ ⚠️ RF simulations are subject to new license
#               requirements in the future. You are using RF-specific components
#               in this simulation.
#                - Contains sources defined for RF wavelengths.
# /tmp/ipykernel_24487/111889182.py:35: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# Visualize the mode field to ensure we are launching the TE0 mode at the mode source.

# %%
mode_solver = ModeSolver(
    simulation=sim,
    plane=td.Box(center=(-R1, W0 / 2, t_si / 2), size=(0, 4 * W0, 4 * t_si)),
    mode_spec=mode_spec,
    freqs=[freq0],
)
mode_data = mode_solver.solve()

f, (ax1, ax2, ax3) = plt.subplots(1, 3, tight_layout=True, figsize=(10, 3))
abs(mode_data.Ex.isel(mode_index=0)).plot(x="y", y="z", ax=ax1, cmap="magma")
abs(mode_data.Ey.isel(mode_index=0)).plot(x="y", y="z", ax=ax2, cmap="magma")
abs(mode_data.Ez.isel(mode_index=0)).plot(x="y", y="z", ax=ax3, cmap="magma")

ax1.set_title("|Ex(x, y)|")
ax2.set_title("|Ey(x, y)|")
ax3.set_title("|Ez(x, y)|")
plt.show()
# Out:
#               WARNING: Use the remote mode solver with subpixel averaging for
#               better accuracy through 'tidy3d.web.run(...)' or the deprecated
#               'tidy3d.plugins.mode.web.run(...)'.
# /tmp/ipykernel_24487/595206881.py:17: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# Submit the simulation job to the server.

# %%
job = web.Job(simulation=sim, task_name="thz_demultiplexer", verbose=True)
sim_data = job.run(path="data/simulation_data.hdf5")
# Out:
# 10:51:33 CEST Created task 'thz_demultiplexer' with task_id
#               'fdve-a8137faf-9765-4ccb-b440-fc5ee1ef2a49' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=105001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8137faf-9765-4ccb-b440-fc5ee1ef2a49\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=524422;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8137faf-9765-4ccb-b440-fc5ee1ef2a49\taskId]8;;\]8;id=105001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8137faf-9765-4ccb-b440-fc5ee1ef2a49\=]8;;\]8;id=13871;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8137faf-9765-4ccb-b440-fc5ee1ef2a49\fdve]8;;\]8;id=105001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8137faf-9765-4ccb-b440-fc5ee1ef2a49\-a8137faf-97]8;;\
#               ]8;id=105001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a8137faf-9765-4ccb-b440-fc5ee1ef2a49\65-4ccb-b440-fc5ee1ef2a49']8;;\.
#               Task folder: ]8;id=366101;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/2.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 100.0% • 2.6/2.6 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:51:36 CEST Maximum FlexCredit cost: 6.759. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:51:37 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 10:51:42 CEST status = preprocess
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# 🏃  Waiting for 'thz_demultiplexer'...
# 🚶  Waiting for 'thz_demultiplexer'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:51:47 CEST starting up solver
#               running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 6.50e-01) ━╺━━━━━━━━━━━━━━━━━━━━━━━━   4% -:--:--
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# solver progress (field decay = 8.23e-02) ━━╺━━━━━━━━━━━━━━━━━━━━━━━   8% 0:07:40
# ...
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/68.2 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━ 0.8% • 0.5/68.2 MB • 17.7 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━ 3.1% • 2.1/68.2 MB • 18.0 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ╸━━━━━━━━━━━━ 4.2% • 2.9/68.2 MB • 11.0 MB/s • 0:00:06
# ↓ simulation_data.hdf5.gz ╸━━━━━━━━━━━━ 6.1% • 4.2/68.2 MB • 11.6 MB/s • 0:00:06
# ↓ simulation_data.hdf5.gz ━╺━━━━━━━━━━━ 8.8% • 6.0/68.2 MB • 12.7 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━╺━━━━━━━━━━ 10.8% • 7.3/68.2 MB • 12.7 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━╸━━━━━━━━━━ 13.2% • 9.0/68.2 MB • 13.1 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━╸━━━━━━━━━━ 16.6% • 11.4/68.2   • 14.1 MB/s • 0:00:05
#                                                MB
# ↓ simulation_data.hdf5.gz ━━╺━━━━━━━━━ 18.9% • 12.9/68.2   • 14.4 MB/s • 0:00:04
#                                                MB
# ↓ simulation_data.hdf5.gz ━━╺━━━━━━━━━ 20.1% • 13.7/68.2   • 13.3 MB/s • 0:00:05
#                                                MB
# ↓ simulation_data.hdf5.gz ━━╸━━━━━━━━━ 22.0% • 15.0/68.2   • 13.3 MB/s • 0:00:04
#                                                MB
# ↓ simulation_data.hdf5.gz ━━╸━━━━━━━━━ 24.7% • 16.9/68.2   • 13.6 MB/s • 0:00:04
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━╺━━━━━━━━ 27.4% • 18.7/68.2   • 13.8 MB/s • 0:00:04
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━╸━━━━━━━━ 30.9% • 21.1/68.2   • 14.6 MB/s • 0:00:04
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━╸━━━━━━━━ 32.8% • 22.4/68.2   • 14.4 MB/s • 0:00:04
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━╺━━━━━━━ 36.2% • 24.7/68.2   • 14.6 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━ 38.2% • 26.0/68.2   • 14.5 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━ 38.9% • 26.6/68.2   • 14.5 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━ 39.7% • 27.1/68.2   • 13.6 MB/s • 0:00:04
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━ 41.6% • 28.4/68.2   • 13.3 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━╸━━━━━━ 46.2% • 31.5/68.2   • 14.1 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━╸━━━━━━ 47.4% • 32.3/68.2   • 13.9 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━╸━━━━━━ 49.3% • 33.6/68.2   • 13.7 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━╺━━━━━ 52.0% • 35.5/68.2   • 13.9 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━╺━━━━━ 53.9% • 36.8/68.2   • 13.7 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━ 56.2% • 38.4/68.2   • 13.7 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━ 57.4% • 39.1/68.2   • 13.6 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 59.3% • 40.5/68.2   • 13.5 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.8% • 41.5/68.2   • 13.3 MB/s • 0:00:03
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 63.5% • 43.3/68.2   • 13.5 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 64.7% • 44.1/68.2   • 13.3 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 67.3% • 46.0/68.2   • 13.4 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 68.5% • 46.7/68.2   • 13.2 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 70.4% • 48.1/68.2   • 13.2 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 72.3% • 49.4/68.2   • 13.2 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 73.9% • 50.4/68.2   • 13.0 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 75.0% • 51.2/68.2   • 12.9 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 76.6% • 52.2/68.2   • 13.0 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 78.1% • 53.3/68.2   • 12.8 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 80.4% • 54.9/68.2   • 12.8 MB/s • 0:00:02
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 81.6% • 55.7/68.2   • 12.8 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 83.5% • 57.0/68.2   • 12.7 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 85.0% • 58.0/68.2   • 12.6 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 86.2% • 58.8/68.2   • 12.4 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 86.9% • 59.3/68.2   • 12.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 87.7% • 59.9/68.2   • 12.2 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.1% • 60.1/68.2   • 11.9 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.1% • 60.1/68.2   • 11.9 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.5% • 60.4/68.2   • 11.6 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.5% • 60.4/68.2   • 11.6 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 88.9% • 60.6/68.2   • 11.3 MB/s • 0:00:01
#                                                MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 60.9/68.2 MB • 8.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.6% • 61.2/68.2 MB • 7.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.6% • 61.2/68.2 MB • 7.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.6% • 61.2/68.2 MB • 7.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.6% • 61.2/68.2 MB • 7.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.6% • 61.2/68.2 MB • 7.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.6% • 61.2/68.2 MB • 7.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.6% • 61.2/68.2 MB • 7.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.0% • 61.4/68.2 MB • 6.4 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.0% • 61.4/68.2 MB • 6.4 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.0% • 61.4/68.2 MB • 6.4 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.0% • 61.4/68.2 MB • 6.4 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.0% • 61.4/68.2 MB • 6.4 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.0% • 61.4/68.2 MB • 6.4 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.4% • 61.7/68.2 MB • 6.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.4% • 61.7/68.2 MB • 6.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.4% • 61.7/68.2 MB • 6.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.4% • 61.7/68.2 MB • 6.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 61.9/68.2 MB • 5.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 61.9/68.2 MB • 5.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 61.9/68.2 MB • 5.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 61.9/68.2 MB • 5.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 61.9/68.2 MB • 5.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 61.9/68.2 MB • 5.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.2% • 62.2/68.2 MB • 5.5 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.2% • 62.2/68.2 MB • 5.5 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.2% • 62.2/68.2 MB • 5.5 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.2% • 62.2/68.2 MB • 5.5 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.2% • 62.2/68.2 MB • 5.5 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.5% • 62.5/68.2 MB • 5.3 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.5% • 62.5/68.2 MB • 5.3 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 91.5% • 62.5/68.2 MB • 5.3 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 91.9% • 62.7/68.2 MB • 5.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 91.9% • 62.7/68.2 MB • 5.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 92.3% • 63.0/68.2 MB • 5.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 92.3% • 63.0/68.2 MB • 5.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 92.7% • 63.3/68.2 MB • 5.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 92.7% • 63.3/68.2 MB • 5.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.1% • 63.5/68.2 MB • 4.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.1% • 63.5/68.2 MB • 4.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.5% • 63.8/68.2 MB • 4.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.5% • 63.8/68.2 MB • 4.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.5% • 63.8/68.2 MB • 4.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.9% • 64.0/68.2 MB • 4.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.9% • 64.0/68.2 MB • 4.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.9% • 64.0/68.2 MB • 4.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 94.2% • 64.3/68.2 MB • 4.7 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 94.2% • 64.3/68.2 MB • 4.7 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 94.6% • 64.6/68.2 MB • 4.6 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.0% • 64.8/68.2 MB • 4.7 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.0% • 64.8/68.2 MB • 4.7 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.4% • 65.1/68.2 MB • 4.6 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.4% • 65.1/68.2 MB • 4.6 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.8% • 65.4/68.2 MB • 4.5 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 96.2% • 65.6/68.2 MB • 4.5 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 96.2% • 65.6/68.2 MB • 4.5 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 96.9% • 66.1/68.2 MB • 4.5 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 96.9% • 66.1/68.2 MB • 4.5 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 97.7% • 66.7/68.2 MB • 4.5 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 97.7% • 66.7/68.2 MB • 4.5 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 98.5% • 67.2/68.2 MB • 4.4 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 98.5% • 67.2/68.2 MB • 4.4 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 99.2% • 67.7/68.2 MB • 4.4 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 99.2% • 67.7/68.2 MB • 4.4 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 99.2% • 67.7/68.2 MB • 4.4 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━ 100.0% • 68.2/68.2   • 4.3 MB/s • 0:00:00
#                                                 MB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:58:35 CEST loading simulation from data/simulation_data.hdf5
#               WARNING: Warning messages were found in the solver log. For more
#               information, check 'SimulationData.log' or use
#               'web.download_log(task_id)'.

# %% [markdown]
# ## Result Visualization

# %% [markdown]
# At 378.8 GHz, the power is transmitted to the through port.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
sim_data.plot_field(
    field_monitor_name="field",
    field_name="E",
    val="abs^2",
    ax=ax,
    f=freq1,
    vmin=0,
    vmax=0.01,
)
plt.show()
# Out:
# /tmp/ipykernel_24487/1037342480.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# At 380.2 GHz, the power is transmitted to the drop port.

# %%
fig = plt.figure()
ax = fig.add_subplot(111)
sim_data.plot_field(
    field_monitor_name="field",
    field_name="E",
    val="abs^2",
    ax=ax,
    f=freq2,
    vmin=0,
    vmax=0.01,
)
plt.show()
# Out:
# /tmp/ipykernel_24487/1869975157.py:12: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# Plot the transmission spectra at the through port and the drop port. A sub 1.5 dB transmission loss as well as a ~3 GHz free spectral range is observed.

# %%
T1 = sim_data["flux1"].flux
T2 = sim_data["flux2"].flux

plt.plot(freqs / 1e9, 10 * np.log10(T1), freqs / 1e9, 10 * np.log10(T2))
plt.xlabel("Frequency (GHz)")
plt.ylabel("Transmission (dB)")
plt.legend(("Through port", "Drop port"))
plt.show()
# Out:
# /tmp/ipykernel_24487/2121407156.py:8: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
