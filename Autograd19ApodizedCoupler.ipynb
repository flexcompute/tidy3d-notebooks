# %% [markdown]
# # Inverse design of an apodized grating coupler through shape optimization
#
# A grating coupler (GC) is a key photonic device used to couple light between optical fibers and on-chip waveguides by diffracting light at a specific angle. These devices often employ apodization, a technique that modifies the grating tooth parameters along the device length to improve efficiency and minimize reflection losses.
#
# In this notebook, we will use gradient-based optimization to determine the optimal grating tooth distribution. We start from a uniform grating coupler and modify the tooth and gap sizes simultaneously using gradient based optimization. Feature size constraints on the parameters enable the device to remain fabricable over the course of optimization. In just a handful of iterations, we achieve a design that outperforms an apodized grating coupler designed using semi-analytical methods.
#
# <img src="img/apodized_grating_feature_image_autograd.png" width=400 alt="Schematic of the coupler">
#
# While the simulations are performed using a 2D cross section, the same approach can be modified to 3D without much further complication.
#
# If you are interested in other inverse design examples using tidy3d, you can find many of them [here](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/docs/features/autograd.html).
#
# If you are unfamiliar with inverse design, we also recommend our [intro to inverse design tutorials](https://www.flexcompute.com/tidy3d/learning-center/inverse-design/) and our [primer on automatic differentiation with tidy3d](https://www.flexcompute.com/tidy3d/examples/notebooks/Autograd1Intro/).

# %%
# as we are using autograd to perform gradient calculations, we need to import numpy from autograd's wrapper
import autograd as ag
import autograd.numpy as np
import matplotlib.pyplot as plt
import tidy3d as td
import tidy3d.web as web

# we will use Tidy3D's built-in Adam helper to perform the optimization
from tidy3d.plugins.autograd import adam, apply_updates

# %% [markdown]
# ### Basic Parameters
#
# First, we define the basic parameters used to define a uniform grating coupler for operation primarily in the C-band.

# %%
lda0 = 1.55  # central wavelength
n_ldas = 101  # number of wavelength points
ldas = np.linspace(1.5, 1.6, n_ldas)  # wavelength range

freq0 = td.C_0 / lda0  # central frequency
freqs = td.C_0 / ldas  # frequency range

num_freqs_objective = 5
ldas_objective = np.linspace(1.5, 1.6, num_freqs_objective)
freqs_objective = td.C_0 / ldas_objective

fwidth = 0.5 * (np.max(freqs) - np.min(freqs))  # width of the source frequency range

# %% [markdown]
# The material platform is the common silicon on insulator (SOI) with a 260 nm silicon thickness and 2 µm BOX thickness. The top cladding layer is 680 nm oxide. The grating will be partially etched with an etching depth of 160 nm.

# %%
# define materials from the material library
si = td.material_library["cSi"]["Palik_Lossless"]
sio2 = td.material_library["SiO2"]["Palik_Lossless"]

t_si = 0.26  # thickness of the silicon layer
etch_depth = 0.16  # etching depth
t_tox = 0.68  # top oxide layer thickness
t_box = 2  # bottom oxide layer thickness

# %% [markdown]
# We aim to design the GC for the standard single-mode fiber (SMF) with a mode field diameter (MFD) of 10.8 µm. The fiber is tilted at a 14.5 degree angle.

# %%
theta = np.deg2rad(14.5)  # fiber tilt angle
mfd = 10.8  # mode field diameter
source_x = 4.5  # x position of the fiber

N = 16  # number of grating teeth to create
inf_eff = 1e3  # effective infinity
buffer = 1.1 * lda0  # buffer spacing to pad the simulation domain

# %% [markdown]
# Next we compute the uniform tooth parameters (periodicity and fill fraction) to maximize efficiency.

# %%
neff_unetch = 2.9  # effective index of the slab mode of the unetched waveguide
neff_etch = 2.2  # effective index of the slab mode of the etched waveguide
n_c = 1.44  # refractive index of the cladding (SiO2)
theta_c = np.sin(theta) / n_c  # incident angle in the cladding


def get_periodicity(fill_fraction: float) -> float:
    """periodicity (bragg condition) as function of fill fraction, angle, wavelength, and etching parameters."""
    return lda0 / (
        fill_fraction * neff_unetch + (1 - fill_fraction) * neff_etch - n_c * np.sin(theta_c)
    )


f0 = 0.80
periodicity = get_periodicity(f0)
p_list = N * [periodicity]
f_list = N * [f0]

# %% [markdown]
# After obtaining $p_{\text{i}}$ and $f_{\text{i}}$, we will write a function to return the width of each air gap and each tooth. We will use these gap widths as the parameters for our design. The advantage is that we can impose bounds on these values to ensure the minimal feature size is above the fabrication constraint.
#
# Here we aim to have a minimal feature size above 60 nm. The current design has a minimal feature size right above it.

# %%
def get_widths(p_list, f_list):
    # calculate the widths of air gaps and silicon teeth
    return np.array([item for p, f in zip(p_list, f_list) for item in [p * (1 - f), p * f]])


widths = get_widths(p_list, f_list)

l_grating = np.sum(widths) + 3 * lda0  # total length of the GC

# print the current minimal feature size
print(f"The minimal feature size is {1e3 * np.min(widths):.2f} nm.")
# Out:
# The minimal feature size is 123.46 nm.

# %% [markdown]
# To ensure the minimal feature size is maintained during the optimization, we will use a design parameter in the range from `-inf` to `inf` and project it to a `tanh` function that is bounded by the minimal and maximal feature sizes.

# %%
min_width = 0.08  # minimal feature size we want to maintain
max_width = 1  # maximal feature size


# function to project a design parameter between -inf to inf to between min_width and max_width
def project(x):
    return 0.5 * (max_width - min_width) * np.tanh(x) + 0.5 * (max_width + min_width)


# function to inversely project a design parameter between min_width and max_width to between -inf to inf
def inverse_project(y):
    return np.arctanh((2 * (y - 0.5 * (max_width + min_width))) / (max_width - min_width))


# project the widths to parameters between -inf to inf
params0 = inverse_project(widths)

# %% [markdown]
# ### Define Static Components of the Simulation
#
# Next we will define the components that don't change during the optimization. These include the cladding layer, the output waveguide, the unetched layer, the bottom oxide layer, and the silicon substrate.

# %%
mask = td.Structure(
    geometry=td.Box(size=(td.inf, td.inf, td.inf), center=(0, 0, 0)),
    medium=td.Medium(),
)

# create the top oxide layer
tox = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, 0), rmax=(inf_eff, inf_eff, t_tox)),
    medium=sio2,
)

# create the output waveguide
slab_waveguide = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, 0), rmax=(0, inf_eff, t_si)),
    medium=si,
)

# create the unetched waveguide
unetched_waveguide = td.Structure(
    geometry=td.Box.from_bounds(rmin=(0, -inf_eff, 0), rmax=(inf_eff, inf_eff, t_si - etch_depth)),
    medium=si,
)

# create the bottom oxide layer
box = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, -t_box), rmax=(inf_eff, inf_eff, 0)),
    medium=sio2,
)

# create the silicon substrate layer
substrate = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-inf_eff, -inf_eff, -inf_eff), rmax=(inf_eff, inf_eff, -t_box)
    ),
    medium=si,
)

# %% [markdown]
# The source and monitor are not changed either. We use a [GaussianBeam](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.GaussianBeam.html#tidy3d.GaussianBeam) to represent the incident fiber mode. A [ModeMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeMonitor.html#tidy3d.ModeMonitor) is placed at the output waveguide to measure the coupling efficiency.

# %%
gap = 1  # gap size between the source plane and the top surface of the cladding

# define a gaussian beam source
source = td.GaussianBeam(
    size=(2 * mfd, td.inf, 0),
    center=[source_x, 0, t_tox + gap],
    source_time=td.GaussianPulse(freq0=freq0, fwidth=fwidth),
    angle_theta=theta,
    direction="-",
    waist_radius=mfd / 2,
    pol_angle=np.pi / 2,  # 90 degree polarization angle for TE polarization
)

# define a mode monitor
mode_monitor = td.ModeMonitor(
    center=(-buffer / 2, 0, t_si / 2),
    size=(0, td.inf, 6 * t_si),
    freqs=freqs,
    mode_spec=td.ModeSpec(num_modes=1, target_neff=3),
    name="mode",
)

# %% [markdown]
# ### Simulate the Designed Apodized GC
#
# To simulate the designed GC and facility future optimization, we define a function that takes in an array of design parameters and returns a [Simulation]() object. Note again that each design parameter has a range from `-inf` to `inf`. It will then be projected to a range between `min_width` and `max_width`.

# %%
def make_2d_sim(design_parameters):
    # calculate the widths of air gaps and silicon teeth
    widths_si = project(design_parameters[1::2])
    widths_air = project(design_parameters[::2])

    # initialize the center and size of each silicon teeth
    center = 0
    size = 0

    # create the grating geometries from the given widths
    gratings = 0
    for width_si, width_air in zip(widths_si, widths_air):
        center += width_air + width_si / 2
        size = width_si
        gratings += td.Box(
            center=(center, 0, t_si - etch_depth / 2), size=(size, td.inf, etch_depth)
        )
        center += width_si / 2

    # create the grating structure
    gratings = td.Structure(geometry=gratings, medium=si)

    # create a box to represent the simulation domain box
    sim_box = td.Box.from_bounds(
        rmin=(-buffer, 0, -t_box - buffer / 2),
        rmax=(l_grating + buffer, 0, t_si + buffer),
    )

    run_time = 1e-12  # simulation run time

    # construct simulation
    sim = td.Simulation(
        center=sim_box.center,
        size=sim_box.size,
        grid_spec=td.GridSpec.auto(
            min_steps_per_wvl=30, wavelength=lda0
        ),  # use a fine grid to ensure the small features are well resolved
        structures=[
            mask,
            tox,
            gratings,
            unetched_waveguide,
            slab_waveguide,
            box,
            substrate,
        ],
        sources=[source],
        monitors=[mode_monitor],
        medium=sio2,
        run_time=run_time,
        boundary_spec=td.BoundarySpec(
            x=td.Boundary.pml(),
            y=td.Boundary.periodic(),  # set the boundary to periodic in y since it's a 2D simulation
            z=td.Boundary.pml(),
        ),
    )

    return sim

# %% [markdown]
# Create the simulation for the designed apodized GC and visualize it.

# %%
sim0 = make_2d_sim(params0)
sim0.plot_eps(y=0, freq=freq0)
plt.show()

# %% [markdown]
# Also visualize the grid to ensure it resolves the small features well.

# %%
ax = sim0.plot(y=0)
sim0.plot_grid(y=0, ax=ax)
ax.set_xlim(-0.1, 1)
ax.set_ylim(0, 0.3)
plt.show()

# %% [markdown]
# Run the simulation.

# %%
sim_data0 = web.run(simulation=sim0, task_name="initial design")
# Out:
# 11:47:54 CET Created task 'initial design' with resource_id
#              'fdve-89378f1c-0222-46f2-a606-8ce3edb045d7' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=817161;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=250818;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\taskId]8;;\]8;id=817161;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\=]8;;\]8;id=384052;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\fdve]8;;\]8;id=817161;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\-89378f1c-022]8;;\
#              ]8;id=817161;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\2-46f2-a606-8ce3edb045d7']8;;\.
#              Task folder: ]8;id=975810;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:48:05 CET Estimated FlexCredit cost: 0.025. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 11:48:06 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 11:48:21 CET status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:48:26 CET starting up solver
# 11:48:27 CET running solver
# Output()
# 11:48:28 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:48:29 CET status = postprocess
# Output()
# 11:48:30 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:48:32 CET View simulation result at
#              ]8;id=69917;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=843683;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\taskId]8;;\]8;id=69917;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\=]8;;\]8;id=395337;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\fdve]8;;\]8;id=69917;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\-89378f1c-022]8;;\
#              ]8;id=69917;https://tidy3d.simulation.cloud/workbench?taskId=fdve-89378f1c-0222-46f2-a606-8ce3edb045d7\2-46f2-a606-8ce3edb045d7']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:48:34 CET Loading results from simulation_data.hdf5

# %% [markdown]
# ### Result Visualization
#
# After the simulation is done, we can extract the coupling efficiency from the mode monitor data. In addition, we also calculate two important metrics: the maximum coupling efficiency and the 1dB bandwidth. The maximal coupling efficiency is about 2.7dB and the 1dB bandwidth is about 36 nm.

# %%
# function to calculate the coupling efficiency from simulation data
def compute_ce(sim_data):
    amp = sim_data["mode"].amps.sel(mode_index=0, direction="-").values
    ce = np.abs(amp) ** 2  # transmission to the top waveguide
    return ce


def dB(ce):
    return 10 * np.log10(ce)


# calculate the coupling efficiency for the designed GC
ce0 = compute_ce(sim_data0)

# plot the coupling efficiency
plt.plot(ldas, dB(ce0), c="red", linewidth=2)
plt.xlim(min(ldas), max(ldas))
plt.ylim(-10, 0)
plt.xlabel("Wavelength (µm)")
plt.ylabel("Coupling efficiency (dB)")
plt.grid()
plt.show()


# function to calculate the 1dB bandwidth from the coupling efficiency
def bandwidth(ldas, ce):
    max_ce = np.max(dB(ce))

    threshold = max_ce - 1

    within_1db = np.where(dB(ce) >= threshold)[0]

    lambda_min = ldas[within_1db[0]]
    lambda_max = ldas[within_1db[-1]]
    bandwidth = lambda_max - lambda_min
    return 1e3 * bandwidth


# print the maximum coupling efficiency and 1dB bandwidth
print(f"The 1dB bandwidth is {bandwidth(ldas, ce0):.1f} nm")
print(f"The maximum coupling efficiency is {np.max(dB(ce0)):.2f} dB.")
# Out:
# The 1dB bandwidth is 36.0 nm
# The maximum coupling efficiency is -2.74 dB.

# %% [markdown]
# ## Optimize GC with Inverse Design to Maximize the Efficiency and Bandwidth
#
# In this part, we will apply inverse design to maximize the coupling efficiency of our coupling over the wavelength range from 1500 to 1600 nm.
#
# To do this, we need to express our objective as a function of our parameters returning a single float value to maximize. This function will involve constructing, running, and postprocessing our simulation.

# %%
def J(design_parameters: np.ndarray) -> float:
    sim = make_2d_sim(design_parameters)
    sim_data = web.run(sim, task_name="GC_invdes", verbose=True)
    ce = np.sum(compute_ce(sim_data)) / n_ldas

    return ce

# %%
dJ = ag.value_and_grad(J)

# %% [markdown]
# Before running the optimization, we can check the value and gradient of the initial design to ensure the gradient tracking is working properly.

# %%
# %%time

val, grad = dJ(params0)
print(val)
print(grad)
# Out:
# 11:48:35 CET Created task 'GC_invdes' with resource_id
#              'fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=183388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=170080;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\taskId]8;;\]8;id=183388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\=]8;;\]8;id=982454;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\fdve]8;;\]8;id=183388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\-62db3366-15f]8;;\
#              ]8;id=183388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\6-4a4b-b4d5-c62b0c7f80e8']8;;\.
#              Task folder: ]8;id=8930;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:48:47 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:49:04 CET starting up solver
# 11:49:05 CET running solver
# Output()
# 11:49:09 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 11:49:13 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:49:15 CET View simulation result at
#              ]8;id=499384;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=672920;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\taskId]8;;\]8;id=499384;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\=]8;;\]8;id=951748;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\fdve]8;;\]8;id=499384;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\-62db3366-15f]8;;\
#              ]8;id=499384;https://tidy3d.simulation.cloud/workbench?taskId=fdve-62db3366-15f6-4a4b-b4d5-c62b0c7f80e8\6-4a4b-b4d5-c62b0c7f80e8']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:49:17 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 11:49:38 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 11:50:03 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.3390469934847685
# [ 0.01941106  0.00920596  0.02057389  0.01266693  0.01664433  0.04694646
#   0.0194907   0.09558201  0.01487506  0.13836691  0.01636642  0.14910505
#   0.01308024  0.12759988  0.00347015  0.10190452  0.00803321  0.07482931
#  -0.00318004  0.02526351  0.00254178  0.01946836 -0.00134298 -0.02017489
#  -0.00106406 -0.03206085  0.00057714 -0.03410951 -0.00018506 -0.03428794
#  -0.00034914 -0.02485857]
# CPU times: user 1.75 s, sys: 140 ms, total: 1.9 s
# Wall time: 1min 29s

# %% [markdown]
# We will use the Adam optimizer to adjust the parameters for a number of iterations until we achieve a good performance.

# %%
# %%time

# hyperparameters
num_steps = 25
learning_rate = 0.05

# initialize adam optimizer with starting parameters
params = params0
optimizer = adam(learning_rate=learning_rate)
opt_state = optimizer.init(params)

# store history
J_history = []
params_history = []

for i in range(num_steps):
    # compute gradient and current objective function value
    value, gradient = dJ(params)

    # outputs
    print(f"step = {i + 1}")
    print(f"\tJ = {value:.3e}")
    print(f"\tgrad_norm = {np.linalg.norm(gradient):.4e}")

    # compute and apply updates to the optimizer based on gradient (-1 sign to maximize obj_fn)
    updates, opt_state = optimizer.update(-gradient, opt_state, params)
    params[:] = apply_updates(params, updates)

    # save history
    J_history.append(value)
    params_history.append(params.copy())
# Out:
# 11:50:04 CET Created task 'GC_invdes' with resource_id
#              'fdve-73a863e9-779f-49f0-b7f6-c928b9014d9c' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=847804;https://tidy3d.simulation.cloud/workbench?taskId=fdve-73a863e9-779f-49f0-b7f6-c928b9014d9c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=652064;https://tidy3d.simulation.cloud/workbench?taskId=fdve-73a863e9-779f-49f0-b7f6-c928b9014d9c\taskId]8;;\]8;id=847804;https://tidy3d.simulation.cloud/workbench?taskId=fdve-73a863e9-779f-49f0-b7f6-c928b9014d9c\=]8;;\]8;id=965592;https://tidy3d.simulation.cloud/workbench?taskId=fdve-73a863e9-779f-49f0-b7f6-c928b9014d9c\fdve]8;;\]8;id=847804;https://tidy3d.simulation.cloud/workbench?taskId=fdve-73a863e9-779f-49f0-b7f6-c928b9014d9c\-73a863e9-779]8;;\
#              ]8;id=847804;https://tidy3d.simulation.cloud/workbench?taskId=fdve-73a863e9-779f-49f0-b7f6-c928b9014d9c\f-49f0-b7f6-c928b9014d9c']8;;\.
#              Task folder: ]8;id=915217;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:50:20 CET status = success
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:50:22 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 11:50:44 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 11:50:45 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 1
# 	J = 3.390e-01
# 	grad_norm = 3.0472e-01
# 11:50:46 CET Created task 'GC_invdes' with resource_id
#              'fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=198408;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=653656;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\taskId]8;;\]8;id=198408;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\=]8;;\]8;id=285161;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\fdve]8;;\]8;id=198408;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\-57bf6eda-9d6]8;;\
#              ]8;id=198408;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\b-4311-8194-5b070099e3a0']8;;\.
#              Task folder: ]8;id=702915;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:51:02 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:51:24 CET starting up solver
# 11:51:25 CET running solver
# Output()
# 11:51:29 CET early shutoff detected at 46%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 11:51:35 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:51:37 CET View simulation result at
#              ]8;id=135531;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=834544;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\taskId]8;;\]8;id=135531;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\=]8;;\]8;id=519740;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\fdve]8;;\]8;id=135531;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\-57bf6eda-9d6]8;;\
#              ]8;id=135531;https://tidy3d.simulation.cloud/workbench?taskId=fdve-57bf6eda-9d6b-4311-8194-5b070099e3a0\b-4311-8194-5b070099e3a0']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:51:39 CET Loading results from simulation_data.hdf5
# 11:51:40 CET Started working on Batch containing 1 tasks.
# 11:52:04 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 11:52:20 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 2
# 	J = 2.285e-01
# 	grad_norm = 2.9688e+00
# 11:52:21 CET Created task 'GC_invdes' with resource_id
#              'fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=178857;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=709298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\taskId]8;;\]8;id=178857;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\=]8;;\]8;id=804199;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\fdve]8;;\]8;id=178857;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\-4be58d84-5bd]8;;\
#              ]8;id=178857;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\8-4980-ae90-5214e0ed5679']8;;\.
#              Task folder: ]8;id=865365;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:52:34 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 11:52:46 CET status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:52:51 CET starting up solver
# 11:52:52 CET running solver
# Output()
# 11:52:58 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 11:53:04 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:53:06 CET View simulation result at
#              ]8;id=970425;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=338166;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\taskId]8;;\]8;id=970425;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\=]8;;\]8;id=884885;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\fdve]8;;\]8;id=970425;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\-4be58d84-5bd]8;;\
#              ]8;id=970425;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4be58d84-5bd8-4980-ae90-5214e0ed5679\8-4980-ae90-5214e0ed5679']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:53:09 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 11:53:33 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 11:54:22 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 3
# 	J = 3.300e-01
# 	grad_norm = 9.5898e-01
# 11:54:23 CET Created task 'GC_invdes' with resource_id
#              'fdve-e231a917-fe4e-40f0-bf21-b4f769963240' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=426500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=354342;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\taskId]8;;\]8;id=426500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\=]8;;\]8;id=611194;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\fdve]8;;\]8;id=426500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\-e231a917-fe4]8;;\
#              ]8;id=426500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\e-40f0-bf21-b4f769963240']8;;\.
#              Task folder: ]8;id=680732;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:54:38 CET status = queued
# 11:54:39 CET To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:54:56 CET starting up solver
#              running solver
# Output()
# 11:55:00 CET early shutoff detected at 49%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 11:55:04 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:55:06 CET View simulation result at
#              ]8;id=790715;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=912285;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\taskId]8;;\]8;id=790715;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\=]8;;\]8;id=730617;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\fdve]8;;\]8;id=790715;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\-e231a917-fe4]8;;\
#              ]8;id=790715;https://tidy3d.simulation.cloud/workbench?taskId=fdve-e231a917-fe4e-40f0-bf21-b4f769963240\e-40f0-bf21-b4f769963240']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:55:08 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 11:55:28 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 11:56:26 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 4
# 	J = 2.917e-01
# 	grad_norm = 2.8230e+00
# 11:56:27 CET Created task 'GC_invdes' with resource_id
#              'fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=97500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=261466;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\taskId]8;;\]8;id=97500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\=]8;;\]8;id=571459;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\fdve]8;;\]8;id=97500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\-afad6c5f-aab]8;;\
#              ]8;id=97500;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\d-4005-b183-a1aa991cd2f7']8;;\.
#              Task folder: ]8;id=492479;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:56:41 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:56:58 CET starting up solver
#              running solver
# Output()
# 11:57:02 CET early shutoff detected at 49%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:57:03 CET status = postprocess
# Output()
# 11:57:09 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:57:11 CET View simulation result at
#              ]8;id=808409;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=750467;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\taskId]8;;\]8;id=808409;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\=]8;;\]8;id=768479;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\fdve]8;;\]8;id=808409;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\-afad6c5f-aab]8;;\
#              ]8;id=808409;https://tidy3d.simulation.cloud/workbench?taskId=fdve-afad6c5f-aabd-4005-b183-a1aa991cd2f7\d-4005-b183-a1aa991cd2f7']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:57:13 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 11:57:33 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 11:58:22 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 5
# 	J = 2.801e-01
# 	grad_norm = 2.3209e+00
# 11:58:24 CET Created task 'GC_invdes' with resource_id
#              'fdve-f05447f9-306f-4792-aa53-662f2b384ab7' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=542530;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=665690;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\taskId]8;;\]8;id=542530;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\=]8;;\]8;id=743632;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\fdve]8;;\]8;id=542530;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\-f05447f9-306]8;;\
#              ]8;id=542530;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\f-4792-aa53-662f2b384ab7']8;;\.
#              Task folder: ]8;id=230060;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:58:40 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:58:54 CET starting up solver
# 11:58:55 CET running solver
# Output()
# 11:58:59 CET early shutoff detected at 48%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 11:59:05 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:59:07 CET View simulation result at
#              ]8;id=286273;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=698874;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\taskId]8;;\]8;id=286273;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\=]8;;\]8;id=119478;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\fdve]8;;\]8;id=286273;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\-f05447f9-306]8;;\
#              ]8;id=286273;https://tidy3d.simulation.cloud/workbench?taskId=fdve-f05447f9-306f-4792-aa53-662f2b384ab7\f-4792-aa53-662f2b384ab7']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 11:59:09 CET Loading results from simulation_data.hdf5
# 11:59:10 CET Started working on Batch containing 1 tasks.
# 11:59:32 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:00:05 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 6
# 	J = 2.970e-01
# 	grad_norm = 6.0586e-01
# 12:00:07 CET Created task 'GC_invdes' with resource_id
#              'fdve-06395960-5f33-4b63-97d7-3c9add4a4c70' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=52084;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=904398;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\taskId]8;;\]8;id=52084;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\=]8;;\]8;id=8218;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\fdve]8;;\]8;id=52084;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\-06395960-5f3]8;;\
#              ]8;id=52084;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\3-4b63-97d7-3c9add4a4c70']8;;\.
#              Task folder: ]8;id=455147;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:00:23 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 12:00:35 CET status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:00:40 CET starting up solver
#              running solver
# Output()
# 12:00:42 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:00:43 CET status = postprocess
# Output()
# 12:00:49 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:00:51 CET View simulation result at
#              ]8;id=727694;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=359640;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\taskId]8;;\]8;id=727694;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\=]8;;\]8;id=740467;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\fdve]8;;\]8;id=727694;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\-06395960-5f3]8;;\
#              ]8;id=727694;https://tidy3d.simulation.cloud/workbench?taskId=fdve-06395960-5f33-4b63-97d7-3c9add4a4c70\3-4b63-97d7-3c9add4a4c70']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:00:53 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 12:01:15 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:01:48 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 7
# 	J = 3.044e-01
# 	grad_norm = 1.1521e+00
# 12:01:49 CET Created task 'GC_invdes' with resource_id
#              'fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=768774;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=62855;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\taskId]8;;\]8;id=768774;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\=]8;;\]8;id=979971;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\fdve]8;;\]8;id=768774;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\-fa8e89ca-3ba]8;;\
#              ]8;id=768774;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\1-4561-bbe6-5695611e14dc']8;;\.
#              Task folder: ]8;id=241997;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:02:02 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:02:22 CET starting up solver
#              running solver
# Output()
# 12:02:26 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:02:27 CET status = postprocess
# Output()
# 12:02:30 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:02:32 CET View simulation result at
#              ]8;id=426000;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=143692;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\taskId]8;;\]8;id=426000;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\=]8;;\]8;id=212621;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\fdve]8;;\]8;id=426000;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\-fa8e89ca-3ba]8;;\
#              ]8;id=426000;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fa8e89ca-3ba1-4561-bbe6-5695611e14dc\1-4561-bbe6-5695611e14dc']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:02:34 CET Loading results from simulation_data.hdf5
# 12:02:35 CET Started working on Batch containing 1 tasks.
# 12:02:54 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:03:41 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 8
# 	J = 2.986e-01
# 	grad_norm = 1.7401e+00
# 12:03:42 CET Created task 'GC_invdes' with resource_id
#              'fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=1611;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=794902;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\taskId]8;;\]8;id=1611;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\=]8;;\]8;id=278108;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\fdve]8;;\]8;id=1611;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\-7ca2c39f-aea]8;;\
#              ]8;id=1611;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\d-4083-b1c5-9b8d8f0eaa68']8;;\.
#              Task folder: ]8;id=202462;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:03:55 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:04:17 CET starting up solver
# 12:04:18 CET running solver
# Output()
# 12:04:22 CET early shutoff detected at 48%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 12:04:28 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:04:30 CET View simulation result at
#              ]8;id=254868;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=486304;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\taskId]8;;\]8;id=254868;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\=]8;;\]8;id=35791;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\fdve]8;;\]8;id=254868;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\-7ca2c39f-aea]8;;\
#              ]8;id=254868;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7ca2c39f-aead-4083-b1c5-9b8d8f0eaa68\d-4083-b1c5-9b8d8f0eaa68']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:04:32 CET Loading results from simulation_data.hdf5
# 12:04:33 CET Started working on Batch containing 1 tasks.
# 12:04:52 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:05:36 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 9
# 	J = 3.082e-01
# 	grad_norm = 1.2892e+00
# 12:05:37 CET Created task 'GC_invdes' with resource_id
#              'fdve-aa39d048-8619-472e-9c1a-dc901b191272' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=139914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=223248;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\taskId]8;;\]8;id=139914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\=]8;;\]8;id=253843;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\fdve]8;;\]8;id=139914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\-aa39d048-861]8;;\
#              ]8;id=139914;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\9-472e-9c1a-dc901b191272']8;;\.
#              Task folder: ]8;id=797550;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:05:50 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 12:06:00 CET status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:06:05 CET starting up solver
#              running solver
# Output()
# 12:06:09 CET early shutoff detected at 48%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:06:10 CET status = postprocess
# Output()
# 12:06:13 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:06:15 CET View simulation result at
#              ]8;id=3554;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=181632;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\taskId]8;;\]8;id=3554;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\=]8;;\]8;id=903391;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\fdve]8;;\]8;id=3554;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\-aa39d048-861]8;;\
#              ]8;id=3554;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aa39d048-8619-472e-9c1a-dc901b191272\9-472e-9c1a-dc901b191272']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:06:17 CET Loading results from simulation_data.hdf5
# 12:06:18 CET Started working on Batch containing 1 tasks.
# 12:06:38 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:07:44 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 10
# 	J = 3.130e-01
# 	grad_norm = 1.4992e-01
# 12:07:45 CET Created task 'GC_invdes' with resource_id
#              'fdve-1656896d-c0af-4f20-8c78-1af2a22bad83' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=935001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=225980;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\taskId]8;;\]8;id=935001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\=]8;;\]8;id=871336;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\fdve]8;;\]8;id=935001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\-1656896d-c0a]8;;\
#              ]8;id=935001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\f-4f20-8c78-1af2a22bad83']8;;\.
#              Task folder: ]8;id=27858;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:07:58 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:08:15 CET starting up solver
# 12:08:16 CET running solver
# Output()
# 12:08:20 CET early shutoff detected at 49%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 12:08:26 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:08:28 CET View simulation result at
#              ]8;id=792870;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=766640;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\taskId]8;;\]8;id=792870;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\=]8;;\]8;id=332584;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\fdve]8;;\]8;id=792870;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\-1656896d-c0a]8;;\
#              ]8;id=792870;https://tidy3d.simulation.cloud/workbench?taskId=fdve-1656896d-c0af-4f20-8c78-1af2a22bad83\f-4f20-8c78-1af2a22bad83']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:08:30 CET Loading results from simulation_data.hdf5
# 12:08:31 CET Started working on Batch containing 1 tasks.
# 12:08:50 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:09:39 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 11
# 	J = 2.978e-01
# 	grad_norm = 1.1736e+00
# 12:09:41 CET Created task 'GC_invdes' with resource_id
#              'fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=350650;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=133843;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\taskId]8;;\]8;id=350650;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\=]8;;\]8;id=760720;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\fdve]8;;\]8;id=350650;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\-cdf6535f-b49]8;;\
#              ]8;id=350650;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\0-443e-b6dd-7217ea2a42b0']8;;\.
#              Task folder: ]8;id=168019;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:09:54 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 12:10:28 CET status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:10:33 CET starting up solver
#              running solver
# Output()
# 12:10:37 CET early shutoff detected at 49%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:10:38 CET status = postprocess
# Output()
# 12:10:44 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:10:46 CET View simulation result at
#              ]8;id=216721;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=869206;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\taskId]8;;\]8;id=216721;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\=]8;;\]8;id=603806;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\fdve]8;;\]8;id=216721;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\-cdf6535f-b49]8;;\
#              ]8;id=216721;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cdf6535f-b490-443e-b6dd-7217ea2a42b0\0-443e-b6dd-7217ea2a42b0']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:10:48 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 12:11:08 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:11:50 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 12
# 	J = 2.925e-01
# 	grad_norm = 1.6056e+00
# 12:11:52 CET Created task 'GC_invdes' with resource_id
#              'fdve-dc8b5d2e-55d6-464c-85c2-136e17c14942' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=455815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc8b5d2e-55d6-464c-85c2-136e17c14942\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=922827;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc8b5d2e-55d6-464c-85c2-136e17c14942\taskId]8;;\]8;id=455815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc8b5d2e-55d6-464c-85c2-136e17c14942\=]8;;\]8;id=880439;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc8b5d2e-55d6-464c-85c2-136e17c14942\fdve]8;;\]8;id=455815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc8b5d2e-55d6-464c-85c2-136e17c14942\-dc8b5d2e-55d]8;;\
#              ]8;id=455815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-dc8b5d2e-55d6-464c-85c2-136e17c14942\6-464c-85c2-136e17c14942']8;;\.
# ...
#              ]8;id=483394;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=192131;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\taskId]8;;\]8;id=483394;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\=]8;;\]8;id=82933;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\fdve]8;;\]8;id=483394;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\-bcb1b38c-7ca]8;;\
#              ]8;id=483394;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\d-4ecd-85e3-bdf05086fbb5']8;;\.
#              Task folder: ]8;id=691958;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:29:35 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:29:49 CET starting up solver
# 12:29:50 CET running solver
# Output()
# 12:29:54 CET early shutoff detected at 48%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 12:30:00 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:30:02 CET View simulation result at
#              ]8;id=186653;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=970498;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\taskId]8;;\]8;id=186653;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\=]8;;\]8;id=635537;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\fdve]8;;\]8;id=186653;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\-bcb1b38c-7ca]8;;\
#              ]8;id=186653;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bcb1b38c-7cad-4ecd-85e3-bdf05086fbb5\d-4ecd-85e3-bdf05086fbb5']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:30:05 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 12:30:24 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:30:59 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 22
# 	J = 2.809e-01
# 	grad_norm = 5.7377e-01
# 12:31:00 CET Created task 'GC_invdes' with resource_id
#              'fdve-5984398e-b68a-451b-abf2-6419d08c5f60' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=257496;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=921107;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\taskId]8;;\]8;id=257496;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\=]8;;\]8;id=666776;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\fdve]8;;\]8;id=257496;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\-5984398e-b68]8;;\
#              ]8;id=257496;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\a-451b-abf2-6419d08c5f60']8;;\.
#              Task folder: ]8;id=405007;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:31:14 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:35:35 CET starting up solver
#              running solver
# Output()
# 12:35:39 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:35:40 CET status = postprocess
# Output()
# 12:35:43 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:35:45 CET View simulation result at
#              ]8;id=642718;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=877498;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\taskId]8;;\]8;id=642718;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\=]8;;\]8;id=343461;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\fdve]8;;\]8;id=642718;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\-5984398e-b68]8;;\
#              ]8;id=642718;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5984398e-b68a-451b-abf2-6419d08c5f60\a-451b-abf2-6419d08c5f60']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:35:48 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 12:36:10 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:37:09 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 23
# 	J = 2.824e-01
# 	grad_norm = 3.3221e-01
# 12:37:11 CET Created task 'GC_invdes' with resource_id
#              'fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=377663;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=527230;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\taskId]8;;\]8;id=377663;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\=]8;;\]8;id=245022;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\fdve]8;;\]8;id=377663;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\-4c79ccd8-db5]8;;\
#              ]8;id=377663;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\b-453f-bf22-69254ebc7207']8;;\.
#              Task folder: ]8;id=376224;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:37:24 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:37:38 CET starting up solver
# 12:37:39 CET running solver
# Output()
# 12:37:43 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 12:37:49 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:37:51 CET View simulation result at
#              ]8;id=446701;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=215594;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\taskId]8;;\]8;id=446701;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\=]8;;\]8;id=815598;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\fdve]8;;\]8;id=446701;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\-4c79ccd8-db5]8;;\
#              ]8;id=446701;https://tidy3d.simulation.cloud/workbench?taskId=fdve-4c79ccd8-db5b-453f-bf22-69254ebc7207\b-453f-bf22-69254ebc7207']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:37:54 CET Loading results from simulation_data.hdf5
#              Started working on Batch containing 1 tasks.
# 12:38:14 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:38:45 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 24
# 	J = 2.863e-01
# 	grad_norm = 8.4776e-01
# 12:38:47 CET Created task 'GC_invdes' with resource_id
#              'fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=835437;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=139639;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\taskId]8;;\]8;id=835437;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\=]8;;\]8;id=972050;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\fdve]8;;\]8;id=835437;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\-c444daa0-a14]8;;\
#              ]8;id=835437;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\0-4e88-a7ae-ddb7eb4da63c']8;;\.
#              Task folder: ]8;id=641390;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:39:00 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:39:14 CET starting up solver
# 12:39:15 CET running solver
# Output()
# 12:39:19 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = postprocess
# Output()
# 12:39:25 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:39:27 CET View simulation result at
#              ]8;id=327724;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=801863;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\taskId]8;;\]8;id=327724;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\=]8;;\]8;id=21221;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\fdve]8;;\]8;id=327724;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\-c444daa0-a14]8;;\
#              ]8;id=327724;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c444daa0-a140-4e88-a7ae-ddb7eb4da63c\0-4e88-a7ae-ddb7eb4da63c']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:39:29 CET Loading results from simulation_data.hdf5
# 12:39:30 CET Started working on Batch containing 1 tasks.
# 12:39:49 CET Maximum FlexCredit cost: 0.025 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#              completion.
# Output()
# 12:40:18 CET Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 25
# 	J = 2.907e-01
# 	grad_norm = 8.9055e-01
# CPU times: user 59 s, sys: 3.41 s, total: 1min 2s
# Wall time: 50min 15s

# %% [markdown]
# Plot the objective function (average coupling efficiency) as a function of the number of iterations. A steady increase of the average coupling efficiency is observed.

# %%
plt.plot(J_history, c="black")
plt.xlabel("Iterations")
plt.ylabel("Objective function (average coupling efficiency)")
plt.show()

# %% [markdown]
# ### Design the Apodized GC
#
# For comparison with more established methods, we'll simulate a device designed using the approach introduced in the reference [paper](https://doi.org/10.1038/s41598-017-16505-z). First of all, the Bragg condition is given by
#
# $$
# p_{\text{i}} = \frac{\lambda_\text{c}}{(n_{\text{eff,i}} - n_{\text{c}}\sin \theta_{\text{c}})},
# $$
#
# where $p_{\text{i}}$ is the local period of the grating, $\lambda_\text{c}$ is the central wavelength, $n_{\text{c}}$ is the refractive index of the cladding, $\theta_{\text{c}}$ is the incident angle in the cladding (~ 10 degrees from Snell's law), and
#
# $$
# n_{\text{eff,i}} = f_\text{i} \times n_\text{neff,nonetch} + (1-f_\text{i}) \times n_\text{neff,etch}.
# $$
#
# Here $f_\text{i}$ is the local filling fraction, $n_\text{neff,unetch}$ is the effective index of the slab mode of the unetched waveguide (260 nm thick), and $n_\text{neff,etch}$ is the effective index of the slab mode of the etched waveguide (100 nm thick). $n_\text{neff,unetch}$ and $n_\text{neff,etch}$ are determined to be about 2.9 and 2.2 by mode analysis (not shown). Furthermore, we follow a linear apodization, namely
#
# $$
# f_\text{i} = f_\text{0} - R \times x,
# $$
#
# where $f_\text{0}$ is the filling fraction of the first period, $R$ is the linear apodization factor and $x$ is the position of each tooth from the starting point of the grating. By using an initial local filling fraction $f_\text{0}$=0.9 and apodization factor $R$=0.0025 µm$^{-1}$ we can recursively calculate $p_{\text{i}}$ and $f_\text{i}$ for $i=0, 1, ..., N-1$ using the equations above. The result is a grating with apodized pitch length and filling fraction.
#
# For more details on the design principles, refer to the reference [paper](https://doi.org/10.1038/s41598-017-16505-z).

# %%
# and then the apodized design parameters to compare to later

R = 0.025  # linear apodization factor

p_list_apodized = []  # list to store all local periodicities
f_list_apodized = []  # list to store all local filling fractions

f0_apodized = 0.86  # filling fraction of the first teeth
f_current = f0_apodized  # variable to store the current local filling fraction

# recursively calculate all local periodicities and filling fractions
for i in range(N):
    p_current = get_periodicity(f_current)
    p_list_apodized.append(p_current)
    f_list_apodized.append(f_current)
    f_current = f0_apodized - R * sum(p_list_apodized)

widths_apodized = get_widths(p_list_apodized, f_list_apodized)
params_apodized = inverse_project(widths_apodized)
sim_apodized = make_2d_sim(params_apodized)

# %% [markdown]
# Let's plot all of the simulations together to see how their features compare.

# %%
params_opt = params_history[-1]
sim_opt = make_2d_sim(params_opt)

f, (ax1, ax2, ax3) = plt.subplots(3, 1, tight_layout=True, figsize=(10, 6))

sim0.plot_eps(y=0, freq=freq0, ax=ax1)
sim_apodized.plot_eps(y=0, freq=freq0, ax=ax2)
sim_opt.plot_eps(y=0, freq=freq0, ax=ax3)

ax1.set_title("uniform")
ax2.set_title("apodized")
ax3.set_title("optimized")


plt.show()

# %% [markdown]
# Next, we'll run each of the designs to be able to compare the coupling efficiencies directly.

# %%
sim_data_apodized = web.run(simulation=sim_apodized, task_name="apodized design")
sim_data_opt = web.run(simulation=sim_opt, task_name="optimized design")
# Out:
# 12:40:21 CET Created task 'apodized design' with resource_id
#              'fdve-845a785b-46cc-462e-9712-5cfd29383e92' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=601825;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=850381;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\taskId]8;;\]8;id=601825;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\=]8;;\]8;id=394353;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\fdve]8;;\]8;id=601825;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\-845a785b-46c]8;;\
#              ]8;id=601825;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\c-462e-9712-5cfd29383e92']8;;\.
#              Task folder: ]8;id=868248;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:40:31 CET Estimated FlexCredit cost: 0.025. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 12:40:32 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:40:44 CET starting up solver
# 12:40:45 CET running solver
# Output()
# 12:40:49 CET early shutoff detected at 42%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              View simulation result at
#              ]8;id=51269;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=754765;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\taskId]8;;\]8;id=51269;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\=]8;;\]8;id=505182;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\fdve]8;;\]8;id=51269;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\-845a785b-46c]8;;\
#              ]8;id=51269;https://tidy3d.simulation.cloud/workbench?taskId=fdve-845a785b-46cc-462e-9712-5cfd29383e92\c-462e-9712-5cfd29383e92']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:40:51 CET Loading results from simulation_data.hdf5
#              Created task 'optimized design' with resource_id
#              'fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=709749;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=791582;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\taskId]8;;\]8;id=709749;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\=]8;;\]8;id=345316;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\fdve]8;;\]8;id=709749;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\-cd22e844-66c]8;;\
#              ]8;id=709749;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\b-4ceb-9c60-fca21c8f8b9e']8;;\.
#              Task folder: ]8;id=786565;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:41:01 CET Estimated FlexCredit cost: 0.025. Minimum cost depends on task
#              execution details. Use 'web.real_cost(task_id)' to get the billed
#              FlexCredit cost after a simulation run.
# 12:41:03 CET status = queued
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:41:18 CET starting up solver
#              running solver
# Output()
# 12:41:22 CET early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:41:23 CET status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#              View simulation result at
#              ]8;id=116292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=518428;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\taskId]8;;\]8;id=116292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\=]8;;\]8;id=190075;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\fdve]8;;\]8;id=116292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\-cd22e844-66c]8;;\
#              ]8;id=116292;https://tidy3d.simulation.cloud/workbench?taskId=fdve-cd22e844-66cb-4ceb-9c60-fca21c8f8b9e\b-4ceb-9c60-fca21c8f8b9e']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:41:25 CET Loading results from simulation_data.hdf5

# %%
ce_opt = compute_ce(sim_data_opt)
ce_apodized = compute_ce(sim_data_apodized)

plt.plot(ldas, dB(ce0), c="red", linewidth=2, label="Initial design")
plt.plot(ldas, dB(ce_apodized), c="orange", linewidth=2, label="Apodized design")
plt.plot(ldas, dB(ce_opt), c="blue", linewidth=2, label="Optimized design")
plt.xlim(min(ldas), max(ldas))
plt.ylim(-10, 0)
plt.xlabel("Wavelength (µm)")
plt.ylabel("Coupling efficiency (dB)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# We see that the optimized and apodized designs both exceed that of the uniform with -2dB efficiency. However, the optimized design far outperforms in terms of bandwidth. We can also confirm that the minimal feature size is maintained above 85 nm.

# %%
print("Uniform:")
print(f"  The 1dB bandwidth is {bandwidth(ldas, ce0):.1f} nm")
print(f"  The maximum coupling efficiency is {np.max(dB(ce0)):.2f} dB.")
print(f"  The minimal feature size is {1e3 * np.min(project(params0)):.2f} nm.")
print("")
print("Apodized:")
print(f"  The 1dB bandwidth is {bandwidth(ldas, ce_apodized):.1f} nm")
print(f"  The maximum coupling efficiency is {np.max(dB(ce_apodized)):.2f} dB.")
print(f"  The minimal feature size is {1e3 * np.min(project(params_apodized)):.2f} nm.")
print("")
print("Optimized:")
print(f"  The 1dB bandwidth is {bandwidth(ldas, ce_opt):.1f} nm")
print(f"  The maximum coupling efficiency is {np.max(dB(ce_opt)):.2f} dB.")
print(f"  The minimal feature size is {1e3 * np.min(project(params_opt)):.2f} nm.")
# Out:
# Uniform:
#   The 1dB bandwidth is 36.0 nm
#   The maximum coupling efficiency is -2.74 dB.
#   The minimal feature size is 116.32 nm.
#
# Apodized:
#   The 1dB bandwidth is 43.0 nm
#   The maximum coupling efficiency is -1.99 dB.
#   The minimal feature size is 85.00 nm.
#
# Optimized:
#   The 1dB bandwidth is 37.0 nm
#   The maximum coupling efficiency is -3.34 dB.
#   The minimal feature size is 116.32 nm.

# %% [markdown]
# ## Take the Model Further
#
#
# In this notebook, we only perform 2D simulations. A good next step would be to convert the 2D design to a 3D linear GC or focusing GC. The coupling efficiency of the 3D GC is likely slightly lower than that in 2D. Inverse design can then be applied to fine-tune it again. To minimize the footprint, one can potentially also apply shape optimization to design a compact and low-loss taper section, as demonstrated in this [example](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/Autograd5BoundaryGradients.html).
#
# ### Further visualizations
#
# In case you would like to gain more insight into how your device has changed over optimization, the following are a few post-processing steps to make animations and visualize the grating teeth locations.

# %%
import matplotlib.animation as animation
from IPython.display import HTML

fig, ax = plt.subplots(1, 1, tight_layout=True, figsize=(10, 3))

sim0 = make_2d_sim(params_history[0])


def plot_fn(params, ax=ax):
    sim = make_2d_sim(params)
    ax = sim.plot_eps(y=0.0, ax=ax, freq=freq0)
    ax.set_aspect("equal")


def animate(i):
    plot_fn(params_history[i])


# create animation
ani = animation.FuncAnimation(fig, animate, frames=len(params_history))
plt.close()

# %%
td.config.logging.level = "ERROR"

# display the animation (press "play" to start)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_imgb5e4333e954c4761a3e612d7fbcd46e8">
#   <div class="anim-controls">
#     <input id="_anim_sliderb5e4333e954c4761a3e612d7fbcd46e8" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="animb5e4333e954c4761a3e612d7fbcd46e8.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="animb5e4333e954c4761a3e612d7fbcd46e8.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_selectb5e4333e954c4761a3e612d7fbcd46e8"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_b5e4333e954c4761a3e612d7fbcd46e8"
#              >
#       <label for="_anim_radio1_b5e4333e954c4761a3e612d7fbcd46e8">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_b5e4333e954c4761a3e612d7fbcd46e8"
#              checked>
#       <label for="_anim_radio2_b5e4333e954c4761a3e612d7fbcd46e8">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_b5e4333e954c4761a3e612d7fbcd46e8"
#              >
#       <label for="_anim_radio3_b5e4333e954c4761a3e612d7fbcd46e8">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_imgb5e4333e954c4761a3e612d7fbcd46e8";
#     var slider_id = "_anim_sliderb5e4333e954c4761a3e612d7fbcd46e8";
#     var loop_select_id = "_anim_loop_selectb5e4333e954c4761a3e612d7fbcd46e8";
#     var frames = new Array(25);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjgsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvwVt1zgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAYM5JR

# %%
# uncomment to save to file
# ani.save("/users/twhughes/Desktop/apodized_grating_coupler.gif", fps=10)

# %%
history_min = [[] for _ in range(len(params_history))]
history_max = [[] for _ in range(len(params_history))]

for i, params in enumerate(params_history):
    sim = make_2d_sim(params)
    for geometry in sim.structures[2].geometry.geometries:
        (xmin, _, _), (xmax, _, _) = geometry.bounds
        history_min[i].append(xmin)
        history_max[i].append(xmax)
        # print(i, j)

history_min = np.array(history_min).T
history_max = np.array(history_max).T

# %%
from matplotlib.pyplot import fill_between

xs = np.arange(len(params_history))

_, ax = plt.subplots()

for y1, y2 in zip(history_min, history_max):
    fill_between(xs, y1, y2)

plt.xlabel("iteration number")
plt.ylabel("x position")
plt.title("tooth position and width over optimization")

plt.show()
