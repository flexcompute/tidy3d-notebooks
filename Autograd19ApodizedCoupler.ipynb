# %% [markdown]
# # Inverse design of an apodized grating coupler through shape optimization
#
# A grating coupler (GC) is a key photonic device used to couple light between optical fibers and on-chip waveguides by diffracting light at a specific angle. These devices often employ apodization, a technique that modifies the grating tooth parameters along the device length to improve efficiency and minimize reflection losses.
#
# In this notebook, we will use gradient-based optimization to determine the optimal grating tooth distribution. We start from a uniform grating coupler and modify the tooth and gap sizes simultaneously using gradient based optimization. Feature size constraints on the parameters enable the device to remain fabricable over the course of optimization. In just a handful of iterations, we achieve a design that outperforms an apodized grating coupler designed using semi-analytical methods.
#
# <img src="img/apodized_grating_feature_image_autograd.png" width=400 alt="Schematic of the coupler">
#
# While the simulations are performed using a 2D cross section, the same approach can be modified to 3D without much further complication.
#
# If you are interested in other inverse design examples using tidy3d, you can find many of them [here](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/docs/features/autograd.html).
#
# If you are unfamiliar with inverse design, we also recommend our [intro to inverse design tutorials](https://www.flexcompute.com/tidy3d/learning-center/inverse-design/) and our [primer on automatic differentiation with tidy3d](https://www.flexcompute.com/tidy3d/examples/notebooks/Autograd1Intro/).

# %%
# as we are using autograd to perform gradient calculations, we need to import numpy from autograd's wrapper
import autograd as ag
import autograd.numpy as np
import matplotlib.pyplot as plt
import tidy3d as td
import tidy3d.web as web

# we will use Tidy3D's built-in Adam helper to perform the optimization
from tidy3d.plugins.autograd import adam, apply_updates

# %% [markdown]
# ### Basic Parameters
#
# First, we define the basic parameters used to define a uniform grating coupler for operation primarily in the C-band.

# %%
lda0 = 1.55  # central wavelength
n_ldas = 101  # number of wavelength points
ldas = np.linspace(1.5, 1.6, n_ldas)  # wavelength range

freq0 = td.C_0 / lda0  # central frequency
freqs = td.C_0 / ldas  # frequency range

num_freqs_objective = 5
ldas_objective = np.linspace(1.5, 1.6, num_freqs_objective)
freqs_objective = td.C_0 / ldas_objective

fwidth = 0.5 * (np.max(freqs) - np.min(freqs))  # width of the source frequency range

# %% [markdown]
# The material platform is the common silicon on insulator (SOI) with a 260 nm silicon thickness and 2 µm BOX thickness. The top cladding layer is 680 nm oxide. The grating will be partially etched with an etching depth of 160 nm.

# %%
# define materials from the material library
si = td.material_library["cSi"]["Palik_Lossless"]
sio2 = td.material_library["SiO2"]["Palik_Lossless"]

t_si = 0.26  # thickness of the silicon layer
etch_depth = 0.16  # etching depth
t_tox = 0.68  # top oxide layer thickness
t_box = 2  # bottom oxide layer thickness

# %% [markdown]
# We aim to design the GC for the standard single-mode fiber (SMF) with a mode field diameter (MFD) of 10.8 µm. The fiber is tilted at a 14.5 degree angle.

# %%
theta = np.deg2rad(14.5)  # fiber tilt angle
mfd = 10.8  # mode field diameter
source_x = 4.5  # x position of the fiber

N = 16  # number of grating teeth to create
inf_eff = 1e3  # effective infinity
buffer = 1.1 * lda0  # buffer spacing to pad the simulation domain

# %% [markdown]
# Next we compute the uniform tooth parameters (periodicity and fill fraction) to maximize efficiency.

# %%
neff_unetch = 2.9  # effective index of the slab mode of the unetched waveguide
neff_etch = 2.2  # effective index of the slab mode of the etched waveguide
n_c = 1.44  # refractive index of the cladding (SiO2)
theta_c = np.sin(theta) / n_c  # incident angle in the cladding


def get_periodicity(fill_fraction: float) -> float:
    """periodicity (bragg condition) as function of fill fraction, angle, wavelength, and etching parameters."""
    return lda0 / (
        fill_fraction * neff_unetch + (1 - fill_fraction) * neff_etch - n_c * np.sin(theta_c)
    )


f0 = 0.80
periodicity = get_periodicity(f0)
p_list = N * [periodicity]
f_list = N * [f0]

# %% [markdown]
# After obtaining $p_{\text{i}}$ and $f_{\text{i}}$, we will write a function to return the width of each air gap and each tooth. We will use these gap widths as the parameters for our design. The advantage is that we can impose bounds on these values to ensure the minimal feature size is above the fabrication constraint.
#
# Here we aim to have a minimal feature size above 60 nm. The current design has a minimal feature size right above it.

# %%
def get_widths(p_list, f_list):
    # calculate the widths of air gaps and silicon teeth
    return np.array([item for p, f in zip(p_list, f_list) for item in [p * (1 - f), p * f]])


widths = get_widths(p_list, f_list)

l_grating = np.sum(widths) + 3 * lda0  # total length of the GC

# print the current minimal feature size
print(f"The minimal feature size is {1e3 * np.min(widths):.2f} nm.")
# Out:
# The minimal feature size is 123.46 nm.

# %% [markdown]
# To ensure the minimal feature size is maintained during the optimization, we will use a design parameter in the range from `-inf` to `inf` and project it to a `tanh` function that is bounded by the minimal and maximal feature sizes.

# %%
min_width = 0.08  # minimal feature size we want to maintain
max_width = 1  # maximal feature size


# function to project a design parameter between -inf to inf to between min_width and max_width
def project(x):
    return 0.5 * (max_width - min_width) * np.tanh(x) + 0.5 * (max_width + min_width)


# function to inversely project a design parameter between min_width and max_width to between -inf to inf
def inverse_project(y):
    return np.arctanh((2 * (y - 0.5 * (max_width + min_width))) / (max_width - min_width))


# project the widths to parameters between -inf to inf
params0 = inverse_project(widths)

# %% [markdown]
# ### Define Static Components of the Simulation
#
# Next we will define the components that don't change during the optimization. These include the cladding layer, the output waveguide, the unetched layer, the bottom oxide layer, and the silicon substrate.

# %%
mask = td.Structure(
    geometry=td.Box(size=(td.inf, td.inf, td.inf), center=(0, 0, 0)),
    medium=td.Medium(),
)

# create the top oxide layer
tox = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, 0), rmax=(inf_eff, inf_eff, t_tox)),
    medium=sio2,
)

# create the output waveguide
slab_waveguide = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, 0), rmax=(0, inf_eff, t_si)),
    medium=si,
)

# create the unetched waveguide
unetched_waveguide = td.Structure(
    geometry=td.Box.from_bounds(rmin=(0, -inf_eff, 0), rmax=(inf_eff, inf_eff, t_si - etch_depth)),
    medium=si,
)

# create the bottom oxide layer
box = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, -t_box), rmax=(inf_eff, inf_eff, 0)),
    medium=sio2,
)

# create the silicon substrate layer
substrate = td.Structure(
    geometry=td.Box.from_bounds(
        rmin=(-inf_eff, -inf_eff, -inf_eff), rmax=(inf_eff, inf_eff, -t_box)
    ),
    medium=si,
)

# %% [markdown]
# The source and monitor are not changed either. We use a [GaussianBeam](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.GaussianBeam.html#tidy3d.GaussianBeam) to represent the incident fiber mode. A [ModeMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeMonitor.html#tidy3d.ModeMonitor) is placed at the output waveguide to measure the coupling efficiency.

# %%
gap = 1  # gap size between the source plane and the top surface of the cladding

# define a gaussian beam source
source = td.GaussianBeam(
    size=(2 * mfd, td.inf, 0),
    center=[source_x, 0, t_tox + gap],
    source_time=td.GaussianPulse(freq0=freq0, fwidth=fwidth),
    angle_theta=theta,
    direction="-",
    waist_radius=mfd / 2,
    pol_angle=np.pi / 2,  # 90 degree polarization angle for TE polarization
)

# define a mode monitor
mode_monitor = td.ModeMonitor(
    center=(-buffer / 2, 0, t_si / 2),
    size=(0, td.inf, 6 * t_si),
    freqs=freqs,
    mode_spec=td.ModeSpec(num_modes=1, target_neff=3),
    name="mode",
)

# %% [markdown]
# ### Simulate the Designed Apodized GC
#
# To simulate the designed GC and facility future optimization, we define a function that takes in an array of design parameters and returns a [Simulation]() object. Note again that each design parameter has a range from `-inf` to `inf`. It will then be projected to a range between `min_width` and `max_width`.

# %%
def make_2d_sim(design_parameters):
    # calculate the widths of air gaps and silicon teeth
    widths_si = project(design_parameters[1::2])
    widths_air = project(design_parameters[::2])

    # initialize the center and size of each silicon teeth
    center = 0
    size = 0

    # create the grating geometries from the given widths
    gratings = 0
    for width_si, width_air in zip(widths_si, widths_air):
        center += width_air + width_si / 2
        size = width_si
        gratings += td.Box(
            center=(center, 0, t_si - etch_depth / 2), size=(size, td.inf, etch_depth)
        )
        center += width_si / 2

    # create the grating structure
    gratings = td.Structure(geometry=gratings, medium=si)

    # create a box to represent the simulation domain box
    sim_box = td.Box.from_bounds(
        rmin=(-buffer, 0, -t_box - buffer / 2),
        rmax=(l_grating + buffer, 0, t_si + buffer),
    )

    run_time = 1e-12  # simulation run time

    # construct simulation
    sim = td.Simulation(
        center=sim_box.center,
        size=sim_box.size,
        grid_spec=td.GridSpec.auto(
            min_steps_per_wvl=30, wavelength=lda0
        ),  # use a fine grid to ensure the small features are well resolved
        structures=[
            mask,
            tox,
            gratings,
            unetched_waveguide,
            slab_waveguide,
            box,
            substrate,
        ],
        sources=[source],
        monitors=[mode_monitor],
        medium=sio2,
        run_time=run_time,
        boundary_spec=td.BoundarySpec(
            x=td.Boundary.pml(),
            y=td.Boundary.periodic(),  # set the boundary to periodic in y since it's a 2D simulation
            z=td.Boundary.pml(),
        ),
    )

    return sim

# %% [markdown]
# Create the simulation for the designed apodized GC and visualize it.

# %%
sim0 = make_2d_sim(params0)
sim0.plot_eps(y=0, freq=freq0)
plt.show()

# %% [markdown]
# Also visualize the grid to ensure it resolves the small features well.

# %%
ax = sim0.plot(y=0)
sim0.plot_grid(y=0, ax=ax)
ax.set_xlim(-0.1, 1)
ax.set_ylim(0, 0.3)
plt.show()

# %% [markdown]
# Run the simulation.

# %%
sim_data0 = web.run(simulation=sim0, task_name="initial design")
# Out:
# 15:03:02 CEST Created task 'initial design' with resource_id
#               'fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=375689;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=53298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\taskId]8;;\]8;id=375689;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\=]8;;\]8;id=852435;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\fdve]8;;\]8;id=375689;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\-492fe7a7-cd]8;;\
#               ]8;id=375689;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\92-4532-9138-8017f36f5aa9']8;;\.
#               Task folder: ]8;id=749333;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:03:05 CEST Estimated FlexCredit cost: 0.025. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 15:03:07 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# 15:03:37 CEST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:03:45 CEST starting up solver
# 15:03:46 CEST running solver
# 15:03:47 CEST early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:03:48 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               View simulation result at
#               ]8;id=518469;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=625306;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\taskId]8;;\]8;id=518469;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\=]8;;\]8;id=548989;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\fdve]8;;\]8;id=518469;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\-492fe7a7-cd]8;;\
#               ]8;id=518469;https://tidy3d.simulation.cloud/workbench?taskId=fdve-492fe7a7-cd92-4532-9138-8017f36f5aa9\92-4532-9138-8017f36f5aa9']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:03:50 CEST Loading results from simulation_data.hdf5

# %% [markdown]
# ### Result Visualization
#
# After the simulation is done, we can extract the coupling efficiency from the mode monitor data. In addition, we also calculate two important metrics: the maximum coupling efficiency and the 1dB bandwidth. The maximal coupling efficiency is about 2.7dB and the 1dB bandwidth is about 36 nm.

# %%
# function to calculate the coupling efficiency from simulation data
def compute_ce(sim_data):
    amp = sim_data["mode"].amps.sel(mode_index=0, direction="-").values
    ce = np.abs(amp) ** 2  # transmission to the top waveguide
    return ce


def dB(ce):
    return 10 * np.log10(ce)


# calculate the coupling efficiency for the designed GC
ce0 = compute_ce(sim_data0)

# plot the coupling efficiency
plt.plot(ldas, dB(ce0), c="red", linewidth=2)
plt.xlim(min(ldas), max(ldas))
plt.ylim(-10, 0)
plt.xlabel("Wavelength (µm)")
plt.ylabel("Coupling efficiency (dB)")
plt.grid()
plt.show()


# function to calculate the 1dB bandwidth from the coupling efficiency
def bandwidth(ldas, ce):
    max_ce = np.max(dB(ce))

    threshold = max_ce - 1

    within_1db = np.where(dB(ce) >= threshold)[0]

    lambda_min = ldas[within_1db[0]]
    lambda_max = ldas[within_1db[-1]]
    bandwidth = lambda_max - lambda_min
    return 1e3 * bandwidth


# print the maximum coupling efficiency and 1dB bandwidth
print(f"The 1dB bandwidth is {bandwidth(ldas, ce0):.1f} nm")
print(f"The maximum coupling efficiency is {np.max(dB(ce0)):.2f} dB.")
# Out:
# The 1dB bandwidth is 36.0 nm
# The maximum coupling efficiency is -2.74 dB.

# %% [markdown]
# ## Optimize GC with Inverse Design to Maximize the Efficiency and Bandwidth
#
# In this part, we will apply inverse design to maximize the coupling efficiency of our coupling over the wavelength range from 1500 to 1600 nm.
#
# To do this, we need to express our objective as a function of our parameters returning a single float value to maximize. This function will involve constructing, running, and postprocessing our simulation.

# %%
def J(design_parameters: np.ndarray) -> float:
    sim = make_2d_sim(design_parameters)
    sim_data = web.run(sim, task_name="GC_invdes", verbose=True)
    ce = np.sum(compute_ce(sim_data)) / n_ldas

    return ce

# %%
dJ = ag.value_and_grad(J)

# %% [markdown]
# Before running the optimization, we can check the value and gradient of the initial design to ensure the gradient tracking is working properly.

# %%
# %%time

val, grad = dJ(params0)
print(val)
print(grad)
# Out:
# 15:03:51 CEST Created task 'GC_invdes' with resource_id
#               'fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=329716;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=600673;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\taskId]8;;\]8;id=329716;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\=]8;;\]8;id=241191;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\fdve]8;;\]8;id=329716;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\-6efdeb2b-36]8;;\
#               ]8;id=329716;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\5e-422a-8b80-5c8a41a7241b']8;;\.
#               Task folder: ]8;id=417185;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:03:56 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# 15:04:05 CEST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:04:10 CEST starting up solver
# 15:04:11 CEST running solver
# 15:04:15 CEST early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = postprocess
# 15:04:21 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:04:23 CEST View simulation result at
#               ]8;id=27925;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=575182;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\taskId]8;;\]8;id=27925;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\=]8;;\]8;id=583579;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\fdve]8;;\]8;id=27925;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\-6efdeb2b-36]8;;\
#               ]8;id=27925;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6efdeb2b-365e-422a-8b80-5c8a41a7241b\5e-422a-8b80-5c8a41a7241b']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:04:25 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:04:31 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:04:47 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 0.3390465892159393
# [-1.17321182e-02  6.28505441e-01  2.69946648e-02  5.84308310e-01
#  -1.64972445e-03  1.32803981e-01 -2.03079973e-03 -2.04572945e-02
#   9.64456146e-04  6.00574356e-02  1.18689844e-02  5.72078254e-02
#   1.55931666e-02 -2.16742048e-02  4.13397433e-03 -7.84230979e-02
#   7.88709567e-03 -7.10540198e-02  1.24795132e-03 -8.56533503e-02
#   4.50736483e-03 -7.83018856e-02 -1.96388528e-03 -7.23079247e-02
#   2.53005638e-04 -5.06262475e-02 -3.73559248e-04 -3.75730912e-02
#  -6.11800676e-04 -2.56284733e-02 -5.57500031e-04 -1.48503663e-02]
# CPU times: user 1.12 s, sys: 92.6 ms, total: 1.21 s
# Wall time: 58.1 s

# %% [markdown]
# We will use the Adam optimizer to adjust the parameters for a number of iterations until we achieve a good performance.

# %%
# %%time

# hyperparameters
num_steps = 25
learning_rate = 0.05

# initialize adam optimizer with starting parameters
params = params0
optimizer = adam(learning_rate=learning_rate)
opt_state = optimizer.init(params)

# store history
J_history = []
params_history = []

for i in range(num_steps):
    # compute gradient and current objective function value
    value, gradient = dJ(params)

    # outputs
    print(f"step = {i + 1}")
    print(f"\tJ = {value:.3e}")
    print(f"\tgrad_norm = {np.linalg.norm(gradient):.4e}")

    # compute and apply updates to the optimizer based on gradient (-1 sign to maximize obj_fn)
    updates, opt_state = optimizer.update(-gradient, opt_state, params)
    params[:] = apply_updates(params, updates)

    # save history
    J_history.append(value)
    params_history.append(params.copy())
# Out:
# 15:04:49 CEST Created task 'GC_invdes' with resource_id
#               'fdve-8bde81da-8479-412d-8581-bf1253505e68' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=216029;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bde81da-8479-412d-8581-bf1253505e68\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=399509;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bde81da-8479-412d-8581-bf1253505e68\taskId]8;;\]8;id=216029;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bde81da-8479-412d-8581-bf1253505e68\=]8;;\]8;id=972945;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bde81da-8479-412d-8581-bf1253505e68\fdve]8;;\]8;id=216029;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bde81da-8479-412d-8581-bf1253505e68\-8bde81da-84]8;;\
#               ]8;id=216029;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8bde81da-8479-412d-8581-bf1253505e68\79-412d-8581-bf1253505e68']8;;\.
#               Task folder: ]8;id=263999;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:04:54 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:04:56 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:05:01 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:05:02 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 1
# 	J = 3.390e-01
# 	grad_norm = 8.9328e-01
# 15:05:04 CEST Created task 'GC_invdes' with resource_id
#               'fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=123647;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=229238;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\taskId]8;;\]8;id=123647;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\=]8;;\]8;id=880267;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\fdve]8;;\]8;id=123647;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\-aafff070-59]8;;\
#               ]8;id=123647;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\dc-4e54-9187-5e3cc5cf594a']8;;\.
#               Task folder: ]8;id=315373;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:05:09 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# 15:05:16 CEST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:05:21 CEST starting up solver
#               running solver
# 15:05:27 CEST early shutoff detected at 48%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:05:28 CEST status = postprocess
# 15:05:34 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:05:36 CEST View simulation result at
#               ]8;id=979899;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=941060;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\taskId]8;;\]8;id=979899;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\=]8;;\]8;id=821751;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\fdve]8;;\]8;id=979899;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\-aafff070-59]8;;\
#               ]8;id=979899;https://tidy3d.simulation.cloud/workbench?taskId=fdve-aafff070-59dc-4e54-9187-5e3cc5cf594a\dc-4e54-9187-5e3cc5cf594a']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:05:37 CEST Loading results from simulation_data.hdf5
# 15:05:38 CEST Started working on Batch containing 1 tasks.
# 15:05:43 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:06:03 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 2
# 	J = 3.173e-01
# 	grad_norm = 9.2350e-01
# 15:06:05 CEST Created task 'GC_invdes' with resource_id
#               'fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=376219;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=314498;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\taskId]8;;\]8;id=376219;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\=]8;;\]8;id=196591;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\fdve]8;;\]8;id=376219;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\-8e080a56-46]8;;\
#               ]8;id=376219;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\ec-48e5-8ef5-24e3366dfee6']8;;\.
#               Task folder: ]8;id=283799;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:06:11 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:06:20 CEST starting up solver
# 15:06:21 CEST running solver
# 15:06:26 CEST early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:06:27 CEST status = postprocess
# 15:06:30 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:06:32 CEST View simulation result at
#               ]8;id=593404;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=326327;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\taskId]8;;\]8;id=593404;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\=]8;;\]8;id=740273;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\fdve]8;;\]8;id=593404;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\-8e080a56-46]8;;\
#               ]8;id=593404;https://tidy3d.simulation.cloud/workbench?taskId=fdve-8e080a56-46ec-48e5-8ef5-24e3366dfee6\ec-48e5-8ef5-24e3366dfee6']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:06:34 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:06:40 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:06:59 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 3
# 	J = 3.793e-01
# 	grad_norm = 5.8213e-01
# 15:07:00 CEST Created task 'GC_invdes' with resource_id
#               'fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=259377;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=60325;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\taskId]8;;\]8;id=259377;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\=]8;;\]8;id=551051;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\fdve]8;;\]8;id=259377;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\-852441f6-fb]8;;\
#               ]8;id=259377;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\aa-43fa-8553-7f08c3eac0d7']8;;\.
#               Task folder: ]8;id=718768;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:07:06 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:07:15 CEST starting up solver
#               running solver
# 15:07:19 CEST early shutoff detected at 46%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:07:20 CEST status = postprocess
# 15:07:26 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:07:28 CEST View simulation result at
#               ]8;id=403906;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=571270;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\taskId]8;;\]8;id=403906;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\=]8;;\]8;id=569160;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\fdve]8;;\]8;id=403906;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\-852441f6-fb]8;;\
#               ]8;id=403906;https://tidy3d.simulation.cloud/workbench?taskId=fdve-852441f6-fbaa-43fa-8553-7f08c3eac0d7\aa-43fa-8553-7f08c3eac0d7']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:07:29 CEST Loading results from simulation_data.hdf5
# 15:07:30 CEST Started working on Batch containing 1 tasks.
# 15:07:35 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:07:50 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 4
# 	J = 3.860e-01
# 	grad_norm = 7.2584e-01
# 15:07:52 CEST Created task 'GC_invdes' with resource_id
#               'fdve-d3743f43-daab-4c3f-a338-f9286cb6e763' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=546447;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=388245;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\taskId]8;;\]8;id=546447;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\=]8;;\]8;id=316059;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\fdve]8;;\]8;id=546447;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\-d3743f43-da]8;;\
#               ]8;id=546447;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\ab-4c3f-a338-f9286cb6e763']8;;\.
#               Task folder: ]8;id=359560;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:07:58 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:08:07 CEST starting up solver
#               running solver
# 15:08:11 CEST early shutoff detected at 45%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:08:12 CEST status = postprocess
# 15:08:17 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:08:19 CEST View simulation result at
#               ]8;id=145954;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=760699;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\taskId]8;;\]8;id=145954;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\=]8;;\]8;id=826052;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\fdve]8;;\]8;id=145954;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\-d3743f43-da]8;;\
#               ]8;id=145954;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d3743f43-daab-4c3f-a338-f9286cb6e763\ab-4c3f-a338-f9286cb6e763']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:08:21 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:08:27 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:08:54 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 5
# 	J = 3.884e-01
# 	grad_norm = 5.9201e-01
# 15:08:57 CEST Created task 'GC_invdes' with resource_id
#               'fdve-30660712-641f-4f51-9658-348f518c6430' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=944298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=927431;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\taskId]8;;\]8;id=944298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\=]8;;\]8;id=958464;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\fdve]8;;\]8;id=944298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\-30660712-64]8;;\
#               ]8;id=944298;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\1f-4f51-9658-348f518c6430']8;;\.
#               Task folder: ]8;id=946832;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:09:02 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:09:16 CEST starting up solver
# 15:09:17 CEST running solver
# 15:09:31 CEST early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:09:32 CEST status = postprocess
# 15:09:38 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:09:40 CEST View simulation result at
#               ]8;id=307815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=606453;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\taskId]8;;\]8;id=307815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\=]8;;\]8;id=560312;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\fdve]8;;\]8;id=307815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\-30660712-64]8;;\
#               ]8;id=307815;https://tidy3d.simulation.cloud/workbench?taskId=fdve-30660712-641f-4f51-9658-348f518c6430\1f-4f51-9658-348f518c6430']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:09:41 CEST Loading results from simulation_data.hdf5
# 15:09:42 CEST Started working on Batch containing 1 tasks.
# 15:09:47 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:10:16 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 6
# 	J = 3.900e-01
# 	grad_norm = 6.7738e-01
# 15:10:17 CEST Created task 'GC_invdes' with resource_id
#               'fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=744743;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=565592;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\taskId]8;;\]8;id=744743;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\=]8;;\]8;id=351505;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\fdve]8;;\]8;id=744743;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\-bb11a510-52]8;;\
#               ]8;id=744743;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\f2-4bcc-afdf-4b2b1c825b42']8;;\.
#               Task folder: ]8;id=829138;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:10:24 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:10:33 CEST starting up solver
#               running solver
# 15:10:39 CEST early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:10:40 CEST status = postprocess
# 15:10:43 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:10:45 CEST View simulation result at
#               ]8;id=646935;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=221317;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\taskId]8;;\]8;id=646935;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\=]8;;\]8;id=24603;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\fdve]8;;\]8;id=646935;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\-bb11a510-52]8;;\
#               ]8;id=646935;https://tidy3d.simulation.cloud/workbench?taskId=fdve-bb11a510-52f2-4bcc-afdf-4b2b1c825b42\f2-4bcc-afdf-4b2b1c825b42']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:10:46 CEST Loading results from simulation_data.hdf5
# 15:10:47 CEST Started working on Batch containing 1 tasks.
# 15:10:52 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:11:17 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 7
# 	J = 4.029e-01
# 	grad_norm = 6.0698e-01
# 15:11:19 CEST Created task 'GC_invdes' with resource_id
#               'fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=751570;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=271123;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\taskId]8;;\]8;id=751570;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\=]8;;\]8;id=611769;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\fdve]8;;\]8;id=751570;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\-36844124-6f]8;;\
#               ]8;id=751570;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\c1-4d3b-b621-e4fd3ee80946']8;;\.
#               Task folder: ]8;id=846294;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:11:25 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# 15:11:32 CEST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:11:37 CEST starting up solver
# 15:11:38 CEST running solver
# 15:11:39 CEST early shutoff detected at 47%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:11:40 CEST status = postprocess
# 15:11:46 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:11:48 CEST View simulation result at
#               ]8;id=207348;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=803417;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\taskId]8;;\]8;id=207348;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\=]8;;\]8;id=325070;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\fdve]8;;\]8;id=207348;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\-36844124-6f]8;;\
#               ]8;id=207348;https://tidy3d.simulation.cloud/workbench?taskId=fdve-36844124-6fc1-4d3b-b621-e4fd3ee80946\c1-4d3b-b621-e4fd3ee80946']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:11:49 CEST Loading results from simulation_data.hdf5
# 15:11:50 CEST Started working on Batch containing 1 tasks.
# 15:11:55 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:12:20 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 8
# 	J = 4.214e-01
# 	grad_norm = 4.2170e-01
# 15:12:22 CEST Created task 'GC_invdes' with resource_id
#               'fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=714547;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=847005;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\taskId]8;;\]8;id=714547;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\=]8;;\]8;id=73474;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\fdve]8;;\]8;id=714547;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\-9851ff3b-ff]8;;\
#               ]8;id=714547;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\67-47c1-b605-2baca0db2c57']8;;\.
#               Task folder: ]8;id=65576;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:12:28 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:12:37 CEST starting up solver
#               running solver
# 15:12:43 CEST early shutoff detected at 45%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:12:44 CEST status = postprocess
# 15:12:50 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:12:52 CEST View simulation result at
#               ]8;id=631696;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=111920;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\taskId]8;;\]8;id=631696;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\=]8;;\]8;id=725916;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\fdve]8;;\]8;id=631696;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\-9851ff3b-ff]8;;\
#               ]8;id=631696;https://tidy3d.simulation.cloud/workbench?taskId=fdve-9851ff3b-ff67-47c1-b605-2baca0db2c57\67-47c1-b605-2baca0db2c57']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:12:53 CEST Loading results from simulation_data.hdf5
# 15:12:54 CEST Started working on Batch containing 1 tasks.
# 15:12:59 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:13:25 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 9
# 	J = 4.287e-01
# 	grad_norm = 3.5624e-01
# 15:13:27 CEST Created task 'GC_invdes' with resource_id
#               'fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=279142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=741969;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\taskId]8;;\]8;id=279142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\=]8;;\]8;id=402969;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\fdve]8;;\]8;id=279142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\-af77a0c3-f2]8;;\
#               ]8;id=279142;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\e5-4e75-9293-5954d62a99cf']8;;\.
#               Task folder: ]8;id=735616;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:13:34 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:13:48 CEST starting up solver
# 15:13:49 CEST running solver
# 15:13:56 CEST early shutoff detected at 43%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:13:57 CEST status = postprocess
# 15:14:03 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:14:05 CEST View simulation result at
#               ]8;id=627654;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=503734;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\taskId]8;;\]8;id=627654;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\=]8;;\]8;id=963674;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\fdve]8;;\]8;id=627654;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\-af77a0c3-f2]8;;\
#               ]8;id=627654;https://tidy3d.simulation.cloud/workbench?taskId=fdve-af77a0c3-f2e5-4e75-9293-5954d62a99cf\e5-4e75-9293-5954d62a99cf']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:14:07 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:14:12 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:14:29 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 10
# 	J = 4.324e-01
# 	grad_norm = 5.1958e-01
# 15:14:31 CEST Created task 'GC_invdes' with resource_id
#               'fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=964728;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=897702;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\taskId]8;;\]8;id=964728;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\=]8;;\]8;id=252344;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\fdve]8;;\]8;id=964728;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\-7579b2b1-ea]8;;\
#               ]8;id=964728;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\3f-411f-9c5f-f7913bceebd5']8;;\.
#               Task folder: ]8;id=288958;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:14:37 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# 15:14:49 CEST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:14:54 CEST starting up solver
#               running solver
# 15:14:58 CEST early shutoff detected at 43%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:14:59 CEST status = postprocess
# 15:15:04 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:15:06 CEST View simulation result at
#               ]8;id=758028;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=44358;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\taskId]8;;\]8;id=758028;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\=]8;;\]8;id=970047;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\fdve]8;;\]8;id=758028;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\-7579b2b1-ea]8;;\
#               ]8;id=758028;https://tidy3d.simulation.cloud/workbench?taskId=fdve-7579b2b1-ea3f-411f-9c5f-f7913bceebd5\3f-411f-9c5f-f7913bceebd5']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:15:08 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:15:14 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:15:37 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 11
# 	J = 4.373e-01
# 	grad_norm = 4.7068e-01
# 15:15:39 CEST Created task 'GC_invdes' with resource_id
#               'fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=98606;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=447457;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\taskId]8;;\]8;id=98606;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\=]8;;\]8;id=578443;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\fdve]8;;\]8;id=98606;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\-83852e8c-aa]8;;\
#               ]8;id=98606;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\6d-4cf8-9bdf-1f1fc67af331']8;;\.
#               Task folder: ]8;id=39423;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:15:45 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:15:59 CEST starting up solver
# 15:16:00 CEST running solver
# 15:16:04 CEST early shutoff detected at 43%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = postprocess
# 15:16:10 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:16:12 CEST View simulation result at
#               ]8;id=87402;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=251113;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\taskId]8;;\]8;id=87402;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\=]8;;\]8;id=928638;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\fdve]8;;\]8;id=87402;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\-83852e8c-aa]8;;\
#               ]8;id=87402;https://tidy3d.simulation.cloud/workbench?taskId=fdve-83852e8c-aa6d-4cf8-9bdf-1f1fc67af331\6d-4cf8-9bdf-1f1fc67af331']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:16:14 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:16:19 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:16:45 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 12
# 	J = 4.450e-01
# 	grad_norm = 4.3449e-01
# 15:16:47 CEST Created task 'GC_invdes' with resource_id
#               'fdve-275a26fb-c091-4466-bc78-c3d08da89e87' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=126191;https://tidy3d.simulation.cloud/workbench?taskId=fdve-275a26fb-c091-4466-bc78-c3d08da89e87\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=620614;https://tidy3d.simulation.cloud/workbench?taskId=fdve-275a26fb-c091-4466-bc78-c3d08da89e87\taskId]8;;\]8;id=126191;https://tidy3d.simulation.cloud/workbench?taskId=fdve-275a26fb-c091-4466-bc78-c3d08da89e87\=]8;;\]8;id=360474;https://tidy3d.simulation.cloud/workbench?taskId=fdve-275a26fb-c091-4466-bc78-c3d08da89e87\fdve]8;;\]8;id=126191;https://tidy3d.simulation.cloud/workbench?taskId=fdve-275a26fb-c091-4466-bc78-c3d08da89e87\-275a26fb-c0]8;;\
#               ]8;id=126191;https://tidy3d.simulation.cloud/workbench?taskId=fdve-275a26fb-c091-4466-bc78-c3d08da89e87\91-4466-bc78-c3d08da89e87']8;;\.
#               Task folder: ]8;id=470191;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:16:53 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# ...
#               View task using web UI at
#               ]8;id=13801;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=957239;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\taskId]8;;\]8;id=13801;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\=]8;;\]8;id=277184;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\fdve]8;;\]8;id=13801;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\-a223d511-85]8;;\
#               ]8;id=13801;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\b4-4148-af9e-f620cdbd53e5']8;;\.
#               Task folder: ]8;id=301212;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:26:37 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# 15:28:01 CEST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:28:06 CEST starting up solver
#               running solver
# 15:28:10 CEST early shutoff detected at 41%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:28:11 CEST status = postprocess
# 15:28:17 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:28:19 CEST View simulation result at
#               ]8;id=696668;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=746251;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\taskId]8;;\]8;id=696668;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\=]8;;\]8;id=116834;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\fdve]8;;\]8;id=696668;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\-a223d511-85]8;;\
#               ]8;id=696668;https://tidy3d.simulation.cloud/workbench?taskId=fdve-a223d511-85b4-4148-af9e-f620cdbd53e5\b4-4148-af9e-f620cdbd53e5']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:28:20 CEST Loading results from simulation_data.hdf5
# 15:28:21 CEST Started working on Batch containing 1 tasks.
# 15:28:27 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:28:58 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 22
# 	J = 4.742e-01
# 	grad_norm = 2.9784e-01
# 15:29:00 CEST Created task 'GC_invdes' with resource_id
#               'fdve-c00db293-c7fe-4549-9e62-457ee0987e38' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=991465;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=211144;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\taskId]8;;\]8;id=991465;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\=]8;;\]8;id=714998;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\fdve]8;;\]8;id=991465;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\-c00db293-c7]8;;\
#               ]8;id=991465;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\fe-4549-9e62-457ee0987e38']8;;\.
#               Task folder: ]8;id=891447;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:29:06 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# 15:29:15 CEST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:29:20 CEST starting up solver
# 15:29:21 CEST running solver
# 15:29:24 CEST early shutoff detected at 41%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:29:25 CEST status = postprocess
# 15:29:31 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:29:33 CEST View simulation result at
#               ]8;id=230168;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=858239;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\taskId]8;;\]8;id=230168;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\=]8;;\]8;id=467065;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\fdve]8;;\]8;id=230168;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\-c00db293-c7]8;;\
#               ]8;id=230168;https://tidy3d.simulation.cloud/workbench?taskId=fdve-c00db293-c7fe-4549-9e62-457ee0987e38\fe-4549-9e62-457ee0987e38']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:29:35 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:29:40 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:29:55 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 23
# 	J = 4.774e-01
# 	grad_norm = 2.1695e-01
# 15:29:57 CEST Created task 'GC_invdes' with resource_id
#               'fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=700211;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=241889;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\taskId]8;;\]8;id=700211;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\=]8;;\]8;id=231724;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\fdve]8;;\]8;id=700211;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\-6a8ed7d8-ee]8;;\
#               ]8;id=700211;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\c7-4b8b-a953-7b8bb05f1588']8;;\.
#               Task folder: ]8;id=106041;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:30:03 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:30:12 CEST starting up solver
#               running solver
# 15:30:18 CEST early shutoff detected at 42%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:30:19 CEST status = postprocess
# 15:30:22 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:30:24 CEST View simulation result at
#               ]8;id=915811;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=136574;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\taskId]8;;\]8;id=915811;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\=]8;;\]8;id=51949;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\fdve]8;;\]8;id=915811;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\-6a8ed7d8-ee]8;;\
#               ]8;id=915811;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6a8ed7d8-eec7-4b8b-a953-7b8bb05f1588\c7-4b8b-a953-7b8bb05f1588']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:30:26 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:30:31 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:30:46 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 24
# 	J = 4.795e-01
# 	grad_norm = 2.2051e-01
# 15:30:48 CEST Created task 'GC_invdes' with resource_id
#               'fdve-66ea8335-817a-4ad9-95cd-328f68d209ea' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=712097;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=394618;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\taskId]8;;\]8;id=712097;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\=]8;;\]8;id=974970;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\fdve]8;;\]8;id=712097;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\-66ea8335-81]8;;\
#               ]8;id=712097;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\7a-4ad9-95cd-328f68d209ea']8;;\.
#               Task folder: ]8;id=607827;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:30:54 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:31:14 CEST starting up solver
#               running solver
# 15:31:18 CEST early shutoff detected at 41%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = postprocess
# 15:31:24 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:31:26 CEST View simulation result at
#               ]8;id=886745;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=255588;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\taskId]8;;\]8;id=886745;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\=]8;;\]8;id=35312;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\fdve]8;;\]8;id=886745;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\-66ea8335-81]8;;\
#               ]8;id=886745;https://tidy3d.simulation.cloud/workbench?taskId=fdve-66ea8335-817a-4ad9-95cd-328f68d209ea\7a-4ad9-95cd-328f68d209ea']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:31:28 CEST Loading results from simulation_data.hdf5
#               Started working on Batch containing 1 tasks.
# 15:31:35 CEST Maximum FlexCredit cost: 0.025 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               completion.
# 15:31:51 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# step = 25
# 	J = 4.801e-01
# 	grad_norm = 1.6475e-01
# CPU times: user 26.4 s, sys: 1.55 s, total: 28 s
# Wall time: 27min 4s

# %% [markdown]
# Plot the objective function (average coupling efficiency) as a function of the number of iterations. A steady increase of the average coupling efficiency is observed.

# %%
plt.plot(J_history, c="black")
plt.xlabel("Iterations")
plt.ylabel("Objective function (average coupling efficiency)")
plt.show()

# %% [markdown]
# ### Design the Apodized GC
#
# For comparison with more established methods, we'll simulate a device designed using the approach introduced in the reference [paper](https://doi.org/10.1038/s41598-017-16505-z). First of all, the Bragg condition is given by
#
# $$
# p_{\text{i}} = \frac{\lambda_\text{c}}{(n_{\text{eff,i}} - n_{\text{c}}\sin \theta_{\text{c}})},
# $$
#
# where $p_{\text{i}}$ is the local period of the grating, $\lambda_\text{c}$ is the central wavelength, $n_{\text{c}}$ is the refractive index of the cladding, $\theta_{\text{c}}$ is the incident angle in the cladding (~ 10 degrees from Snell's law), and
#
# $$
# n_{\text{eff,i}} = f_\text{i} \times n_\text{neff,nonetch} + (1-f_\text{i}) \times n_\text{neff,etch}.
# $$
#
# Here $f_\text{i}$ is the local filling fraction, $n_\text{neff,unetch}$ is the effective index of the slab mode of the unetched waveguide (260 nm thick), and $n_\text{neff,etch}$ is the effective index of the slab mode of the etched waveguide (100 nm thick). $n_\text{neff,unetch}$ and $n_\text{neff,etch}$ are determined to be about 2.9 and 2.2 by mode analysis (not shown). Furthermore, we follow a linear apodization, namely
#
# $$
# f_\text{i} = f_\text{0} - R \times x,
# $$
#
# where $f_\text{0}$ is the filling fraction of the first period, $R$ is the linear apodization factor and $x$ is the position of each tooth from the starting point of the grating. By using an initial local filling fraction $f_\text{0}$=0.9 and apodization factor $R$=0.0025 µm$^{-1}$ we can recursively calculate $p_{\text{i}}$ and $f_\text{i}$ for $i=0, 1, ..., N-1$ using the equations above. The result is a grating with apodized pitch length and filling fraction.
#
# For more details on the design principles, refer to the reference [paper](https://doi.org/10.1038/s41598-017-16505-z).

# %%
# and then the apodized design parameters to compare to later

R = 0.025  # linear apodization factor

p_list_apodized = []  # list to store all local periodicities
f_list_apodized = []  # list to store all local filling fractions

f0_apodized = 0.86  # filling fraction of the first teeth
f_current = f0_apodized  # variable to store the current local filling fraction

# recursively calculate all local periodicities and filling fractions
for i in range(N):
    p_current = get_periodicity(f_current)
    p_list_apodized.append(p_current)
    f_list_apodized.append(f_current)
    f_current = f0_apodized - R * sum(p_list_apodized)

widths_apodized = get_widths(p_list_apodized, f_list_apodized)
params_apodized = inverse_project(widths_apodized)
sim_apodized = make_2d_sim(params_apodized)

# %% [markdown]
# Let's plot all of the simulations together to see how their features compare.

# %%
params_opt = params_history[-1]
sim_opt = make_2d_sim(params_opt)

f, (ax1, ax2, ax3) = plt.subplots(3, 1, tight_layout=True, figsize=(10, 6))

sim0.plot_eps(y=0, freq=freq0, ax=ax1)
sim_apodized.plot_eps(y=0, freq=freq0, ax=ax2)
sim_opt.plot_eps(y=0, freq=freq0, ax=ax3)

ax1.set_title("uniform")
ax2.set_title("apodized")
ax3.set_title("optimized")


plt.show()

# %% [markdown]
# Next, we'll run each of the designs to be able to compare the coupling efficiencies directly.

# %%
sim_data_apodized = web.run(simulation=sim_apodized, task_name="apodized design")
sim_data_opt = web.run(simulation=sim_opt, task_name="optimized design")
# Out:
# 15:31:53 CEST Created task 'apodized design' with resource_id
#               'fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=135962;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=274701;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\taskId]8;;\]8;id=135962;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\=]8;;\]8;id=985570;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\fdve]8;;\]8;id=135962;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\-0cdaa85c-ec]8;;\
#               ]8;id=135962;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\9d-4870-ae88-9cbce3114185']8;;\.
#               Task folder: ]8;id=391671;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:31:56 CEST Estimated FlexCredit cost: 0.025. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 15:31:58 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:32:10 CEST starting up solver
# 15:32:11 CEST running solver
# 15:32:17 CEST early shutoff detected at 42%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               View simulation result at
#               ]8;id=443863;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=295530;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\taskId]8;;\]8;id=443863;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\=]8;;\]8;id=195475;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\fdve]8;;\]8;id=443863;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\-0cdaa85c-ec]8;;\
#               ]8;id=443863;https://tidy3d.simulation.cloud/workbench?taskId=fdve-0cdaa85c-ec9d-4870-ae88-9cbce3114185\9d-4870-ae88-9cbce3114185']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:32:19 CEST Loading results from simulation_data.hdf5
#               Created task 'optimized design' with resource_id
#               'fdve-5b593685-71c6-4e80-bb21-394fe0feea27' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=172755;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=563262;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\taskId]8;;\]8;id=172755;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\=]8;;\]8;id=449837;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\fdve]8;;\]8;id=172755;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\-5b593685-71]8;;\
#               ]8;id=172755;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\c6-4e80-bb21-394fe0feea27']8;;\.
#               Task folder: ]8;id=137513;https://tidy3d.simulation.cloud/folders/folder-df61810d-cad6-4474-8ea9-e4f00d5dfcb0\'default']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:32:22 CEST Estimated FlexCredit cost: 0.025. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 15:32:24 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:32:36 CEST starting up solver
#               running solver
# 15:32:40 CEST early shutoff detected at 42%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:32:41 CEST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               View simulation result at
#               ]8;id=629274;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=764135;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\taskId]8;;\]8;id=629274;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\=]8;;\]8;id=76762;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\fdve]8;;\]8;id=629274;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\-5b593685-71]8;;\
#               ]8;id=629274;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5b593685-71c6-4e80-bb21-394fe0feea27\c6-4e80-bb21-394fe0feea27']8;;\.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 15:32:42 CEST Loading results from simulation_data.hdf5

# %%
ce_opt = compute_ce(sim_data_opt)
ce_apodized = compute_ce(sim_data_apodized)

plt.plot(ldas, dB(ce0), c="red", linewidth=2, label="Initial design")
plt.plot(ldas, dB(ce_apodized), c="orange", linewidth=2, label="Apodized design")
plt.plot(ldas, dB(ce_opt), c="blue", linewidth=2, label="Optimized design")
plt.xlim(min(ldas), max(ldas))
plt.ylim(-10, 0)
plt.xlabel("Wavelength (µm)")
plt.ylabel("Coupling efficiency (dB)")
plt.legend()
plt.grid()
plt.show()

# %% [markdown]
# We see that the optimized and apodized designs both exceed that of the uniform with -2dB efficiency. However, the optimized design far outperforms in terms of bandwidth. We can also confirm that the minimal feature size is maintained above 85 nm.

# %%
print("Uniform:")
print(f"  The 1dB bandwidth is {bandwidth(ldas, ce0):.1f} nm")
print(f"  The maximum coupling efficiency is {np.max(dB(ce0)):.2f} dB.")
print(f"  The minimal feature size is {1e3 * np.min(project(params0)):.2f} nm.")
print("")
print("Apodized:")
print(f"  The 1dB bandwidth is {bandwidth(ldas, ce_apodized):.1f} nm")
print(f"  The maximum coupling efficiency is {np.max(dB(ce_apodized)):.2f} dB.")
print(f"  The minimal feature size is {1e3 * np.min(project(params_apodized)):.2f} nm.")
print("")
print("Optimized:")
print(f"  The 1dB bandwidth is {bandwidth(ldas, ce_opt):.1f} nm")
print(f"  The maximum coupling efficiency is {np.max(dB(ce_opt)):.2f} dB.")
print(f"  The minimal feature size is {1e3 * np.min(project(params_opt)):.2f} nm.")
# Out:
# Uniform:
#   The 1dB bandwidth is 36.0 nm
#   The maximum coupling efficiency is -2.74 dB.
#   The minimal feature size is 86.12 nm.
#
# Apodized:
#   The 1dB bandwidth is 43.0 nm
#   The maximum coupling efficiency is -1.99 dB.
#   The minimal feature size is 85.00 nm.
#
# Optimized:
#   The 1dB bandwidth is 50.0 nm
#   The maximum coupling efficiency is -1.99 dB.
#   The minimal feature size is 86.12 nm.

# %% [markdown]
# ## Take the Model Further
#
#
# In this notebook, we only perform 2D simulations. A good next step would be to convert the 2D design to a 3D linear GC or focusing GC. The coupling efficiency of the 3D GC is likely slightly lower than that in 2D. Inverse design can then be applied to fine-tune it again. To minimize the footprint, one can potentially also apply shape optimization to design a compact and low-loss taper section, as demonstrated in this [example](https://docs.flexcompute.com/projects/tidy3d/en/latest/notebooks/Autograd5BoundaryGradients.html).
#
# ### Further visualizations
#
# In case you would like to gain more insight into how your device has changed over optimization, the following are a few post-processing steps to make animations and visualize the grating teeth locations.

# %%
import matplotlib.animation as animation
from IPython.display import HTML

fig, ax = plt.subplots(1, 1, tight_layout=True, figsize=(10, 3))

sim0 = make_2d_sim(params_history[0])


def plot_fn(params, ax=ax):
    sim = make_2d_sim(params)
    ax = sim.plot_eps(y=0.0, ax=ax, freq=freq0)
    ax.set_aspect("equal")


def animate(i):
    plot_fn(params_history[i])


# create animation
ani = animation.FuncAnimation(fig, animate, frames=len(params_history))
plt.close()

# %%
td.config.logging.level = "ERROR"

# display the animation (press "play" to start)
HTML(ani.to_jshtml())
# Out:
# <link rel="stylesheet"
# href="https://maxcdn.bootstrapcdn.com/font-awesome/4.4.0/css/font-awesome.min.css">
# <script language="javascript">
#   function isInternetExplorer() {
#     ua = navigator.userAgent;
#     /* MSIE used to detect old browsers and Trident used to newer ones*/
#     return ua.indexOf("MSIE ") > -1 || ua.indexOf("Trident/") > -1;
#   }
#
#   /* Define the Animation class */
#   function Animation(frames, img_id, slider_id, interval, loop_select_id){
#     this.img_id = img_id;
#     this.slider_id = slider_id;
#     this.loop_select_id = loop_select_id;
#     this.interval = interval;
#     this.current_frame = 0;
#     this.direction = 0;
#     this.timer = null;
#     this.frames = new Array(frames.length);
#
#     for (var i=0; i<frames.length; i++)
#     {
#      this.frames[i] = new Image();
#      this.frames[i].src = frames[i];
#     }
#     var slider = document.getElementById(this.slider_id);
#     slider.max = this.frames.length - 1;
#     if (isInternetExplorer()) {
#         // switch from oninput to onchange because IE <= 11 does not conform
#         // with W3C specification. It ignores oninput and onchange behaves
#         // like oninput. In contrast, Microsoft Edge behaves correctly.
#         slider.setAttribute('onchange', slider.getAttribute('oninput'));
#         slider.setAttribute('oninput', null);
#     }
#     this.set_frame(this.current_frame);
#   }
#
#   Animation.prototype.get_loop_state = function(){
#     var button_group = document[this.loop_select_id].state;
#     for (var i = 0; i < button_group.length; i++) {
#         var button = button_group[i];
#         if (button.checked) {
#             return button.value;
#         }
#     }
#     return undefined;
#   }
#
#   Animation.prototype.set_frame = function(frame){
#     this.current_frame = frame;
#     document.getElementById(this.img_id).src =
#             this.frames[this.current_frame].src;
#     document.getElementById(this.slider_id).value = this.current_frame;
#   }
#
#   Animation.prototype.next_frame = function()
#   {
#     this.set_frame(Math.min(this.frames.length - 1, this.current_frame + 1));
#   }
#
#   Animation.prototype.previous_frame = function()
#   {
#     this.set_frame(Math.max(0, this.current_frame - 1));
#   }
#
#   Animation.prototype.first_frame = function()
#   {
#     this.set_frame(0);
#   }
#
#   Animation.prototype.last_frame = function()
#   {
#     this.set_frame(this.frames.length - 1);
#   }
#
#   Animation.prototype.slower = function()
#   {
#     this.interval /= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.faster = function()
#   {
#     this.interval *= 0.7;
#     if(this.direction > 0){this.play_animation();}
#     else if(this.direction < 0){this.reverse_animation();}
#   }
#
#   Animation.prototype.anim_step_forward = function()
#   {
#     this.current_frame += 1;
#     if(this.current_frame < this.frames.length){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.first_frame();
#       }else if(loop_state == "reflect"){
#         this.last_frame();
#         this.reverse_animation();
#       }else{
#         this.pause_animation();
#         this.last_frame();
#       }
#     }
#   }
#
#   Animation.prototype.anim_step_reverse = function()
#   {
#     this.current_frame -= 1;
#     if(this.current_frame >= 0){
#       this.set_frame(this.current_frame);
#     }else{
#       var loop_state = this.get_loop_state();
#       if(loop_state == "loop"){
#         this.last_frame();
#       }else if(loop_state == "reflect"){
#         this.first_frame();
#         this.play_animation();
#       }else{
#         this.pause_animation();
#         this.first_frame();
#       }
#     }
#   }
#
#   Animation.prototype.pause_animation = function()
#   {
#     this.direction = 0;
#     if (this.timer){
#       clearInterval(this.timer);
#       this.timer = null;
#     }
#   }
#
#   Animation.prototype.play_animation = function()
#   {
#     this.pause_animation();
#     this.direction = 1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_forward();
#     }, this.interval);
#   }
#
#   Animation.prototype.reverse_animation = function()
#   {
#     this.pause_animation();
#     this.direction = -1;
#     var t = this;
#     if (!this.timer) this.timer = setInterval(function() {
#         t.anim_step_reverse();
#     }, this.interval);
#   }
# </script>
#
# <style>
# .animation {
#     display: inline-block;
#     text-align: center;
# }
# input[type=range].anim-slider {
#     width: 374px;
#     margin-left: auto;
#     margin-right: auto;
# }
# .anim-buttons {
#     margin: 8px 0px;
# }
# .anim-buttons button {
#     padding: 0;
#     width: 36px;
# }
# .anim-state label {
#     margin-right: 8px;
# }
# .anim-state input {
#     margin: 0;
#     vertical-align: middle;
# }
# </style>
#
# <div class="animation">
#   <img id="_anim_img07ab0ae7b9634769a4dae22af428452a">
#   <div class="anim-controls">
#     <input id="_anim_slider07ab0ae7b9634769a4dae22af428452a" type="range" class="anim-slider"
#            name="points" min="0" max="1" step="1" value="0"
#            oninput="anim07ab0ae7b9634769a4dae22af428452a.set_frame(parseInt(this.value));">
#     <div class="anim-buttons">
#       <button title="Decrease speed" aria-label="Decrease speed" onclick="anim07ab0ae7b9634769a4dae22af428452a.slower()">
#           <i class="fa fa-minus"></i></button>
#       <button title="First frame" aria-label="First frame" onclick="anim07ab0ae7b9634769a4dae22af428452a.first_frame()">
#         <i class="fa fa-fast-backward"></i></button>
#       <button title="Previous frame" aria-label="Previous frame" onclick="anim07ab0ae7b9634769a4dae22af428452a.previous_frame()">
#           <i class="fa fa-step-backward"></i></button>
#       <button title="Play backwards" aria-label="Play backwards" onclick="anim07ab0ae7b9634769a4dae22af428452a.reverse_animation()">
#           <i class="fa fa-play fa-flip-horizontal"></i></button>
#       <button title="Pause" aria-label="Pause" onclick="anim07ab0ae7b9634769a4dae22af428452a.pause_animation()">
#           <i class="fa fa-pause"></i></button>
#       <button title="Play" aria-label="Play" onclick="anim07ab0ae7b9634769a4dae22af428452a.play_animation()">
#           <i class="fa fa-play"></i></button>
#       <button title="Next frame" aria-label="Next frame" onclick="anim07ab0ae7b9634769a4dae22af428452a.next_frame()">
#           <i class="fa fa-step-forward"></i></button>
#       <button title="Last frame" aria-label="Last frame" onclick="anim07ab0ae7b9634769a4dae22af428452a.last_frame()">
#           <i class="fa fa-fast-forward"></i></button>
#       <button title="Increase speed" aria-label="Increase speed" onclick="anim07ab0ae7b9634769a4dae22af428452a.faster()">
#           <i class="fa fa-plus"></i></button>
#     </div>
#     <form title="Repetition mode" aria-label="Repetition mode" action="#n" name="_anim_loop_select07ab0ae7b9634769a4dae22af428452a"
#           class="anim-state">
#       <input type="radio" name="state" value="once" id="_anim_radio1_07ab0ae7b9634769a4dae22af428452a"
#              >
#       <label for="_anim_radio1_07ab0ae7b9634769a4dae22af428452a">Once</label>
#       <input type="radio" name="state" value="loop" id="_anim_radio2_07ab0ae7b9634769a4dae22af428452a"
#              checked>
#       <label for="_anim_radio2_07ab0ae7b9634769a4dae22af428452a">Loop</label>
#       <input type="radio" name="state" value="reflect" id="_anim_radio3_07ab0ae7b9634769a4dae22af428452a"
#              >
#       <label for="_anim_radio3_07ab0ae7b9634769a4dae22af428452a">Reflect</label>
#     </form>
#   </div>
# </div>
#
#
# <script language="javascript">
#   /* Instantiate the Animation class. */
#   /* The IDs given should match those used in the template above. */
#   (function() {
#     var img_id = "_anim_img07ab0ae7b9634769a4dae22af428452a";
#     var slider_id = "_anim_slider07ab0ae7b9634769a4dae22af428452a";
#     var loop_select_id = "_anim_loop_select07ab0ae7b9634769a4dae22af428452a";
#     var frames = new Array(25);
#
#   frames[0] = "...\
# bGliIHZlcnNpb24zLjEwLjgsIGh0dHBzOi8vbWF0cGxvdGxpYi5vcmcvwVt1zgAAAAlwSFlzAAAP\
# YQAAD2EBqD+naQAAYMRJR

# %%
# uncomment to save to file
# ani.save("/users/twhughes/Desktop/apodized_grating_coupler.gif", fps=10)

# %%
history_min = [[] for _ in range(len(params_history))]
history_max = [[] for _ in range(len(params_history))]

for i, params in enumerate(params_history):
    sim = make_2d_sim(params)
    for geometry in sim.structures[2].geometry.geometries:
        (xmin, _, _), (xmax, _, _) = geometry.bounds
        history_min[i].append(xmin)
        history_max[i].append(xmax)
        # print(i, j)

history_min = np.array(history_min).T
history_max = np.array(history_max).T

# %%
from matplotlib.pyplot import fill_between

xs = np.arange(len(params_history))

_, ax = plt.subplots()

for y1, y2 in zip(history_min, history_max):
    fill_between(xs, y1, y2)

plt.xlabel("iteration number")
plt.ylabel("x position")
plt.title("tooth position and width over optimization")

plt.show()
