# %% [markdown]
# # Broadband polarizer assisted by anisotropic metamaterial

# %% [markdown]
# Silicon photonic polarizers are specialized optical devices designed to filter, control, and manipulate the polarization state of light in integrated photonic circuits. Comprising carefully engineered silicon waveguide structures, these polarizers play a crucial role in ensuring the efficient and reliable operation of various optical communication and sensing systems. Over the years, various silicon photonic polarizer designs have been proposed. However, most designs suffer from a narrow working bandwidth or a large device footprint.
#
# A polarizer design demonstrated by `Hongnan Xu, Daoxin Dai, and Yaocheng Shi, "Anisotropic metamaterial-assisted all-silicon polarizer with 415-nm bandwidth," *Photon. Res.* 7, 1432-1439 (2019)`, [DOI: 10.1364/PRJ.7.001432](https://doi.org/10.1364/PRJ.7.001432) utilizes anisotropic subwavelength grating (SWG) metamaterial cladding to a 180 degree waveguide bend. This polarizer design preserves the TE mode and filters out TM mode in a broad wavelength range of 400 nm. The footprint of the device is also more compact than many of the previous designs.
#
# <img src="img/swg_polarizer.png" width="500" alt="Schematic of the polarizer">
#
# For more integrated photonic examples such as the [8-Channel mode and polarization de-multiplexer](https://www.flexcompute.com/tidy3d/examples/notebooks/8ChannelDemultiplexer/), the [broadband bi-level taper polarization rotator-splitter](https://www.flexcompute.com/tidy3d/examples/notebooks/BilevelPSR/), and the [broadband directional coupler](https://www.flexcompute.com/tidy3d/examples/notebooks/BroadbandDirectionalCoupler/), please visit our [examples page](https://www.flexcompute.com/tidy3d/examples/).
#
# If you are new to the finite-difference time-domain (FDTD) method, we highly recommend going through our [FDTD101](https://www.flexcompute.com/fdtd101/) tutorials.

# %%
import gdstk
import matplotlib.pyplot as plt
import numpy as np
import tidy3d as td
import tidy3d.web as web

# %% [markdown]
# ## Effective Anisotropic Refractive Index Tensor of the SWG

# %% [markdown]
# For this device, first we are going to make a regular 180 degree waveguide bend. In the bending region, we are going to add an SWG metamaterial parallel to the bend. The SWG metamaterial acts as an effective medium with an anisotropic refractive index tensor. The ordinary and extraordinary refractive indices are given by the well known Rytov's approximation: $1/n_e^2=f/n_{si}^2+(1-f)/n_{air}^2$ and $n_o^2=fn_{si}^2+(1-f)n_{air}^2$, where $f$ is the duty cycle of the SWG. We can investigate how the effective indices vary with $f$.
#
# From the result, we notice that $n_0$ is much larger than $n_e$ when $f$ is not close to 0 or 1. Since the TE waveguide mode has the electric field primarily in the extraordinary direction while the TM mode has the electric field primarily in the ordinary direction, they will feel very different refractive index in the SWG metamaterial. For TE mode, the refractive index is much lower than $n_{si}$ so it should stay guided inside the waveguide. For TM mode, on the other hand, the effective refractive index is close to $n_{si}$ so it will be guided into the SWG metamaterial region and radiates out. This way, the waveguide bend together with the SWG metamaterial functions as a polarizer that passes TE mode and suppresses TM mode.
#
# For a more detailed discussion, please refer to the [reference](https://doi.org/10.1364/PRJ.7.001432).

# %%
n_si = 3.47

f = np.linspace(0, 1, 30)
n_e = np.sqrt(1 / (f / n_si**2 + (1 - f)))
n_o = np.sqrt(f * n_si**2 + (1 - f))
plt.plot(f, n_e, label="$n_e$")
plt.plot(f, n_o, label="$n_o$")
plt.xlabel("$f$")
plt.ylabel("Effective index")
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_11893/1097417752.py:11: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Structure Setup

# %% [markdown]
# The simulation wavelength range is from 1260 nm to 1675 nm.

# %%
lda_min = 1.26  # minimal wavelength
lda_max = 1.675  # maximal wavelength
lda0 = (lda_min + lda_max) / 2  # central wavelength
freqs = np.linspace(td.C_0 / lda_max, td.C_0 / lda_min, 301)  # frequency range
freq0 = td.C_0 / lda0  # central frequency

fwidth = 0.4 * (td.C_0 / lda_min - td.C_0 / lda_max)  # width of the frequency range of the source

# %% [markdown]
# Next, we define the media used in the simulation. Since the simulation is very broadband, it is better to use dispersive media. We can use the crystalline silicon and silicon dioxide from Tidy3D's built-in [material library](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/material_library.html).

# %%
si = td.material_library["cSi"]["Li1993_293K"]
sio2 = td.material_library["SiO2"]["Horiba"]

# %% [markdown]
# The silicon layer has a thickness of 250 nm. To stay at single mode operation, the waveguide width is chosen to be 360 nm. The design parameters such as waveguide bend radius, period of the SWG, maximal and minimal duty cycles, and the number of SWG layers need to be optimized for the design. This is explored in the [reference](https://doi.org/10.1364/PRJ.7.001432). Here we report the optimized parameters.

# %%
h_si = 0.25  # silicon layer thickness
w_wg = 0.36  # waveguide width
R_0 = 3.5  # radius of the waveguide bend
p = 0.3  # period of the SWG
f_M = 0.75  # maximal duty cycle
f_m = 0.2  # minimal duty cycle
N = 9  # number of SWG layers
inf_eff = 1e3  # effective infinity

# %% [markdown]
# The radius of the $i$-th SWG layer is given by $R_i = R_0 + w_wg/2 + p(i-1/2)$ and the duty cycle of the layer is also given by a linear ramping $f_i=f_M+(f_m-f_M)(i-1)/(N-1)$. The width of the waveguide in each SWG layer is thus given by $pf_i$.

# %%
R_is = [R_0 + w_wg / 2 + p * (i - 0.5) for i in range(1, N + 1)]  # radius of each SWG layer
f_is = [
    f_M + (f_m - f_M) * (i - 1) / (N - 1) for i in range(1, N + 1)
]  # duty cycle of each SWG layer
w_is = [p * f for f in f_is]  # waveguide width of each SWG layer

# insert the circular waveguide band into the list
R_is.insert(0, R_0)
w_is.insert(0, w_wg)

# %% [markdown]
# With all the parameters determined, we can set up the geometries. One easy way is to make use of the `gdstk` library as demonstrated below.

# %%
cell = gdstk.Cell("SWG")  # define a gds cell

# define a path of each swg layer
for R_i, w_i in zip(R_is, w_is):
    points_x = np.linspace(-R_i, R_i, 1001)  # x coordinates of the waveguide in the swg layer
    points_y = np.sqrt(R_i**2 - points_x**2)  # y coordinates

    # if it's the innermost waveguide bend, add two points to the coordinates to include the straight waveguides
    if R_i == R_0:
        points_x = np.insert(points_x, 0, -R_0)
        points_y = np.insert(points_y, 0, -inf_eff)
        points_x = np.append(points_x, R_0)
        points_y = np.append(points_y, -inf_eff)

    points = points_x + 1j * points_y

    # add the path to the cell
    cell.add(gdstk.FlexPath(points, w_i, layer=1, datatype=0))

# %%
# define geometry from the paths in the cell
device_geo = td.PolySlab.from_gds(
    cell,
    gds_layer=1,
    axis=2,
    slab_bounds=(0, h_si),
)

# %% [markdown]
# To make sure the geometries are defined correctly, we can plot them first. From the plot, it indeed looks like the correct device.

# %%
l_straight = 4
pad = lda0

fig, ax = plt.subplots()
for geo in device_geo:
    geo.plot(z=h_si / 2, ax=ax)
ax.set_ylim(-l_straight, R_is[-1] + pad)
ax.set_xlim(-R_is[-1] - pad, R_is[-1] + pad)
plt.show()
# Out:
# /tmp/ipykernel_11893/106335976.py:9: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# Lastly, we define Tidy3D [Structures](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Structure.html) from the geometries. A silicon dioxide substrate structure is also defined.

# %%
device_structure = [td.Structure(geometry=geo, medium=si) for geo in device_geo]
substrate = td.Structure(
    geometry=td.Box.from_bounds(rmin=(-inf_eff, -inf_eff, -inf_eff), rmax=(inf_eff, inf_eff, 0)),
    medium=sio2,
)

# %% [markdown]
# ## TE Input Simulation

# %% [markdown]
# To fully characterize the device performance, we need to simulate two cases: TE input and TM input. First, let's set up the simulation for the TE input. A [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeSource.html) is defined to inject the TE mode at the input waveguide by setting `mode_index=0`. Note that since the simulation is quite broadband, we use a broadband source by setting `num_freqs = 10`, which accounts for the frequency-dependent mode profile.

# %%
# define a mode source that injects the fundamental te mode
mode_spec = td.ModeSpec(num_modes=2, target_neff=n_si)
mode_source = td.ModeSource(
    center=(-R_0, -l_straight / 2, h_si / 2),
    size=(4 * w_wg, 0, 4 * h_si),
    source_time=td.GaussianPulse(freq0=freq0, fwidth=fwidth),
    direction="+",
    mode_spec=mode_spec,
    mode_index=0,
    num_freqs=10,
)

# define a mode monitor to measure the transmission of the mode
mode_monitor = td.ModeMonitor(
    center=(R_0, -l_straight * 0.9, h_si / 2),
    size=mode_source.size,
    freqs=freqs,
    mode_spec=mode_spec,
    name="mode",
)

lda_field = 1.55  # frequency at which field is monitored

# define a field monitor to visualize mode propagation
field_monitor = td.FieldMonitor(
    center=(0, 0, h_si / 2), size=(td.inf, td.inf, 0), freqs=[td.C_0 / lda_field], name="field"
)

# %% [markdown]
# Define a Tidy3D [Simulation](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Simulation.html).

# %%
# simulation domain size
Lx = 2 * (R_is[-1] + pad)
Ly = l_straight + R_is[-1] + pad
Lz = 8 * h_si

run_time = 1e-12  # simulation run time

# define a simulation
sim_te = td.Simulation(
    center=(0, 0.5 * (R_is[-1] + pad - l_straight), 0),
    size=(Lx, Ly, Lz),
    grid_spec=td.GridSpec.auto(min_steps_per_wvl=20, wavelength=lda0),
    structures=device_structure + [substrate],
    sources=[mode_source],
    monitors=[mode_monitor, field_monitor],
    run_time=run_time,
)
# Out:
# 10:19:52 CEST WARNING: A structure has a nonzero dimension along axis y, which
#               is however too small compared to the generated mesh step along
#               that direction. This could produce unpredictable results. We
#               recommend increasing the resolution, or adding a mesh override
#               structure to ensure that all geometries are at least one pixel
#               thick along all dimensions.
#               WARNING: Suppressed 7 WARNING messages.

# %% [markdown]
# Visualize the simulation setup before submitting it to the server.

# %%
sim_te.plot(z=h_si / 2)
plt.show()
# Out:
# /tmp/ipykernel_11893/3717937267.py:2: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# Submit the simulation to the server.

# %%
job = web.Job(simulation=sim_te, task_name="TE_mode")
sim_data_te = job.run(path="data/simulation_data.hdf5")
# Out:
# 10:19:53 CEST Created task 'TE_mode' with task_id
#               'fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=672656;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=209489;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\taskId]8;;\]8;id=672656;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\=]8;;\]8;id=474565;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\fdve]8;;\]8;id=672656;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\-2660adab-92]8;;\
#               ]8;id=672656;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\b4-44f4-8914-fb2cbe218e0f']8;;\.
# 10:19:54 CEST Task folder: ]8;id=762472;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 100.0% • 171.6/171.6 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:19:58 CEST Maximum FlexCredit cost: 0.396. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:19:59 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 10:20:13 CEST status = preprocess
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🚶  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# 🏃  Waiting for 'TE_mode'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:20:19 CEST starting up solver
# 10:20:20 CEST running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 1.22e-05) ━━━━━━━━━━━━━╸━━━━━━━━━━━━  52% -:--:--
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━╸━━━━━━━━━━━  56% 0:00:19
# 10:20:44 CEST early shutoff detected at 56%, exiting.
# solver progress (field decay = 5.41e-06) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = postprocess
# Output()
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 10:20:47 CEST status = success
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# 🚶  Finishing 'TE_mode'...
# 🏃  Finishing 'TE_mode'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:20:49 CEST View simulation result at
#               ]8;id=745682;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=472110;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\taskId]8;;\]8;id=745682;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\=]8;;\]8;id=935687;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\fdve]8;;\]8;id=745682;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\-2660adab-92]8;;\
#               ]8;id=745682;https://tidy3d.simulation.cloud/workbench?taskId=fdve-2660adab-92b4-44f4-8914-fb2cbe218e0f\b4-44f4-8914-fb2cbe218e0f']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 1.5% • 0.3/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 1.5% • 0.3/17.0 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━ 3.1% • 0.5/17.0 MB • 1.0 MB/s • 0:00:16
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━ 3.1% • 0.5/17.0 MB • 1.0 MB/s • 0:00:16
# ↓ simulation_data.hdf5.gz ╸━━━━━━━━━━━━━ 6.2% • 1.0/17.0 MB • 1.5 MB/s • 0:00:11
# ↓ simulation_data.hdf5.gz ━╺━━━━━━━━━━━━ 7.7% • 1.3/17.0 MB • 1.8 MB/s • 0:00:09
# ↓ simulation_data.hdf5.gz ━╸━━━━━━━━━━━ 12.3% • 2.1/17.0 MB • 2.6 MB/s • 0:00:06
# ↓ simulation_data.hdf5.gz ━━╺━━━━━━━━━━ 15.4% • 2.6/17.0 MB • 2.8 MB/s • 0:00:06
# ↓ simulation_data.hdf5.gz ━━╺━━━━━━━━━━ 18.5% • 3.2/17.0 MB • 3.1 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━━╸━━━━━━━━━━ 20.0% • 3.4/17.0 MB • 3.2 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━━╸━━━━━━━━━━ 21.6% • 3.7/17.0 MB • 3.2 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━━━╺━━━━━━━━━ 23.1% • 3.9/17.0 MB • 3.1 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━━━╺━━━━━━━━━ 26.2% • 4.5/17.0 MB • 3.0 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━━━╸━━━━━━━━━ 29.3% • 5.0/17.0 MB • 3.2 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━╺━━━━━━━━ 32.3% • 5.5/17.0 MB • 3.3 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━╺━━━━━━━━ 33.9% • 5.8/17.0 MB • 3.3 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━╸━━━━━━━━ 37.0% • 6.3/17.0 MB • 3.4 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━━ 38.5% • 6.6/17.0 MB • 3.4 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━━ 40.0% • 6.8/17.0 MB • 3.4 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━━ 41.6% • 7.1/17.0 MB • 3.3 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━━ 41.6% • 7.1/17.0 MB • 3.3 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━╸━━━━━━━ 44.6% • 7.6/17.0 MB • 3.1 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━━━╺━━━━━━ 46.2% • 7.9/17.0 MB • 3.1 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━╺━━━━━━ 47.7% • 8.1/17.0 MB • 3.1 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━ 50.8% • 8.7/17.0 MB • 3.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 53.9% • 9.2/17.0 MB • 3.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 55.4% • 9.4/17.0 MB • 3.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 56.9% • 9.7/17.0 MB • 3.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 56.9% • 9.7/17.0 MB • 3.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 56.9% • 9.7/17.0 MB • 3.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 56.9% • 9.7/17.0 MB • 3.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 58.5% • 10.0/17.0 MB • 2.9 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 58.5% • 10.0/17.0 MB • 2.9 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.0% • 10.2/17.0 MB • 2.7 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.0% • 10.2/17.0 MB • 2.7 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.0% • 10.2/17.0 MB • 2.7 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.0% • 10.2/17.0 MB • 2.7 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 61.6% • 10.5/17.0 MB • 2.6 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 61.6% • 10.5/17.0 MB • 2.6 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 63.1% • 10.8/17.0 MB • 2.5 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 63.1% • 10.8/17.0 MB • 2.5 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 64.6% • 11.0/17.0 MB • 2.4 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 64.6% • 11.0/17.0 MB • 2.4 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 66.2% • 11.3/17.0 MB • 2.4 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 66.2% • 11.3/17.0 MB • 2.4 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 67.7% • 11.5/17.0 MB • 2.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 67.7% • 11.5/17.0 MB • 2.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 69.2% • 11.8/17.0 MB • 2.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 69.2% • 11.8/17.0 MB • 2.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 70.8% • 12.1/17.0 MB • 2.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 70.8% • 12.1/17.0 MB • 2.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 72.3% • 12.3/17.0 MB • 2.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 72.3% • 12.3/17.0 MB • 2.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 73.9% • 12.6/17.0 MB • 2.1 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 73.9% • 12.6/17.0 MB • 2.1 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 75.4% • 12.9/17.0 MB • 2.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 76.9% • 13.1/17.0 MB • 2.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 78.5% • 13.4/17.0 MB • 2.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 78.5% • 13.4/17.0 MB • 2.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 80.0% • 13.6/17.0 MB • 2.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 80.0% • 13.6/17.0 MB • 2.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 81.5% • 13.9/17.0 MB • 2.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 83.1% • 14.2/17.0 MB • 2.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 83.1% • 14.2/17.0 MB • 2.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 84.6% • 14.4/17.0 MB • 2.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 86.2% • 14.7/17.0 MB • 2.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 86.2% • 14.7/17.0 MB • 2.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 87.7% • 15.0/17.0 MB • 2.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.2% • 15.2/17.0 MB • 2.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 15.5/17.0 MB • 2.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 92.3% • 15.7/17.0 MB • 2.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.8% • 16.0/17.0 MB • 2.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.4% • 16.3/17.0 MB • 2.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.4% • 16.3/17.0 MB • 2.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 98.5% • 16.8/17.0 MB • 2.0 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━ 100.0% • 17.0/17.0   • 2.0 MB/s • 0:00:00
#                                                 MB
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━ 100.0% • 17.0/17.0   • 2.0 MB/s • 0:00:00
#                                                 MB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:21:00 CEST loading simulation from data/simulation_data.hdf5
# 10:21:01 CEST WARNING: A structure has a nonzero dimension along axis y, which
#               is however too small compared to the generated mesh step along
#               that direction. This could produce unpredictable results. We
#               recommend increasing the resolution, or adding a mesh override
#               structure to ensure that all geometries are at least one pixel
#               thick along all dimensions.
# 10:21:02 CEST WARNING: Suppressed 7 WARNING messages.
#               WARNING: Warning messages were found in the solver log. For more
#               information, check 'SimulationData.log' or use
#               'web.download_log(task_id)'.

# %% [markdown]
# ## TM Input Simulation

# %% [markdown]
# Before analyzing the simulation result for the TE input case, let's run the TM input case first. To have a TM input simulation, we only need to update the `mode_index` to `1` in the [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeSource.html). This can be done easily by copying the previous simulation.

# %%
mode_source = mode_source.copy(
    update={"mode_index": 1}
)  # copy the mode source and update mode_index
sim_tm = sim_te.copy(update={"sources": [mode_source]})  # copy the simulation and update the source

job = web.Job(simulation=sim_tm, task_name="TM_mode")
sim_data_tm = job.run(path="data/simulation_data.hdf5")
# Out:
#               WARNING: A structure has a nonzero dimension along axis y, which
#               is however too small compared to the generated mesh step along
#               that direction. This could produce unpredictable results. We
#               recommend increasing the resolution, or adding a mesh override
#               structure to ensure that all geometries are at least one pixel
#               thick along all dimensions.
#               WARNING: Suppressed 7 WARNING messages.
#               Created task 'TM_mode' with task_id
#               'fdve-6c48848d-3579-42ba-849d-5e4b7cc06099' and task_type 'FDTD'.
#               View task using web UI at
#               ]8;id=372477;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=23812;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\taskId]8;;\]8;id=372477;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\=]8;;\]8;id=753299;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\fdve]8;;\]8;id=372477;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\-6c48848d-35]8;;\
#               ]8;id=372477;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\79-42ba-849d-5e4b7cc06099']8;;\.
#               Task folder: ]8;id=906109;https://tidy3d.simulation.cloud/folders/9b36e144-ddb6-41f8-8dd8-30b62b26a870\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/171.6 kB • ? • -:--:--
# ↑ simulation.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 100.0% • 171.6/171.6 kB • ? • 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:21:06 CEST Maximum FlexCredit cost: 0.396. Minimum cost depends on task
#               execution details. Use 'web.real_cost(task_id)' to get the billed
#               FlexCredit cost after a simulation run.
# 10:21:07 CEST status = queued
#               To cancel the simulation, use 'web.abort(task_id)' or
#               'web.delete(task_id)' or abort/delete the task in the web UI.
#               Terminating the Python script will not stop the job running on the
#               cloud.
# Output()
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 10:21:21 CEST status = preprocess
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🏃  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# 🚶  Waiting for 'TM_mode'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:21:25 CEST starting up solver
# 10:21:26 CEST running solver
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# % done ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 0.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 1.00e+00) ━━━━━━━━━━━━━━━━━━━━━━━━━━   0% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 7.82e-02) ━━━━━━╺━━━━━━━━━━━━━━━━━━━  24% -:--:--
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 1.89e-05) ━━━━━━━━━━━━━━━━━╸━━━━━━━━  68% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━╸━━━━━━━  72% 0:00:08
# 10:22:04 CEST early shutoff detected at 72%, exiting.
# solver progress (field decay = 7.61e-06) ━━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:00
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
#               status = postprocess
# Output()
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 10:22:09 CEST status = success
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# 🚶  Finishing 'TM_mode'...
# 🏃  Finishing 'TM_mode'...
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:22:11 CEST View simulation result at
#               ]8;id=173973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=912630;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\taskId]8;;\]8;id=173973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\=]8;;\]8;id=20498;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\fdve]8;;\]8;id=173973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\-6c48848d-35]8;;\
#               ]8;id=173973;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6c48848d-3579-42ba-849d-5e4b7cc06099\79-42ba-849d-5e4b7cc06099']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 0.0% • 0.0/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 1.5% • 0.3/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━━━━━━━━━━ 1.5% • 0.3/17.1 MB • ? • -:--:--
# ↓ simulation_data.hdf5.gz ╸━━━━━━━━━━━━━ 4.6% • 0.8/17.1 MB • 2.0 MB/s • 0:00:09
# ↓ simulation_data.hdf5.gz ╸━━━━━━━━━━━━━ 6.1% • 1.0/17.1 MB • 2.1 MB/s • 0:00:08
# ↓ simulation_data.hdf5.gz ━╺━━━━━━━━━━━━ 7.7% • 1.3/17.1 MB • 2.4 MB/s • 0:00:07
# ↓ simulation_data.hdf5.gz ━╺━━━━━━━━━━━ 10.7% • 1.8/17.1 MB • 2.7 MB/s • 0:00:06
# ↓ simulation_data.hdf5.gz ━╸━━━━━━━━━━━ 15.3% • 2.6/17.1 MB • 3.4 MB/s • 0:00:05
# ↓ simulation_data.hdf5.gz ━━╺━━━━━━━━━━ 18.4% • 3.1/17.1 MB • 3.6 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━╸━━━━━━━━━━ 21.5% • 3.7/17.1 MB • 3.8 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━╸━━━━━━━━━━ 23.0% • 3.9/17.1 MB • 3.6 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━╺━━━━━━━━━ 26.3% • 4.5/17.1 MB • 3.8 MB/s • 0:00:04
# ↓ simulation_data.hdf5.gz ━━━━╺━━━━━━━━ 30.9% • 5.3/17.1 MB • 4.0 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━╺━━━━━━━━ 34.0% • 5.8/17.1 MB • 4.1 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━━ 38.6% • 6.6/17.1 MB • 4.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━╺━━━━━━━ 41.7% • 7.1/17.1 MB • 4.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━╸━━━━━━━ 44.7% • 7.6/17.1 MB • 4.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━╸━━━━━━━ 44.7% • 7.6/17.1 MB • 4.3 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━╺━━━━━━ 47.8% • 8.2/17.1 MB • 4.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━ 50.9% • 8.7/17.1 MB • 4.2 MB/s • 0:00:03
# ↓ simulation_data.hdf5.gz ━━━━━━╸━━━━━━ 52.4% • 9.0/17.1 MB • 4.2 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 54.0% • 9.2/17.1 MB • 4.2 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 55.5% • 9.5/17.1 MB • 4.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━━ 57.0% • 9.7/17.1 MB • 4.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.1% • 10.3/17.1 MB • 3.9 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.1% • 10.3/17.1 MB • 3.9 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╺━━━━ 60.1% • 10.3/17.1 MB • 3.9 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 64.7% • 11.0/17.1 MB • 3.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 64.7% • 11.0/17.1 MB • 3.8 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 66.2% • 11.3/17.1 MB • 3.6 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━╸━━━━ 66.2% • 11.3/17.1 MB • 3.6 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 67.8% • 11.6/17.1 MB • 3.5 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━╺━━━ 69.3% • 11.8/17.1 MB • 3.4 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 70.8% • 12.1/17.1 MB • 3.3 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 70.8% • 12.1/17.1 MB • 3.3 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 72.4% • 12.4/17.1 MB • 3.3 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━╸━━━ 73.9% • 12.6/17.1 MB • 3.2 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 75.4% • 12.9/17.1 MB • 3.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 75.4% • 12.9/17.1 MB • 3.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 77.0% • 13.1/17.1 MB • 3.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 78.5% • 13.4/17.1 MB • 3.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╺━━ 78.5% • 13.4/17.1 MB • 3.1 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 80.0% • 13.7/17.1 MB • 3.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 81.6% • 13.9/17.1 MB • 3.0 MB/s • 0:00:02
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 83.1% • 14.2/17.1 MB • 2.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━╸━━ 83.1% • 14.2/17.1 MB • 2.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 84.7% • 14.5/17.1 MB • 2.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╺━ 86.2% • 14.7/17.1 MB • 2.9 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 87.7% • 15.0/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 87.7% • 15.0/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 89.3% • 15.2/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━╸━ 90.8% • 15.5/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 92.3% • 15.8/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 93.9% • 16.0/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.4% • 16.3/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╺ 95.4% • 16.3/17.1 MB • 2.8 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 96.9% • 16.6/17.1 MB • 2.7 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━╸ 98.5% • 16.8/17.1 MB • 2.7 MB/s • 0:00:01
# ↓ simulation_data.hdf5.gz ━━━━━━━━━━━━ 100.0% • 17.1/17.1   • 2.7 MB/s • 0:00:00
#                                                 MB
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:22:20 CEST loading simulation from data/simulation_data.hdf5
# 10:22:21 CEST WARNING: A structure has a nonzero dimension along axis y, which
#               is however too small compared to the generated mesh step along
#               that direction. This could produce unpredictable results. We
#               recommend increasing the resolution, or adding a mesh override
#               structure to ensure that all geometries are at least one pixel
#               thick along all dimensions.
#               WARNING: Suppressed 7 WARNING messages.
#               WARNING: Warning messages were found in the solver log. For more
#               information, check 'SimulationData.log' or use
#               'web.download_log(task_id)'.

# %% [markdown]
# ## Result Analysis

# %% [markdown]
# Now that both simulations are complete, let's visualize the results. First, we plot the transmission spectra. We see that in the TE input, transmission is close to 0 dB while in the TM input case, transmission is below -20 dB. This is the desirable outcome for a polarizer.

# %%
amp_te = sim_data_te["mode"].amps.sel(mode_index=0, direction="-")
T_te = np.abs(amp_te) ** 2

amp_tm = sim_data_tm["mode"].amps.sel(mode_index=1, direction="-")
T_tm = np.abs(amp_tm) ** 2

plt.plot(td.C_0 / freqs, 10 * np.log10(T_te), label="TE input")
plt.plot(td.C_0 / freqs, 10 * np.log10(T_tm), label="TM input")
plt.xlabel(r"Wavelength ($\mu m$)")
plt.ylabel("Transmission (dB)")
plt.ylim(-35, 0)
plt.xlim(lda_min, lda_max)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_11893/867540343.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# We go on to plot the field distributions at 1550 nm in the two simulations. The TE mode (left plot) stays guided inside the waveguide bend and thus the transmission is high. The TM mode (right plot), on the other hand, is leaked into the SWG metamaterial region and radiates to free space eventually, leading to a low transmission.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
sim_data_te.plot_field(field_monitor_name="field", field_name="Hz", vmin=-0.7, vmax=0.7, ax=ax1)
sim_data_tm.plot_field(field_monitor_name="field", field_name="Ez", vmin=-40, vmax=40, ax=ax2)
ax1.set_title("Hz at 1550 nm (TE input)")
ax2.set_title("Ez at 1550 nm (TM input)")
plt.show()
# Out:
# /tmp/ipykernel_11893/1567095134.py:6: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %% [markdown]
# ## Reference Simulations without SWG

# %% [markdown]
# As a comparison, we can run a baseline reference and simulate the same waveguide bend without the SWG metamaterial cladding. We only need to copy the previous simulations and update the structure such that they don't contain the SWG.
#
# To further speed up the simulation, we put the TE and TM input cases into a batch and run them on the server simultaneously.

# %%
# copy previous simulations and update the structures
sim_te_ref = sim_te.copy(update={"structures": [device_structure[0], substrate]})
sim_tm_ref = sim_tm.copy(update={"structures": [device_structure[0], substrate]})

# make a batch and run it
sims = {
    "TE": sim_te_ref,
    "TM": sim_tm_ref,
}
batch = web.Batch(simulations=sims, verbose=True)
batch_results = batch.run(path_dir="data")
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:03
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# Uploading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━━  50% 0:00:04
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 10:22:32 CEST Started working on Batch containing 2 tasks.
# 10:22:35 CEST Maximum FlexCredit cost: 0.482 for the whole batch.
#               Use 'Batch.real_cost()' to get the billed FlexCredit cost after
#               the Batch has completed.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:00
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:01
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:02
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:03
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:04
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:05
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:06
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:07
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:08
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:09
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:10
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:11
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:12
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:13
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:14
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:15
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:16
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:17
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:18
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → queued        ━━━╺━━━━━━━━━━━━━━━━━━━━━  12% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:18
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:19
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:20
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:21
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:21
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → preprocess    ━━━━━━╺━━━━━━━━━━━━━━━━━━  25% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:22
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:23
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:24
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:25
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:26
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:27
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# TM              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:28
# ...
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:45
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:45
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:45
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:45
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:45
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:45
# TE              → running       ━━━━━━━━━━━━╸━━━━━━━━━━━━  50% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:45
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:45
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:45
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:46
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:47
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:48
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:48
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:49
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → postprocess   ━━━━━━━━━━━━━━━╸━━━━━━━━━  62% 0:00:50
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━╸━━━  88% 0:00:49
# TE              → success       ━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:50
# TM              → success       ━━━━━━━━━━━━━━━━━━━━━━━━━ 100% 0:00:49
# 10:23:25 CEST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:00
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:01
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:02
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:03
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:04
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:05
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:06
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:07
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:08
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:09
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━   0% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:10
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:11
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:11
# Downloading data for 2 tasks ━━━━━━━━━━━━━━━━━━━╺━━━━━━━━━━━━━━━━━━  50% 0:00:11
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>

# %% [markdown]
# Lastly, we plot the same results. Without SWG, we see that both the TE and TM mode transmissions are high. Adding the SWG indeed couples the TM mode out of the waveguide.

# %%
amp_te_ref = batch_results["TE"]["mode"].amps.sel(mode_index=0, direction="-")
T_te_ref = np.abs(amp_te_ref) ** 2

amp_tm_ref = batch_results["TM"]["mode"].amps.sel(mode_index=1, direction="-")
T_tm_ref = np.abs(amp_tm_ref) ** 2

plt.plot(td.C_0 / freqs, 10 * np.log10(T_te_ref), label="TE input")
plt.plot(td.C_0 / freqs, 10 * np.log10(T_tm_ref), label="TM input")
plt.xlabel(r"Wavelength ($\mu m$)")
plt.ylabel("Transmission (dB)")
plt.ylim(-35, 0)
plt.xlim(lda_min, lda_max)
plt.legend()
plt.show()
# Out:
# /tmp/ipykernel_11893/3142954107.py:14: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()

# %%
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(12, 3))
batch_results["TE"].plot_field(
    field_monitor_name="field", field_name="Hz", vmin=-0.7, vmax=0.7, ax=ax1
)
batch_results["TM"].plot_field(
    field_monitor_name="field", field_name="Ez", vmin=-40, vmax=40, ax=ax2
)
ax1.set_title("Hz at 1550 nm (TE input)")
ax2.set_title("Ez at 1550 nm (TM input)")
plt.show()
# Out:
# /tmp/ipykernel_11893/3712385668.py:10: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   plt.show()
