# %% [markdown]
# # 1x4 MMI power splitter

# %% [markdown]
# Note: the cost of running the entire notebook is larger than 1 FlexCredit.
#
# Optical power splitters are essential components in integrated photonics. Power splitters based on multimode interference (MMI) device are easy to fabricate and can achieve low excess loss as well as large bandwidth. Although the design of a MMI power splitter is based on the self-imaging principle, fine-tuning the geometric parameters with accurate and fast numerical simulations is crucial to achieving optimal device performance.
#
# This example aims to demonstrate the design and optimization of 1 to 4 MMI device at telecom wavelength for power splitting applications. The initial design is adapted from [D. Malka, Y. Danan, Y. Ramon, Z. Zalevsky, A Photonic 1 x 4 Power Splitter Based on Multimode Interference in Silicon–Gallium-Nitride Slot Waveguide Structures. Materials. 9, 516 (2016)](https://www.mdpi.com/1996-1944/9/7/516).
#
# The device uses a Si-GaN-Si slot waveguide strcuture as schematically shown below.
#
# <img src="img/mmi_schematic.png" width="300" alt="Schematic of the MMI">
#
# For more integrated photonic examples such as the [8-Channel mode and polarization de-multiplexer](https://www.flexcompute.com/tidy3d/examples/notebooks/8ChannelDemultiplexer/), the [broadband bi-level taper polarization rotator-splitter](https://www.flexcompute.com/tidy3d/examples/notebooks/BilevelPSR/), and the [broadband directional coupler](https://www.flexcompute.com/tidy3d/examples/notebooks/BroadbandDirectionalCoupler/), please visit our [examples page](https://www.flexcompute.com/tidy3d/examples/).
#
# If you are new to the finite-difference time-domain (FDTD) method, we highly recommend going through our [FDTD101](https://www.flexcompute.com/fdtd101/) tutorials.

# %% [markdown]
# ## Simulation Setup

# %%
import numpy as np
import matplotlib.pyplot as plt

import tidy3d as td
import tidy3d.web as web
from tidy3d.plugins.mode import ModeSolver

# %% [markdown]
# Define materials. There are three materials involved in this model. The SiO2 cladding and the Si waveguide with GaN slot. All materials are modeled as lossless and dispersionless in this particular case.

# %%
# material refractive indices
n_si = 3.48
n_gan = 2.305
n_sio2 = 1.444

# define media
si = td.Medium(permittivity=n_si**2)
gan = td.Medium(permittivity=n_gan**2)
sio2 = td.Medium(permittivity=n_sio2**2)

# %% [markdown]
# Define initial design parameters and wrap simulation setup in a function. The arguments of the function are the paremeters we want to optimize later. In this example, we aim to optimize the length and width of the MMI section.

# %%
W_MMI = 5  # width of the MMI section
L_MMI = 11.2  # length of the MMI section
g1 = 0.9  # gap between the output waveguides
W1 = 0.4  # width of the waveguide
W2 = 0.8  # width of the tapper
L1 = 2  # length of the input tapper
L2 = 5  # length of the output tapper
H_Si = 0.3  # thickness of the Si layer
H_GaN = 0.1  # thickness of the GaN layer
g3 = (W2 - W1) / 2  # auxilary parameter defined for easier geometry building
g2 = g1 - 2 * g3  # gap between the output tapers
lda0 = 1.55  # central wavelength
freq0 = td.C_0 / lda0  # central frequency
ldas = np.linspace(1.5, 1.6, 101)  # wavelength range
freqs = td.C_0 / ldas  # frequency range
fwidth = 0.5 * (np.max(freqs) - np.min(freqs))

# buffer spacings in the x and y directions.
buffer_x = 1
buffer_y = 1.5

# define a function that takes the geometric parameters as input arguments and return a Simulation object
def make_sim(L_MMI, W_MMI):
    # the whole device is defined as a PolySlab with vertices given by the following
    vertices = np.array(
        [
            (-W1 / 2, -100),
            (-W1 / 2, 0),
            (-W2 / 2, L1),
            (-W_MMI / 2, L1),
            (-W_MMI / 2, L1 + L_MMI),
            (-g2 / 2 - W2 - g2 - 2 * g3 - W1, L1 + L_MMI),
            (-g2 / 2 - W2 - g2 - g3 - W1, L1 + L_MMI + L2),
            (-g2 / 2 - W2 - g2 - g3 - W1, 100),
            (-g2 / 2 - W2 - g2 - g3, 100),
            (-g2 / 2 - W2 - g2 - g3, L1 + L_MMI + L2),
            (-g2 / 2 - W2 - g2, L1 + L_MMI),
            (-g2 / 2 - W2, L1 + L_MMI),
            (-g1 / 2 - W1, L1 + L_MMI + L2),
            (-g1 / 2 - W1, 100),
            (-g1 / 2, 100),
            (-g1 / 2, L1 + L_MMI + L2),
            (-g2 / 2, L1 + L_MMI),
            (g2 / 2, L1 + L_MMI),
            (g1 / 2, L1 + L_MMI + L2),
            (g1 / 2, 100),
            (g1 / 2 + W1, 100),
            (g1 / 2 + W1, L1 + L_MMI + L2),
            (g2 / 2 + W2, L1 + L_MMI),
            (g2 / 2 + W2 + g2, L1 + L_MMI),
            (g2 / 2 + W2 + g2 + g3, L1 + L_MMI + L2),
            (g1 / 2 + W1 + g1, 100),
            (g1 / 2 + W1 + g1 + W1, 100),
            (g2 / 2 + W2 + g2 + g3 + W1, L1 + L_MMI + L2),
            (g2 / 2 + W2 + g2 + 2 * g3 + W1, L1 + L_MMI),
            (W_MMI / 2, L1 + L_MMI),
            (W_MMI / 2, L1),
            (W2 / 2, L1),
            (W1 / 2, 0),
            (W1 / 2, -100),
        ]
    )

    mmi_layer1 = td.Structure(
        geometry=td.PolySlab(
            vertices=vertices,
            axis=2,
            slab_bounds=(-H_Si - 0.5 * H_GaN, H_Si + 0.5 * H_GaN),
        ),
        medium=si,
    )
    mmi_layer2 = td.Structure(
        geometry=td.PolySlab(
            vertices=vertices, axis=2, slab_bounds=(-0.5 * H_GaN, 0.5 * H_GaN)
        ),
        medium=gan,
    )

    # simulation domain size
    Lx = W_MMI + 2 * buffer_x
    Ly = L1 + L_MMI + L2 + 2 * buffer_y
    Lz = 5 * (H_GaN * 2 + H_Si)
    sim_size = (Lx, Ly, Lz)

    mode_spec = td.ModeSpec(num_modes=2, target_neff=n_si)

    # add a mode source for excitation
    mode_source = td.ModeSource(
        center=(0, -buffer_y / 3, 0),
        size=(5 * W1, 0, Lz),
        source_time=td.GaussianPulse(freq0=freq0, fwidth=fwidth),
        direction="+",
        mode_spec=mode_spec,
        mode_index=0,
        num_freqs=5,
    )

    # add two flux monitors to monitor the transmission power at output waveguides
    flux_monitor1 = td.FluxMonitor(
        center=((g1 + W1) / 2, Ly - buffer_y / 2, 0),
        size=(3 * W1, 0, Lz),
        freqs=freqs,
        name="flux1",
    )

    flux_monitor2 = td.FluxMonitor(
        center=(3 * (g1 + W1) / 2, Ly - buffer_y / 2, 0),
        size=(3 * W1, 0, Lz),
        freqs=freqs,
        name="flux2",
    )

    # add two mode monitors to monitor the mode profiles at output waveguides
    mode_monitor1 = td.ModeMonitor(
        center=((g1 + W1) / 2, Ly - buffer_y / 2, 0),
        size=(3 * W1, 0, Lz),
        freqs=freqs,
        mode_spec=mode_spec,
        name="mode1",
    )

    mode_monitor2 = td.ModeMonitor(
        center=(3 * (g1 + W1) / 2, Ly - buffer_y / 2, 0),
        size=(3 * W1, 0, Lz),
        freqs=freqs,
        mode_spec=mode_spec,
        name="mode2",
    )

    # add a field monitor to monitor the field distribution
    field_monitor = td.FieldMonitor(
        center=(0, 0, 0), size=(td.inf, td.inf, 0), freqs=[freq0], name="field"
    )

    sim = td.Simulation(
        center=(0, Ly / 2 - buffer_y / 2, 0),
        size=sim_size,
        grid_spec=td.GridSpec.auto(min_steps_per_wvl=20, wavelength=td.C_0 / freq0),
        structures=[mmi_layer1, mmi_layer2],
        sources=[mode_source],
        monitors=[
            field_monitor,
            flux_monitor1,
            flux_monitor2,
            mode_monitor1,
            mode_monitor2,
        ],
        run_time=5e-12,
        boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),
        medium=sio2,
        symmetry=(1, 0, -1),
    )
    return sim

# %% [markdown]
# ## Initial Design

# %% [markdown]
# First, we simulate an initial design using the previously defined design parameters.

# %%
f, (ax1, ax2) = plt.subplots(1, 2)
sim = make_sim(L_MMI, W_MMI)
sim.plot(z=0, ax=ax1)
sim.plot(y=-buffer_y / 3, ax=ax2)
plt.show()

# %% [markdown]
# Before simulation, let's inspect the waveguide modes supported in the slot waveguide to make sure we are using the correct excitation source.

# %%
mode_solver = ModeSolver(
    simulation=sim,
    plane=td.Box(center=sim.sources[0].center, size=sim.sources[0].size),
    mode_spec=sim.sources[0].mode_spec,
    freqs=[freq0],
)
mode_data = mode_solver.solve()
# Out:
# 22:03:25 PST WARNING: Use the remote mode solver with subpixel averaging for
#              better accuracy through 'tidy3d.plugins.mode.web.run(...)'.

# %% [markdown]
# The lowest order mode shows a strong field confinement between the Si area. This is the mode we want to use as excitation.

# %%
mode_index = 0

f, (ax1, ax2, ax3) = plt.subplots(1, 3, tight_layout=True, figsize=(10, 3))
abs(mode_data.Ex.isel(mode_index=mode_index)).plot(x="x", y="z", ax=ax1, cmap="magma")
abs(mode_data.Ey.isel(mode_index=mode_index)).plot(x="x", y="z", ax=ax2, cmap="magma")
abs(mode_data.Ez.isel(mode_index=mode_index)).plot(x="x", y="z", ax=ax3, cmap="magma")

ax1.set_title("|Ex(x, y)|")
ax1.set_aspect("equal")
ax2.set_title("|Ey(x, y)|")
ax2.set_aspect("equal")
ax3.set_title("|Ez(x, y)|")
ax3.set_aspect("equal")
plt.show()

# %% [markdown]
# Submit simulation job to the server.

# %%
job = web.Job(simulation=sim, task_name="mmi", verbose=True)
sim_data = job.run(path="data/simulation_data.hdf5")
# Out:
# 22:03:26 PST Created task 'mmi' with task_id
#              'fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=561001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=907616;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\taskId]8;;\]8;id=561001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\=]8;;\]8;id=41447;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\fdve]8;;\]8;id=561001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\-6e8459a5-a09]8;;\
#              ]8;id=561001;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\a-4a61-8a77-8ab2442ebd38']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:03:27 PST status = queued
# Output()
# 22:03:31 PST status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 22:03:34 PST Maximum FlexCredit cost: 0.289. Use 'web.real_cost(task_id)' to get
#              the billed FlexCredit cost after a simulation run.
#              starting up solver
#              running solver
#              To cancel the simulation, use 'web.abort(task_id)' or
#              'web.delete(task_id)' or abort/delete the task in the web UI.
#              Terminating the Python script will not stop the job running on the
#              cloud.
# Output()
# 22:05:06 PST early shutoff detected at 48%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              status = postprocess
# Output()
# 22:05:08 PST status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 22:05:09 PST View simulation result at
#              ]8;id=173563;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=176999;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\taskId]8;;\]8;id=173563;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\=]8;;\]8;id=552451;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\fdve]8;;\]8;id=173563;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\-6e8459a5-a09]8;;\
#              ]8;id=173563;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6e8459a5-a09a-4a61-8a77-8ab2442ebd38\a-4a61-8a77-8ab2442ebd38']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              loading simulation from data/simulation_data.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.

# %% [markdown]
# Visualize the field distribution.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, figsize=(10, 8))
sim_data.plot_field(
    field_monitor_name="field", field_name="E", val="abs^2", ax=ax1, f=freq0
)
sim_data.plot_field(field_monitor_name="field", field_name="Ez", ax=ax2, f=freq0)
plt.show()

# %% [markdown]
# Plot transmission on each output waveguide as well as the total excess loss. At the central wavelength of 1550 nm, the transimission power at the inner waveguide and outer waveguide differs by about 2%. The excess loss is about 0.4 dB.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))
T1 = sim_data["flux1"].flux
T2 = sim_data["flux2"].flux

plt.sca(ax1)
plt.plot(ldas, T1, ldas, T2)
plt.vlines(x=1.55, ymin=0.1, ymax=0.3, colors="black", ls="--")
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Transmission to output waveguide")
plt.legend(("Inner waveguide", "Outer waveguide"))

plt.sca(ax2)
excess_loss = -10 * np.log10(2 * (T1 + T2))
plt.plot(ldas, excess_loss)
plt.vlines(x=1.55, ymin=0, ymax=1, colors="black", ls="--")
plt.hlines(y=excess_loss[50], xmin=1.5, xmax=1.6, colors="black", ls="--")
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Excess loss (dB)")
plt.show()

# %% [markdown]
# We can use the mode monitor to inspect the composition of each mode at the output. For the outer waveguide, we can see that the fundamental mode is dominant.

# %%
mode_amp = sim_data["mode2"].amps.sel(direction="+")
mode_power = np.abs(mode_amp) ** 2 / T2
plt.plot(ldas, mode_power)
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Power share (%)")
plt.legend(["Mode 0", "Mode 1"])
plt.show()
# Out:
# 22:05:14 PST WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.

# %% [markdown]
# ## Optimization

# %% [markdown]
# Further tuning of the geometric parameters is likely to improve the device's performance further. We will perform a parameter sweep on two parameters to see if we can optimize the MMI. The goal is to achieve even power splitting among output waveguides while keeping the excess loss low.
#
# The length of the MMI is swept from 11.1 to 11.2 $\mu m$ in 50 nm step and the width from 4.8 to 5 $\mu m$ in 100 nm step. This results in a total of 9 simulations. Since this is just a demonstration model, we limit the total number of simulations for the sake of time. In practice, one can perform much larger parameter sweeps to cover a larger parameter space.

# %%
L_MMIs = np.linspace(11.1, 11.2, 3)  # MMI length varies from 11.1 to 11.2 um
W_MMIs = np.linspace(4.8, 5, 3)  # MMI width varies from 4.8 to 5 um

sims = {
    f"L_MMI={L_MMI:.2f};W_MMI={W_MMI:.2f}": make_sim(L_MMI, W_MMI)
    for L_MMI in L_MMIs
    for W_MMI in W_MMIs
}
batch = web.Batch(simulations=sims, verbose=True)
batch_results = batch.run(path_dir="data")
# Out:
#              Created task 'L_MMI=11.10;W_MMI=4.80' with task_id
#              'fdve-6d15615e-203a-4071-a14f-018ebaae97c8' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=582847;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6d15615e-203a-4071-a14f-018ebaae97c8\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=563192;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6d15615e-203a-4071-a14f-018ebaae97c8\taskId]8;;\]8;id=582847;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6d15615e-203a-4071-a14f-018ebaae97c8\=]8;;\]8;id=479016;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6d15615e-203a-4071-a14f-018ebaae97c8\fdve]8;;\]8;id=582847;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6d15615e-203a-4071-a14f-018ebaae97c8\-6d15615e-203]8;;\
#              ]8;id=582847;https://tidy3d.simulation.cloud/workbench?taskId=fdve-6d15615e-203a-4071-a14f-018ebaae97c8\a-4071-a14f-018ebaae97c8']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:05:15 PST Created task 'L_MMI=11.10;W_MMI=4.90' with task_id
#              'fdve-25487baf-bac7-4965-a65d-edefe1faf377' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=822786;https://tidy3d.simulation.cloud/workbench?taskId=fdve-25487baf-bac7-4965-a65d-edefe1faf377\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=481259;https://tidy3d.simulation.cloud/workbench?taskId=fdve-25487baf-bac7-4965-a65d-edefe1faf377\taskId]8;;\]8;id=822786;https://tidy3d.simulation.cloud/workbench?taskId=fdve-25487baf-bac7-4965-a65d-edefe1faf377\=]8;;\]8;id=633405;https://tidy3d.simulation.cloud/workbench?taskId=fdve-25487baf-bac7-4965-a65d-edefe1faf377\fdve]8;;\]8;id=822786;https://tidy3d.simulation.cloud/workbench?taskId=fdve-25487baf-bac7-4965-a65d-edefe1faf377\-25487baf-bac]8;;\
#              ]8;id=822786;https://tidy3d.simulation.cloud/workbench?taskId=fdve-25487baf-bac7-4965-a65d-edefe1faf377\7-4965-a65d-edefe1faf377']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              Created task 'L_MMI=11.10;W_MMI=5.00' with task_id
#              'fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=657908;https://tidy3d.simulation.cloud/workbench?taskId=fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=65246;https://tidy3d.simulation.cloud/workbench?taskId=fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee\taskId]8;;\]8;id=657908;https://tidy3d.simulation.cloud/workbench?taskId=fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee\=]8;;\]8;id=723574;https://tidy3d.simulation.cloud/workbench?taskId=fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee\fdve]8;;\]8;id=657908;https://tidy3d.simulation.cloud/workbench?taskId=fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee\-59e394a0-c6a]8;;\
#              ]8;id=657908;https://tidy3d.simulation.cloud/workbench?taskId=fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee\d-4bbe-8587-c7f51d6372ee']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:05:16 PST Created task 'L_MMI=11.15;W_MMI=4.80' with task_id
#              'fdve-d818859b-6c3c-45af-94a1-ffa278942dca' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=329340;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d818859b-6c3c-45af-94a1-ffa278942dca\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=18631;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d818859b-6c3c-45af-94a1-ffa278942dca\taskId]8;;\]8;id=329340;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d818859b-6c3c-45af-94a1-ffa278942dca\=]8;;\]8;id=850863;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d818859b-6c3c-45af-94a1-ffa278942dca\fdve]8;;\]8;id=329340;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d818859b-6c3c-45af-94a1-ffa278942dca\-d818859b-6c3]8;;\
#              ]8;id=329340;https://tidy3d.simulation.cloud/workbench?taskId=fdve-d818859b-6c3c-45af-94a1-ffa278942dca\c-45af-94a1-ffa278942dca']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              Created task 'L_MMI=11.15;W_MMI=4.90' with task_id
#              'fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=880081;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=776090;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080\taskId]8;;\]8;id=880081;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080\=]8;;\]8;id=945481;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080\fdve]8;;\]8;id=880081;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080\-fe572e26-1fb]8;;\
#              ]8;id=880081;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080\1-4ecc-bda1-7993b945f080']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:05:17 PST Created task 'L_MMI=11.15;W_MMI=5.00' with task_id
#              'fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=168310;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=1189;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7\taskId]8;;\]8;id=168310;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7\=]8;;\]8;id=153472;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7\fdve]8;;\]8;id=168310;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7\-5bfa533a-ad4]8;;\
#              ]8;id=168310;https://tidy3d.simulation.cloud/workbench?taskId=fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7\d-4afc-812f-782b89c9f3b7']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              Created task 'L_MMI=11.20;W_MMI=4.80' with task_id
#              'fdve-fe385657-c62c-4fb1-b17a-f90408094ef0' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=940618;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe385657-c62c-4fb1-b17a-f90408094ef0\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=755862;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe385657-c62c-4fb1-b17a-f90408094ef0\taskId]8;;\]8;id=940618;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe385657-c62c-4fb1-b17a-f90408094ef0\=]8;;\]8;id=581889;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe385657-c62c-4fb1-b17a-f90408094ef0\fdve]8;;\]8;id=940618;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe385657-c62c-4fb1-b17a-f90408094ef0\-fe385657-c62]8;;\
#              ]8;id=940618;https://tidy3d.simulation.cloud/workbench?taskId=fdve-fe385657-c62c-4fb1-b17a-f90408094ef0\c-4fb1-b17a-f90408094ef0']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              Created task 'L_MMI=11.20;W_MMI=4.90' with task_id
#              'fdve-09f83dac-8552-43d9-888e-f960606b6e02' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=187551;https://tidy3d.simulation.cloud/workbench?taskId=fdve-09f83dac-8552-43d9-888e-f960606b6e02\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=570337;https://tidy3d.simulation.cloud/workbench?taskId=fdve-09f83dac-8552-43d9-888e-f960606b6e02\taskId]8;;\]8;id=187551;https://tidy3d.simulation.cloud/workbench?taskId=fdve-09f83dac-8552-43d9-888e-f960606b6e02\=]8;;\]8;id=368508;https://tidy3d.simulation.cloud/workbench?taskId=fdve-09f83dac-8552-43d9-888e-f960606b6e02\fdve]8;;\]8;id=187551;https://tidy3d.simulation.cloud/workbench?taskId=fdve-09f83dac-8552-43d9-888e-f960606b6e02\-09f83dac-855]8;;\
#              ]8;id=187551;https://tidy3d.simulation.cloud/workbench?taskId=fdve-09f83dac-8552-43d9-888e-f960606b6e02\2-43d9-888e-f960606b6e02']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:05:18 PST Created task 'L_MMI=11.20;W_MMI=5.00' with task_id
#              'fdve-95444199-00cd-45f9-8959-1409261a94a1' and task_type 'FDTD'.
#              View task using web UI at
#              ]8;id=50383;https://tidy3d.simulation.cloud/workbench?taskId=fdve-95444199-00cd-45f9-8959-1409261a94a1\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=625919;https://tidy3d.simulation.cloud/workbench?taskId=fdve-95444199-00cd-45f9-8959-1409261a94a1\taskId]8;;\]8;id=50383;https://tidy3d.simulation.cloud/workbench?taskId=fdve-95444199-00cd-45f9-8959-1409261a94a1\=]8;;\]8;id=822798;https://tidy3d.simulation.cloud/workbench?taskId=fdve-95444199-00cd-45f9-8959-1409261a94a1\fdve]8;;\]8;id=50383;https://tidy3d.simulation.cloud/workbench?taskId=fdve-95444199-00cd-45f9-8959-1409261a94a1\-95444199-00c]8;;\
#              ]8;id=50383;https://tidy3d.simulation.cloud/workbench?taskId=fdve-95444199-00cd-45f9-8959-1409261a94a1\d-45f9-8959-1409261a94a1']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:05:23 PST Started working on Batch.
# 22:05:26 PST Maximum FlexCredit cost: 2.560 for the whole batch.
#              Use 'Batch.real_cost()' to get the billed FlexCredit cost after the
#              Batch has completed.
# Output()
# 22:06:59 PST Batch complete.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>

# %% [markdown]
# Parse flux data into numpy arrays.

# %%
T1 = np.zeros((len(L_MMIs), len(W_MMIs)))
T2 = np.zeros((len(L_MMIs), len(W_MMIs)))
for i, L_MMI in enumerate(L_MMIs):
    for j, W_MMI in enumerate(W_MMIs):
        sim_data = batch_results[f"L_MMI={L_MMI:.2f};W_MMI={W_MMI:.2f}"]
        t1 = sim_data["flux1"].flux
        T1[i, j] = t1[50]  # the index 50 corresponds to the wavelength of 1550 nm
        t2 = sim_data["flux2"].flux
        T2[i, j] = t2[50]
# Out:
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:02 PST loading simulation from
#              data/fdve-6d15615e-203a-4071-a14f-018ebaae97c8.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:03 PST loading simulation from
#              data/fdve-25487baf-bac7-4965-a65d-edefe1faf377.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:04 PST loading simulation from
#              data/fdve-59e394a0-c6ad-4bbe-8587-c7f51d6372ee.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:05 PST loading simulation from
#              data/fdve-d818859b-6c3c-45af-94a1-ffa278942dca.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#              loading simulation from
#              data/fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:06 PST loading simulation from
#              data/fdve-5bfa533a-ad4d-4afc-812f-782b89c9f3b7.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:07 PST loading simulation from
#              data/fdve-fe385657-c62c-4fb1-b17a-f90408094ef0.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:08 PST loading simulation from
#              data/fdve-09f83dac-8552-43d9-888e-f960606b6e02.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 22:07:09 PST loading simulation from
#              data/fdve-95444199-00cd-45f9-8959-1409261a94a1.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.

# %% [markdown]
# Visualize power difference between outputs as well as the excess loss. The optimal design would have both values as close to 0 as possible. From the plots, we can see that in this parameter range, the smallest power different does not coincide with the lowest excess loss. If we prioritize small power difference, for example, L_MMI = 11.15 $\mu m$ and W_MMI = 4.9 $\mu m$ would be a good design choice.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))
plt.sca(ax1)
plt.pcolor(W_MMIs, L_MMIs, np.abs(T1 - T2), vmin=0, vmax=0.02, cmap="binary")
plt.colorbar()
plt.title("Power difference between inner and outer waveguides")
plt.xlabel("W_MMI ($\mu m$)")
plt.ylabel("L_MMI ($\mu m$)")
plt.sca(ax2)
plt.pcolor(
    W_MMIs, L_MMIs, -10 * np.log10(2 * (T1 + T2)), vmin=0, vmax=0.25, cmap="binary"
)
plt.colorbar()
plt.title("Excess loss (dB)")
plt.xlabel("W_MMI ($\mu m$)")
plt.ylabel("L_MMI ($\mu m$)")
plt.show()

# %% [markdown]
# Plot field intensity for the optimal design.

# %%
sim_data = batch_results["L_MMI=11.15;W_MMI=4.90"]
f, ax = plt.subplots(1, 1, figsize=(10, 10))
sim_data.plot_field(
    field_monitor_name="field", field_name="E", val="abs^2", ax=ax, f=freq0
)
plt.show()
# Out:
#              loading simulation from
#              data/fdve-fe572e26-1fb1-4ecc-bda1-7993b945f080.hdf5
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
#              WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.

# %% [markdown]
# Plot transmission on each output waveguide as well as the total excess loss. For this design, at the central wavelength of 1.55 $\mu m$, the power on each power is roughly equal. The total excess loss is below 0.2 dB.

# %%
f, (ax1, ax2) = plt.subplots(1, 2, tight_layout=True, figsize=(10, 5))
T1 = sim_data["flux1"].flux
T2 = sim_data["flux2"].flux

plt.sca(ax1)
plt.plot(ldas, T1, ldas, T2)
plt.vlines(x=1.55, ymin=0.1, ymax=0.3, colors="black", ls="--")
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Transmission to output")
plt.legend(("Inner output", "Outer outport"))

plt.sca(ax2)
excess_loss = -10 * np.log10(2 * (T1 + T2))
plt.plot(ldas, excess_loss)
plt.vlines(x=1.55, ymin=0, ymax=1, colors="black", ls="--")
plt.hlines(y=excess_loss[50], xmin=1.5, xmax=1.6, colors="black", ls="--")
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Excess loss (dB)")
plt.show()

# %% [markdown]
# In principle, the design can be further optimized by tuning other parameters such as gap size, tapper width, etc. if even lower excess loss is required.
# Finally, we can see the mode decomposition at the outer output waveguide. The fundamental mode is still dominant.

# %%
mode_amp = sim_data["mode2"].amps.sel(direction="+")
mode_power = np.abs(mode_amp) ** 2 / T2
plt.plot(ldas, mode_power)
plt.xlabel("Wavelength ($\mu m$)")
plt.ylabel("Power fraction of the modes (%)")
plt.legend(["Mode 0", "Mode 1"])
plt.show()
# Out:
# 22:07:11 PST WARNING: Monitor data requires 'grid_expanded' to be defined to
#              compute values like flux, Poynting and dot product with other data.
