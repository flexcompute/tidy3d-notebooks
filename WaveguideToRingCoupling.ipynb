# %% [markdown]
# # Waveguide to ring coupling

# %% [markdown]
# Optical ring resonators are key components in the field of integrated photonics. The unique capability of ring resonators to selectively interact with specific wavelengths of light makes them extremely versatile. They can be utilized in a broad array of applications, including optical filtering, modulating, switching, and sensing. However, simulating a ring resonator can be computationally expensive due to the high-Q resonances. Alternatively, we can investigate the coupling between a straight waveguide to a ring only by simulating the coupling region. The coupling coefficients can be extracted from this much simpler simulation.
#
# Noticeably, in a waveguide-to-ring simulation, one of the simulation domain boundaries intersects the ring structure. Non-translational invariant structures inside PML are known to cause instabilities in a FDTD simulation so such a simulation is likely to **diverge**. In this notebook, we will try to use the PML boundary first to see if the simulation diverges. When it does, we will apply an effective remedy under this situation: **replacing the PML with the adiabatic absorber boundary**. The absorber functions similarly to PML such that it absorbs the outgoing radiation to mimic the infinite space. However, the absorber has a slightly higher reflection and requires a bit more computation than PML but it is numerically much more stable.
#
# FDTD simulations can diverge due to various reasons. If you run into any simulation divergence issues, please follow the steps outlined in our [troubleshooting guide](https://www.flexcompute.com/tidy3d/examples/notebooks/DivergedFDTDSimulation/) to resolve it.
#
# <img src="img/waveguide_to_ring.png" width="600" alt="Schematic of the waveguide to ring coupling">
#
# For more integrated photonic examples such as the [8-Channel mode and polarization de-multiplexer](https://www.flexcompute.com/tidy3d/examples/notebooks/8ChannelDemultiplexer/), the [broadband bi-level taper polarization rotator-splitter](https://www.flexcompute.com/tidy3d/examples/notebooks/BilevelPSR/), and the [broadband directional coupler](https://www.flexcompute.com/tidy3d/examples/notebooks/BroadbandDirectionalCoupler/), please visit our [examples page](https://www.flexcompute.com/tidy3d/examples/).
#
# If you are new to the finite-difference time-domain (FDTD) method, we highly recommend going through our [FDTD101](https://www.flexcompute.com/fdtd101/) tutorials.

# %%
import gdstk
import matplotlib.pyplot as plt
import numpy as np
import tidy3d as td
import tidy3d.web as web

# %% [markdown]
# ## Simulation Setup

# %% [markdown]
# Define simulation wavelength range to be 1.5 $\mu m$ to 1.6 $\mu m$.
# .

# %%
lda0 = 1.55  # central wavelength
ldas = np.linspace(1.5, 1.6, 101)  # wavelength range of interest
freq0 = td.C_0 / lda0  # central frequency
freqs = td.C_0 / ldas  # frequency range of interest
fwidth = 0.5 * (np.max(freqs) - np.min(freqs))  # frequency width of the source

# %% [markdown]
# The ring and waveguide are made of silicon. The top and bottom claddings are made of silicon oxide. Here we use the materials from Tidy3D's [material library](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/material_library.html) directly.

# %%
# define silicon and silicon dioxide media from the material library
si = td.material_library["cSi"]["Li1993_293K"]
sio2 = td.material_library["SiO2"]["Horiba"]

# %% [markdown]
# Define the geometric parameters. The waveguide is 500 nm wide and 220 nm thick. The ring has a radius of 5 $\mu m$ and the gap size is 50 nm.

# %%
w = 0.5  # width of the waveguide
h_si = 0.22  # thickness of the silicon layer
gap = 0.05  # gap size between the waveguides and the ring
r = 5  # radius of the ring
inf_eff = 1e2  # effective infinity

# simulation domain size
Lx = 2 * r + 2 * lda0
Ly = r / 2 + gap + 2 * w + lda0
Lz = 9 * h_si

# %% [markdown]
# We only need to define two structures: a straight waveguide and a ring. Both are commonly used PIC components introduced in the [demonstration notebook](../notebooks/PICComponents.html). We can simply copy the associated functions here and them use to define the structures quickly. Namely, we copy the `straight_waveguide` function and the `ring_resonator` function.

# %%
def straight_waveguide(x0, y0, z0, x1, y1, wg_width, wg_thickness, medium, sidewall_angle=0):
    """
    This function defines a straight strip waveguide and returns the tidy3d structure of it.

    Parameters
    ----------
    x0: x coordinate of the waveguide starting position (um)
    y0: y coordinate of the waveguide starting position (um)
    z0: z coordinate of the waveguide starting position (um)
    x1: x coordinate of the waveguide end position (um)
    y1: y coordinate of the waveguide end position (um)
    wg_width: width of the waveguide (um)
    wg_thickness: thickness of the waveguide (um)
    medium: medium of the waveguide
    sidewall_angle: side wall angle of the waveguide (rad)
    """

    cell = gdstk.Cell("waveguide")  # define a gds cell

    path = gdstk.RobustPath((x0, y0), wg_width, layer=1, datatype=0)  # define a path
    path.segment((x1, y1))

    cell.add(path)  # add path to the cell

    # define geometry from the gds cell
    wg_geo = td.PolySlab.from_gds(
        cell,
        gds_layer=1,
        axis=2,
        slab_bounds=(z0 - wg_thickness / 2, z0 + wg_thickness / 2),
        sidewall_angle=sidewall_angle,
    )

    # define tidy3d structure of the bend
    wg = td.Structure(geometry=wg_geo[0], medium=medium)

    return wg

# %%
def ring_resonator(
    x0,
    y0,
    z0,
    R,
    wg_width,
    wg_thickness,
    medium,
    sidewall_angle=0,
):
    """
    This function defines a ring and returns the tidy3d structure of it.

    Parameters
    ----------
    x0: x coordinate of center of the ring (um)
    y0: y coordinate of center of the ring (um)
    z0: z coordinate of center of the ring (um)
    R: radius of the ring (um)
    wg_width: width of the waveguide (um)
    wg_thickness: thickness of the waveguide (um)
    medium: medium of the waveguide
    sidewall_angle: side wall angle of the waveguide (rad)
    """

    cell = gdstk.Cell("top")  # define a gds cell

    # define a path
    path_top = gdstk.RobustPath(
        (x0 + R, y0), wg_width - wg_thickness * np.tan(np.abs(sidewall_angle)), layer=1, datatype=0
    )
    path_top.arc(R, 0, np.pi)  # make the top half of the ring
    cell.add(path_top)  # add path to the cell

    # the reference plane depends on the sign of the sidewall_angle
    if sidewall_angle >= 0:
        reference_plane = "top"
    else:
        reference_plane = "bottom"

    # define top half ring geometry
    ring_top_geo = td.PolySlab.from_gds(
        cell,
        gds_layer=1,
        axis=2,
        slab_bounds=(z0 - wg_thickness / 2, z0 + wg_thickness / 2),
        sidewall_angle=sidewall_angle,
        reference_plane=reference_plane,
    )

    # similarly for the bottom half of the ring
    cell = gdstk.Cell("bottom")
    path_bottom = gdstk.RobustPath(
        (x0 + R, y0), wg_width - wg_thickness * np.tan(np.abs(sidewall_angle)), layer=1, datatype=0
    )

    path_bottom.arc(R, 0, -np.pi)
    cell.add(path_bottom)

    ring_bottom_geo = td.PolySlab.from_gds(
        cell,
        gds_layer=1,
        axis=2,
        slab_bounds=(z0 - wg_thickness / 2, z0 + wg_thickness / 2),
        sidewall_angle=sidewall_angle,
        reference_plane=reference_plane,
    )

    # define ring structure
    ring = td.Structure(
        geometry=td.GeometryGroup(geometries=ring_bottom_geo + ring_top_geo), medium=medium
    )

    return ring

# %% [markdown]
# Use the above functions to define the [Structures](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Structure.html).

# %%
# define straight waveguide
waveguide = straight_waveguide(
    x0=-inf_eff,
    y0=0,
    z0=0,
    x1=inf_eff,
    y1=0,
    wg_width=w,
    wg_thickness=h_si,
    medium=si,
    sidewall_angle=0,
)

# define ring
ring = ring_resonator(
    x0=0,
    y0=w + gap + r,
    z0=0,
    R=r,
    wg_width=w,
    wg_thickness=h_si,
    medium=si,
    sidewall_angle=0,
)

# %% [markdown]
# We will use a [ModeSource](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeSource.html) to excite the straight waveguide using the fundamental TE mode. A [ModeMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeMonitor.html) is placed at the through to measure the transmission. Another [ModeMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeMonitor.html) is placed at the ring to measure the coupling to the ring. For the monitor at the ring, we need to properly set up `angle_theta`, `angle_theta`, `bend_radius`, and `bend_axis` in the [ModeSpec](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.ModeSpec.html) as demonstrated in the [tutorial](https://www.flexcompute.com/tidy3d/examples/notebooks/ModesBentAngled/). Finally, we add a [FieldMonitor](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.FieldMonitor.html) to help visualize the field distribution.

# %%
n_si = 3.47
# mode spec for the source
mode_spec_source = td.ModeSpec(num_modes=1, target_neff=n_si)
# mode spec for the through port
mode_spec_through = mode_spec_source
# angle of the mode at the ring
theta = np.pi / 4
# mode spec for the drop port at the ring
mode_spec_drop = td.ModeSpec(
    num_modes=1, target_neff=n_si, angle_theta=theta, bend_radius=r, bend_axis=1
)

# add a mode source as excitation
mode_source = td.ModeSource(
    center=(-r - lda0 / 4, 0, 0),
    size=(0, 6 * w, 6 * h_si),
    source_time=td.GaussianPulse(freq0=freq0, fwidth=fwidth),
    direction="+",
    mode_spec=mode_spec_source,
    mode_index=0,
)

# add a mode monitor to measure transmission at the through port
mode_monitor_through = td.ModeMonitor(
    center=(r + lda0 / 4, 0, 0),
    size=mode_source.size,
    freqs=freqs,
    mode_spec=mode_spec_through,
    name="through",
)

# add a mode monitor to measure transmission at the drop port
mode_monitor_drop = td.ModeMonitor(
    center=(np.sin(theta) * r, w + gap + r - np.cos(theta) * r, 0),
    size=(6 * w, 0, 6 * h_si),
    freqs=freqs,
    mode_spec=mode_spec_drop,
    name="drop",
)

# add a field monitor to visualize the field distribution
field_monitor = td.FieldMonitor(
    center=(0, 0, 0), size=(td.inf, td.inf, 0), freqs=[freq0], name="field"
)

# %% [markdown]
# ## Using PML Boundary

# %% [markdown]
# Finally, we define the Simulation. Intuitively, we would use the [PML](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.PML.html) boundary on all sides similar to what we did in most other PIC component simulations. Let's try it here.

# %%
run_time = 2e-12  # simulation run time

# construct simulation
sim_pml = td.Simulation(
    center=(0, Ly / 4, 0),
    size=(Lx, Ly, Lz),
    grid_spec=td.GridSpec.auto(min_steps_per_wvl=25, wavelength=lda0),
    structures=[waveguide, ring],
    sources=[mode_source],
    monitors=[mode_monitor_through, mode_monitor_drop, field_monitor],
    run_time=run_time,
    boundary_spec=td.BoundarySpec.all_sides(boundary=td.PML()),
    medium=sio2,
    symmetry=(0, 0, 1),
)

# plot simulation
sim_pml.plot(z=0)
plt.show()

# %% [markdown]
# Submit the simulation to the server to run.

# %%
sim_data = web.run(
    simulation=sim_pml, task_name="waveguide_to_ring", path="data/simulation_data.hdf5"
)
# Out:
# 12:01:51 Eastern Daylight Time Created task 'waveguide_to_ring' with task_id
#                                'fdve-830a9632-dd43-4833-a440-949c42caccd9' and
#                                task_type 'FDTD'.
#                                View task using web UI at
#                                ]8;id=675012;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=695010;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\taskId]8;;\
#                                ]8;id=675012;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\=]8;;\]8;id=8313;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\fdve]8;;\]8;id=675012;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\-830a9632-dd43-4833-a440-949c42caccd9']8;;\.
#                                Task folder: ]8;id=816567;https://tidy3d.simulation.cloud/folders/639eb096-a602-4b56-a502-cac1f18f9557\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:01:53 Eastern Daylight Time Maximum FlexCredit cost: 0.469. Minimum cost
#                                depends on task execution details. Use
#                                'web.real_cost(task_id)' to get the billed
#                                FlexCredit cost after a simulation run.
#                                status = queued
#                                To cancel the simulation, use
#                                'web.abort(task_id)' or 'web.delete(task_id)' or
#                                abort/delete the task in the web UI. Terminating
#                                the Python script will not stop the job running
#                                on the cloud.
# Output()
# 12:02:00 Eastern Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:02:04 Eastern Daylight Time starting up solver
# 12:02:05 Eastern Daylight Time running solver
# Output()
# 12:02:41 Eastern Daylight Time early shutoff detected at 52%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                status = postprocess
# Output()
# 12:02:43 Eastern Daylight Time status = diverged
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:02:45 Eastern Daylight Time View simulation result at
#                                ]8;id=421692;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=811101;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\taskId]8;;\
#                                ]8;id=421692;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\=]8;;\]8;id=618923;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\fdve]8;;\]8;id=421692;https://tidy3d.simulation.cloud/workbench?taskId=fdve-830a9632-dd43-4833-a440-949c42caccd9\-830a9632-dd43-4833-a440-949c42caccd9']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:02:48 Eastern Daylight Time loading simulation from data/simulation_data.hdf5
# 12:02:50 Eastern Daylight Time WARNING: The simulation has diverged! For more
#                                information, check 'SimulationData.log' or use
#                                'web.download_log(task_id)'.

# %% [markdown]
# Now we see that the status of the job is shown to be **diverged**. As discussed in the introduction, it should not come as a surprise since the ring section in the PML layer is not perpendicular to the boundary and translational invariant as shown in the zoomed-in plot below. We see that we are also given a warning about the divergence and prompted to check the log for more information.

# %%
print(sim_data.log)
# Out:
# [16:02:00] USER: Simulation domain Nx, Ny, Nz: [759, 280, 82]
#            USER: Applied symmetries: (0, 0, 1)
#            USER: Number of computational grid points: 9.2279e+06.
#            USER: Subpixel averaging method: SubpixelSpec(attrs={},
#            dielectric=PolarizedAveraging(attrs={}, type='PolarizedAveraging'),
#            metal=Staircasing(attrs={}, type='Staircasing'),
#            pec=PECConformal(attrs={}, type='PECConformal',
#            timestep_reduction=0.3), lossy_metal=SurfaceImpedance(attrs={},
#            type='SurfaceImpedance', timestep_reduction=0.0),
#            type='SubpixelSpec')
#            USER: Number of time steps: 6.2950e+04
#            USER: Automatic shutoff factor: 1.00e-05
#            USER: Time step (s): 3.1772e-17
#            USER:
#
#            USER: Mode solver at f=1.9341448903e+14 with plane size (135, 24),
#            direction: +
#            USER: Compute source modes time (s):     0.8372
# [16:02:01] USER: Rest of setup time (s):            0.5892
# [16:02:08] USER: Mode solver at f=1.9986163867e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9972848634e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9919764651e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9671421129e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9762192353e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9749173781e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9736172350e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9697270565e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9893328334e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9840665652e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9827543519e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9959551132e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9853805166e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9723188026e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9906537716e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9814438731e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9866962094e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9933009176e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9880136472e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9801351255e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9788281056e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9775228100e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9710220776e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9684337360e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9946271324e+14 with plane size (135, 24),
#            direction: +
# [16:02:08] USER: Mode solver at f=1.9658521836e+14 with plane size (135, 24),
#            direction: +
# [16:02:17] USER: Mode solver at f=1.9645639450e+14 with plane size (135, 24),
#            direction: +
# [16:02:17] USER: Mode solver at f=1.9632773936e+14 with plane size (135, 24),
#            direction: +
# [16:02:17] USER: Mode solver at f=1.9619925262e+14 with plane size (135, 24),
#            direction: +
# [16:02:17] USER: Mode solver at f=1.9607093394e+14 with plane size (135, 24),
#            direction: +
# [16:02:17] USER: Mode solver at f=1.9594278301e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9581479948e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9568698303e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9555933333e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9543185007e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9530453290e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9517738151e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9505039558e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9492357477e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9479691878e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9467042727e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9454409994e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9441793645e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9429193649e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9416609974e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9404042589e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9391491462e+14 with plane size (135, 24),
#            direction: +
# [16:02:18] USER: Mode solver at f=1.9378956561e+14 with plane size (135, 24),
#            direction: +
# [16:02:19] USER: Mode solver at f=1.9366437855e+14 with plane size (135, 24),
#            direction: +
# [16:02:19] USER: Mode solver at f=1.9353935313e+14 with plane size (135, 24),
#            direction: +
# [16:02:19] USER: Mode solver at f=1.9341448903e+14 with plane size (135, 24),
#            direction: +
# [16:02:19] USER: Mode solver at f=1.9328978594e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9316524356e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9304086156e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9291663964e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9279257749e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9266867481e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9254493128e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9242134660e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9229792046e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9217465256e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9205154260e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9192859027e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9180579527e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9168315729e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9156067604e+14 with plane size (135, 24),
#            direction: +
# [16:02:26] USER: Mode solver at f=1.9143835121e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9131618251e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9119416964e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9107231230e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9095061019e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9082906302e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9070767048e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9058643229e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9046534816e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9034441778e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9022364086e+14 with plane size (135, 24),
#            direction: +
# [16:02:27] USER: Mode solver at f=1.9010301712e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8998254626e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8986222799e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8974206203e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8962204807e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8950218584e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8938247505e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8926291540e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8914350662e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8902424842e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8890514052e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8878618262e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8866737445e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8854871572e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8843020616e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8831184548e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8819363340e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8807556964e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8795765392e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8783988596e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8772226550e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8760479224e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8748746592e+14 with plane size (135, 24),
#            direction: +
# [16:02:36] USER: Mode solver at f=1.8737028625e+14 with plane size (135, 24),
#            direction: +
# [16:02:39] USER: Solver time (s):                   34.4010
#            USER: Time-stepping speed (cells/s):     1.05e+10
#            WARNING: The simulation has diverged!
#            WARNING: Some structures were found to be spatially varying inside
#            the PML. Ensure that structures are translationally invariant in the
#            PML regions in the direction normal to the PML interface.
#            Alternatively, switching the PML to Absorber boundary should fix the
#            divergence.
#            WARNING: A dispersive medium inside the PML regions was detected,
#            which may be causing the divergence. Consider making the medium
#            non-dispersive, or fitting a different dispersive model for that
#            medium. Alternatively, switching the PML to Absorber boundary should
#            fix the divergence.
# [16:02:40] USER: Post-processing time (s):          0.5700
#
#  ====== SOLVER LOG ======
#
# Processing grid and structures...
# Building FDTD update coefficients...
# Potential divergence: dispersive medium into PML.
# Potential divergence: structures are not translationally invariant inside PML.
# Solver setup time (s):             4.3910
#
# Running solver for 62950 time steps...
# - Time step   2517 / time 8.00e-14s (  4 % done), field decay: 1.00e+00
# - Time step   4010 / time 1.27e-13s (  6 % done), field decay: 1.00e+00
# - Time step   5035 / time 1.60e-13s (  8 % done), field decay: 1.00e+00
# - Time step   7553 / time 2.40e-13s ( 12 % done), field decay: 1.00e+00
# - Time step  10071 / time 3.20e-13s ( 16 % done), field decay: 6.82e-02
# - Time step  12589 / time 4.00e-13s ( 20 % done), field decay: 2.93e-04
# - Time step  15107 / time 4.80e-13s ( 24 % done), field decay: 1.00e+00
# - Time step  17625 / time 5.60e-13s ( 28 % done), field decay: 1.00e+00
# - Time step  20143 / time 6.40e-13s ( 32 % done), field decay: 1.00e+00
# - Time step  22661 / time 7.20e-13s ( 36 % done), field decay: 1.00e+00
# - Time step  25179 / time 8.00e-13s ( 40 % done), field decay: 1.00e+00
# - Time step  27697 / time 8.80e-13s ( 44 % done), field decay: 1.00e+00
# - Time step  30215 / time 9.60e-13s ( 48 % done), field decay: 1.00e+00
# - Time step  32733 / time 1.04e-12s ( 52 % done), field decay: 1.00e+00
# Field diverged at time step  33820 ( 53 % done), exiting solver.
# Time-stepping time (s):            29.6326
# Data write time (s):               0.3752

# %% [markdown]
# The log indeed tells us that there are two potential causes of divergence that were found in this simulation. One is the presence of dispersive materials in the PML, while the other is the fact that the ring is not translationally invariant. While both of those things can cause divergence, our in-built silicon material model has been fit to perform well for straight waveguides going into the PML, at telecommunication wavelengths. Thus, the more likely cause of the divergence is the fact that the ring is not translationally invariant.

# %%
# zoom-in plot around the pml
ax = sim_pml.plot(z=0)
ax.set_xlim(4, 5.5)
ax.set_ylim(3.5, 4.5)
plt.show()

# %% [markdown]
# This can be further confirmed by plotting the electric field distribution. From the plot, we can see where the field built up and caused the simulation to diverge. As expected, the field built up around the ring to PML area.

# %%
sim_data.plot_field(field_monitor_name="field", field_name="E", val="abs")
plt.show()

# %% [markdown]
# ## Using Absorber Boundary

# %% [markdown]
# To resolve the diverge, we can switch to [Absorber](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Absorber.html). This can be done by copying the previous simulation and only updating the `boundary_spec`. Since the ring is only intersecting the boundary in the y direction, we only need to apply [Absorber](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Absorber.html) to the positive $y$ boundary.
#
# In addition, we increased the number of layers in the [Absorber](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Absorber.html) to `60` to ensure sufficient absorption and minimal reflection.

# %%
# copy simulation and update boundary condition
sim_absorber = sim_pml.copy(
    update={
        "boundary_spec": td.BoundarySpec(
            x=td.Boundary.pml(),
            y=td.Boundary(plus=td.Absorber(num_layers=60), minus=td.PML()),
            z=td.Boundary.pml(),
        )
    }
)

# run simulation
sim_data = web.run(
    simulation=sim_absorber, task_name="waveguide_to_ring", path="data/simulation_data.hdf5"
)
# Out:
# 12:02:53 Eastern Daylight Time Created task 'waveguide_to_ring' with task_id
#                                'fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363' and
#                                task_type 'FDTD'.
#                                View task using web UI at
#                                ]8;id=25151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=164381;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\taskId]8;;\
#                                ]8;id=25151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\=]8;;\]8;id=367169;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\fdve]8;;\]8;id=25151;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\-da026ba0-cbdd-46b4-b0e7-886fdaa2c363']8;;\.
#                                Task folder: ]8;id=155438;https://tidy3d.simulation.cloud/folders/639eb096-a602-4b56-a502-cac1f18f9557\'default']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:02:55 Eastern Daylight Time Maximum FlexCredit cost: 0.520. Minimum cost
#                                depends on task execution details. Use
#                                'web.real_cost(task_id)' to get the billed
#                                FlexCredit cost after a simulation run.
#                                status = queued
#                                To cancel the simulation, use
#                                'web.abort(task_id)' or 'web.delete(task_id)' or
#                                abort/delete the task in the web UI. Terminating
#                                the Python script will not stop the job running
#                                on the cloud.
# Output()
# 12:03:02 Eastern Daylight Time status = preprocess
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:03:07 Eastern Daylight Time starting up solver
#                                running solver
# Output()
# 12:04:24 Eastern Daylight Time early shutoff detected at 20%, exiting.
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
#                                status = postprocess
# Output()
# 12:04:30 Eastern Daylight Time status = success
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# 12:04:32 Eastern Daylight Time View simulation result at
#                                ]8;id=961676;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\'https://tidy3d.simulation.cloud/workbench?]8;;\]8;id=6771;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\taskId]8;;\
#                                ]8;id=961676;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\=]8;;\]8;id=600388;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\fdve]8;;\]8;id=961676;https://tidy3d.simulation.cloud/workbench?taskId=fdve-da026ba0-cbdd-46b4-b0e7-886fdaa2c363\-da026ba0-cbdd-46b4-b0e7-886fdaa2c363']8;;\.
# Output()
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace">
# </pre>
# 12:04:36 Eastern Daylight Time loading simulation from data/simulation_data.hdf5

# %% [markdown]
# After switching to [Absorber](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Absorber.html), the simulation doesn't run into the divergence issue anymore and thus we can plot the transmission spectra to the through and drop ports.

# %%
# extract mode amplitude in the through port
t = sim_data["through"].amps.sel(mode_index=0, direction="+")
# extract mode amplitude in the drop port
k = sim_data["drop"].amps.sel(mode_index=0, direction="+")

# plot transmission
plt.plot(ldas, np.abs(t) ** 2, label="Through port")
plt.plot(ldas, np.abs(k) ** 2, label="Drop port")
plt.legend()
plt.xlabel(r"Wavelength ($\mu m$)")
plt.ylabel("Transmission")
plt.xlim(1.5, 1.6)
plt.ylim(0, 1)
plt.show()

# %% [markdown]
# Again we can visualize the field distribution. This time, we see the correct result where the energy is partially coupled to the ring and partially stays in the straight waveguide.

# %%
sim_data.plot_field(field_monitor_name="field", field_name="E", val="abs")
plt.show()

# %% [markdown]
# ## Additional Notes on Absorber

# %% [markdown]
# The adiabatic absorber is a multilayer system with gradually increasing conductivity. As briefly discussed above, the absorber usually has a larger undesired reflection compared to PML. In practice, this small difference rarely matters, but is important to understand for simulations that require high accuracy. There are two possible sources for the reflection from absorbers. The first, and more common one, is that the ramping up of the conductivity is not sufficiently slow, which can be remedied by increasing the number of absorber layers (40 by default). The second one is that the absorption is not high enough, such that the light reaches the PEC boundary at the end of the Absorber, travels back through it, and is still not fully attenuated before re-entering the simulation region. If this is the case, increasing the maximum conductivity (see the [API reference](https://docs.flexcompute.com/projects/tidy3d/en/latest/api/_autosummary/tidy3d.Absorber.html)) can help. In both cases, changing the order of the scaling of the conductivity (`sigma_order`) can also have an effect, but this is a more advanced setting that we typically do not recommend modifying.
